# %% [markdown]
# # Theoretical Questions

# %% [markdown]
# Question 1. What are the key differences between SQL and NoSQL databases.
#
# Answer:
#
# SQL and NoSQL databases differ in structure, scalability, and use cases. Here's a concise breakdown of their key differences:
#
# *   Data Structure:
#
#     * SQL: Relational databases use structured tables with predefined schemas, organizing data into rows and columns. Data is stored in a tabular format with fixed fields.
#     * NoSQL: Non-relational databases support flexible, schema-less structures. They handle various data types like key-value, document, column-family, or graph formats.
#
#
# *   Schema:
#
#     * SQL: Requires a rigid, predefined schema. Changes to the schema (e.g., adding columns) can be complex and may require downtime.
#     * NoSQL: Dynamic schema allows adding fields on the fly, making it adaptable to evolving data needs without major restructuring.
#
#
# *   Scalability:
#
#     * SQL: Scales vertically (adding more power to a single server). Scaling horizontally (across multiple servers) is possible but complex and less common.
#     * NoSQL: Designed for horizontal scaling, easily distributing data across multiple servers or nodes, ideal for large-scale, distributed systems.
#
#
# *   Query Language:
#
#     * SQL: Uses standardized SQL (Structured Query Language) for queries, consistent across relational databases like MySQL, PostgreSQL, or Oracle.
#     * NoSQL: Query mechanisms vary by type (e.g., MongoDB uses JSON-like queries, Cassandra uses CQL). No universal standard exists.
#
#
# *   Consistency vs. Availability:
#
#     * SQL: Emphasizes ACID (Atomicity, Consistency, Isolation, Durability) properties, ensuring strong consistency but potentially sacrificing availability in distributed systems.
#     * NoSQL: Often follows BASE (Basically Available, Soft state, Eventual consistency), prioritizing availability and partition tolerance over immediate consistency, suitable for high-availability systems.
#
#
# *   Use Cases:
#
#     * SQL: Best for structured data and applications requiring complex queries, transactions, or joins, like financial systems, ERP, or CRM.
#     * NoSQL: Suited for unstructured or semi-structured data, big data, real-time analytics, or applications like social media, IoT, or content management.
#
#
# *   Examples:
#
#     * SQL: MySQL, PostgreSQL, Oracle Database, Microsoft SQL Server.
#     * NoSQL: MongoDB (document), Cassandra (column-family), Redis (key-value), Neo4j (graph).

# %% [markdown]
# Question 2. What makes MongoDB a good choice for modern applications?
#
#
# Answer:
#
# MongoDB, a leading NoSQL database, is a strong choice for modern applications due to its flexibility, scalability, and developer-friendly features. Here’s a concise overview of what makes MongoDB well-suited for contemporary use cases:
#
# *   Flexible Document Model:
#
#     * MongoDB uses a JSON-like (BSON) document structure, allowing storage of diverse data types without a rigid schema. This flexibility supports rapid development and accommodates evolving data needs, ideal for applications like e-commerce, content management, or IoT.
#
#
# *   Scalability:
#
#     * Designed for horizontal scaling, MongoDB distributes data across multiple servers via sharding, handling large-scale, high-traffic applications efficiently. Its architecture supports seamless scaling for modern cloud-based or distributed systems.
#
#
# *   High Performance:
#
#     * MongoDB's in-memory processing, indexing, and aggregation capabilities enable fast read/write operations, making it suitable for real-time applications like analytics, social media, or recommendation engines.
#
#
# *   Rich Query Language:
#
#     * Supports powerful queries, including filtering, sorting, and aggregations, as well as geospatial and full-text search. This allows developers to handle complex data operations without needing additional tools.
#
#
# *   Developer Productivity:
#
#     * Its JSON-like documents align closely with modern programming languages (e.g., JavaScript, Python), reducing data mapping overhead. Native drivers for multiple languages and a low learning curve streamline development.
#
#
# *   Cloud-Native and Managed Services:
#
#     * MongoDB Atlas, its fully managed cloud service, simplifies deployment, scaling, and maintenance across AWS, Azure, and Google Cloud. Features like automated backups, monitoring, and global clusters support modern DevOps workflows.
#
#
# *   Support for Diverse Workloads:
#
#     * Handles unstructured, semi-structured, or structured data, making it versatile for use cases like real-time analytics, mobile apps, personalization engines, or event-driven architectures.
#
#
# *   Ecosystem and Community:
#
#     * MongoDB offers tools like MongoDB Compass (GUI), MongoDB Charts, and integration with frameworks like Node.js, Spring, or Django. A large community and extensive documentation ensure robust support.

# %% [markdown]
# Question 3.  Explain the concept of collections in MongoDB
#
# Answer:
#
# In MongoDB, a collection is a fundamental concept that serves as a container for storing documents, which are the basic units of data in this NoSQL database. Collections are analogous to tables in relational databases (e.g., SQL), but they differ significantly due to MongoDB's schema-less, document-oriented design. Below is a clear and concise explanation of collections in MongoDB:
#
# Key Characteristics of Collections
#
# *   Group of Documents:
#
#     A collection holds multiple documents, where each document is a JSON-like (BSON) record containing key-value pairs. For example, a document might look like:
#
#     {
#     "_id": 1,
#     "name": "Alice",
#     "age": 25,
#     "city": "New York"
#     }
#
#     Documents within a collection can have different structures, unlike the fixed schema of SQL tables.
#
#
# *   Schema-Less Design:
#
#     Collections do not enforce a predefined schema. This means documents in the same collection can have varied fields, data types, or structures, enabling flexibility for evolving application needs.
#
#     Example: One document in a users collection might have an age field, while another might include an email field instead, with no conflict.
#
#
# *   No Fixed Size or Structure:
#
#     Collections are dynamic, allowing documents to be added, updated, or removed without predefined constraints on size or format, making them ideal for handling diverse or unstructured data.
#
#
# *   Organized Within Databases:
#
#     Collections reside within a MongoDB database. A single database can contain multiple collections, each with a unique name (e.g., users, products, orders).
#
#     Example: A database named shop might have collections like customers, orders, and inventory.
#
#
# *   Automatic Creation:
#
#     Collections are created implicitly when you insert a document into a non-existent collection. No explicit creation command is needed, simplifying development.
#
#     Example: Running db.users.insertOne({"name": "Bob"}) creates the users collection if it doesn’t already exist.
#
#
# *   Indexing Support:
#
#     Collections support indexes to optimize query performance. You can create indexes on fields (e.g., name, _id) to enable faster searches, sorting, or filtering.
#
#     The _id field is automatically indexed as a unique identifier for each document.
#
#
# *   Capped Collections:
#
#     MongoDB supports a special type called capped collections, which have a fixed size and automatically overwrite old data when full. These are useful for logging or caching scenarios where only recent data is needed.

# %% [markdown]
# Question 4.  How does MongoDB ensure high availability using replication?
#
# Answer:
#
# MongoDB ensures high availability through replication, a process that maintains multiple copies of data across different servers to prevent data loss and ensure continuous access, even during failures. This is primarily achieved using replica sets, MongoDB’s replication mechanism. Below is a concise explanation of how MongoDB uses replication to ensure high availability:
#
# 1. Replica Sets: The Core of Replication
#
#     A replica set is a group of MongoDB servers (nodes) that maintain identical copies of data. Typically, it consists of:
#
#     Primary Node: Handles all write operations and read operations (by default). Clients interact primarily with this node.
#
#     Secondary Nodes: Replicate data from the primary node and can serve read operations (if configured). They maintain a synchronized copy of the data.
#
#     Arbiter Node (optional): A lightweight node that doesn’t store data but participates in elections to help select a new primary during failover.
#
#
#     A typical replica set has 3-5 nodes, ensuring redundancy without excessive overhead.
#
# 2. Data Synchronization
#
#     Oplog (Operation Log): The primary node records all write operations in a capped collection called the oplog. Secondary nodes continuously replicate this oplog and apply the operations to their own data copies, ensuring data consistency.
#
#     Asynchronous Replication: By default, replication is asynchronous, meaning secondaries may lag slightly behind the primary. However, this lag is typically minimal (milliseconds) under normal conditions.
#
#     Write Concern: MongoDB allows configuration of write concern to control how many nodes must acknowledge a write before it's considered successful. For example, setting w: "majority" ensures writes are acknowledged by a majority of nodes, enhancing durability.
#
# 3. Automatic Failover
#
#     If the primary node fails (e.g., due to hardware issues or network partitions), the replica set triggers an automatic failover:
#
#     Election Process: Surviving nodes communicate to elect a new primary from the secondaries. The election is based on factors like node priority, recency of data, and network reachability.
#
#     Seamless Transition: Once a new primary is elected, clients redirect their operations to it, minimizing downtime. This process typically completes in seconds.
#
#     Arbiter Role: If an arbiter is present, it votes in elections to break ties, ensuring a majority decision even in smaller replica sets.
#
#
#
# 4. High Availability Features
#
#     Redundancy: Multiple nodes ensure data is available even if one or more nodes fail. For example, in a 3-node replica set, the system remains operational as long as at least one node is available.
#
#     Data Durability: With appropriate write concern (e.g., w: "majority"), data is persisted across multiple nodes, reducing the risk of data loss.
#
#     Read Availability: Clients can read from secondary nodes (if configured), distributing read load and maintaining availability during primary node maintenance or failure.
#
#     Geographic Distribution: Replica sets can be spread across data centers (e.g., using MongoDB Atlas), ensuring availability during regional outages and reducing latency for global users.
#
# 5. Consistency vs. Availability Trade-Off
#
#     MongoDB prioritizes availability and partition tolerance (AP in CAP theorem) over strict consistency. During network partitions, secondaries may lag, but the system remains available for reads and writes.
#
#     Eventual Consistency: Secondary nodes eventually catch up with the primary via oplog replication, ensuring data consistency over time.
#
#     For applications needing stronger consistency, MongoDB supports read concern (e.g., majority) to ensure reads reflect writes acknowledged by a majority of nodes.
#
# 6. Practical Implementation
#
#     Configuration: A replica set is initialized with a configuration specifying member nodes, their roles, and settings like priority or read preferences.
#
#     Example: rs.initiate({"_id": "rs0", "members": [{"_id": 0, "host": "server1:27017"}, {"_id": 1, "host": "server2:27017"}, {"_id": 2, "host": "server3:27017"}]})
#
#     MongoDB Atlas: The managed cloud service simplifies replica set setup, maintenance, and failover, with automated backups and global distribution options.
#
#     Monitoring: Tools like MongoDB Compass, Atlas monitoring, or rs.status() provide insights into replica set health, lag, and election status.
#
# 7. Use Case Benefits
#
#     Fault Tolerance: Replica sets ensure applications like e-commerce platforms or real-time analytics remain operational during server failures.
#
#     Maintenance Without Downtime: Nodes can be upgraded or maintained by temporarily stepping down the primary, with no service interruption.
#
#     Load Balancing: Read-heavy applications (e.g., social media feeds) can distribute queries to secondaries, improving performance.
#
# 8. Limitations to Consider
#
#     Replication Lag: Asynchronous replication may cause slight delays in secondary data, which can affect applications requiring immediate consistency.
#
#     Resource Overhead: Maintaining multiple nodes increases storage and operational costs.
#
#     Complex Setup: While Atlas simplifies management, manual replica set configuration requires careful planning for network, priority, and failover settings.
#
# 9. Example Scenario
#
#     In an e-commerce application, a products collection is hosted in a 3-node replica set:
#
#     The primary node in New York handles writes (e.g., updating stock levels).
#
#     Two secondaries (one in London, one in Singapore) replicate the data, serving reads for local users and ensuring availability if the primary fails.
#
#     If the New York node goes offline, the London secondary becomes the new primary after an election, and the application continues with minimal disruption.

# %% [markdown]
# Question 5. What are the main benefits of MongoDB Atlas?
#
# Answer:
#
# MongoDB Atlas is a fully managed cloud database service that simplifies the deployment, management, and scaling of MongoDB databases. It offers numerous benefits tailored to modern application needs, making it a popular choice for developers and businesses. Below is a concise overview of the main benefits of MongoDB Atlas:
#
# 1. Fully Managed Service
#
#     Automation: Atlas handles infrastructure management tasks like provisioning, patching, backups, and monitoring, freeing developers to focus on application development.
#
#     Ease of Use: Simplifies setup with an intuitive UI, CLI, or API, allowing users to deploy clusters in minutes without managing servers.
#
# 2. Scalability
#
#     Horizontal Scaling: Supports sharding and replica sets for seamless scaling across multiple nodes to handle growing data and traffic.
#
#     Elastic Scaling: Automatically scales compute and storage resources up or down based on demand, optimizing costs and performance.
#
#     Global Clusters: Enables geographically distributed deployments for low-latency access and high availability across regions.
#
# 3. High Availability
#
#     Replica Sets: Automatically configures replica sets with primary and secondary nodes, ensuring data redundancy and automatic failover for minimal downtime.
#
#     Cross-Region Replication: Distributes data across multiple cloud regions (e.g., AWS, Azure, Google Cloud) to withstand regional outages.
#
# 4. Security Features
#
#     Built-In Security: Offers encryption at rest (using AWS KMS, Azure Key Vault, or Google Cloud KMS), TLS/SSL for data in transit, and fine-grained access control with role-based permissions.
#
#     Authentication and Authorization: Supports integration with LDAP, AWS IAM, and other identity providers for secure access management.
#
#     Network Isolation: Provides VPC peering, private endpoints, and IP whitelisting to secure database access.
#
# 5. Global Deployment and Performance
#
#     Multi-Cloud Support: Runs on AWS, Azure, and Google Cloud, allowing flexibility to choose or combine providers without vendor lock-in.
#
#     Low-Latency Reads/Writes: Global clusters and read replicas enable data locality, reducing latency for users worldwide.
#
#     Performance Optimization: Built-in tools like Performance Advisor and automated indexing suggestions enhance query efficiency.
#
# 6. Automated Backups and Recovery
#
#
#     Continuous Backups: Provides automated, continuous backups with point-in-time recovery to restore data to a specific moment.
#
#     On-Demand Snapshots: Allows manual snapshots for additional control, with minimal impact on performance.
#
#     Disaster Recovery: Supports quick recovery from accidental deletions or outages, ensuring data durability.
#
# 7. Monitoring and Analytics
#
#
#     Real-Time Monitoring: Offers detailed metrics on database performance, query execution, and resource usage through an intuitive dashboard.
#
#     Alerts and Insights: Configurable alerts for issues like high latency or resource limits, with proactive recommendations via Performance Advisor.
#
#     Integration with Analytics: Seamlessly integrates with tools like MongoDB Charts, BI Connector, or external platforms for data visualization and analysis.
#
# 8. Developer Productivity
#
#     Native Tools: Includes tools like MongoDB Compass (GUI), MongoDB Shell, and drivers for popular languages (e.g., Node.js, Python), streamlining development.
#
#     Serverless and Free Tier: Offers serverless instances and a free tier (M0) for prototyping or small-scale applications, reducing costs for developers.
#
#     Data API: Provides RESTful APIs for simplified integration with modern frameworks and serverless architectures.
#
# 9. Cost Efficiency
#
#
#     Pay-as-You-Go Pricing: Charges based on usage, with options to scale resources dynamically to match workload demands.
#
#     Free Tier and Low-Cost Options: The M0 free tier and affordable shared clusters make it accessible for startups and small projects.
#
#     Resource Optimization: Auto-scaling and workload isolation prevent over-provisioning, balancing performance and cost.
#
# 10. Ecosystem and Community
#
#
#     Integration with Modern Stacks: Works seamlessly with frameworks like React, Node.js, and cloud services like AWS Lambda or Kubernetes.
#
#     Extensive Support: Backed by MongoDB’s documentation, community forums, and enterprise-grade support for critical applications.
#
#     MongoDB University: Offers free training and certifications to help teams master Atlas and MongoDB.
#
# 11. Example Use Cases
#
#     E-commerce: Scales to handle peak traffic (e.g., Black Friday) and supports global customers with low-latency access via global clusters.
#
#     IoT Applications: Manages high-velocity, unstructured data from devices with flexible schemas and automated scaling.
#
#     Real-Time Analytics: Powers dashboards and analytics with fast queries and integration with MongoDB Charts or external BI tools.
#
#     Startups: Enables rapid prototyping with the free tier and serverless options, scaling as the business grows.

# %% [markdown]
# Question 6. What is the role of indexes in MongoDB, and how do they improve performance?
#
# Answer:
#
# In MongoDB, indexes are special data structures that optimize the speed of data retrieval operations on collections by reducing the amount of data scanned during queries. They play a critical role in improving query performance, especially for large datasets, by enabling efficient access to documents. Below is a concise explanation of the role of indexes in MongoDB and how they enhance performance.
#
# Role of Indexes in MongoDB
#
# *   Speed Up Query Execution:
#
#     Indexes allow MongoDB to locate documents quickly without scanning every document in a collection (a process called a collection scan). This is similar to using an index in a book to find specific topics without reading every page.
#
#     For example, querying a users collection for a specific email is faster with an index on the email field.
#
#
# *   Support Efficient Sorting and Filtering:
#
#     Indexes enable efficient sorting (e.g., sort({ age: 1 })) and filtering (e.g., find({ city: "New York" })) by organizing data in a way that minimizes computational overhead.
#
#     They also support range queries, regular expressions, and geospatial queries.
#
#
# *   Enforce Uniqueness:
#
#     Indexes can enforce unique constraints on fields (e.g., email or username), preventing duplicate values in a collection.
#
#     Example: db.users.createIndex({ "email": 1 }, { unique: true }) ensures no two documents have the same email.
#
#
# *   Optimize Aggregation and Joins:
#
#     Indexes improve the performance of aggregation pipelines and lookup operations by reducing the data processed during complex queries.
#
#
# *   Support Specialized Queries:
#
#     MongoDB supports various index types (e.g., text, geospatial, hashed) to optimize specific use cases like full-text search, location-based queries, or load balancing in sharded clusters.
#
#
#
# How Indexes Improve Performance:
#
# Indexes improve performance by reducing the time and resources required for queries. Here's how:
#
# *   Reduced Data Scanning:
#
#     Without an index, MongoDB performs a collection scan, examining every document in a collection, which is slow for large datasets (O(n) complexity).
#
#     With an index, MongoDB uses the index's ordered structure (typically a B-tree or B+ tree) to locate documents in O(log n) time, significantly speeding up queries.
#
#
# *   Efficient Data Access:
#
#     Indexes store references to documents' locations, allowing MongoDB to fetch only the relevant documents. For example, an index on { age: 1 } organizes documents by age, enabling quick lookups for queries like db.users.find({ age: 25 }).
#
#
# *   Minimized Resource Usage:
#
#     By avoiding full collection scans, indexes reduce CPU, memory, and disk I/O usage, improving performance for high-traffic applications.
#
#
# *   Support for Covered Queries:
#
#     A covered query is fully resolved using an index (i.e., all queried fields are in the index, and no document data needs to be fetched). This minimizes disk access, boosting performance.
#
#     Example: If an index exists on { name: 1, age: 1 }, a query like db.users.find({ name: "Alice" }, { age: 1, _id: 0 }) can be covered.

# %% [markdown]
# Question 7. Describe the stages of the MongoDB aggregation pipeline
#
# Answer:
#
# The stages of the MongoDB aggregation pipeline are a sequence of data processing steps, where each stage transforms the documents and passes the results to the next stage. The most commonly used stages include:
#
# *   $match: Filters the documents, passing only those that meet the specified condition to the next pipeline stage.
#
# *   $group: Groups documents by a specified key and applies aggregate functions like sum, count, etc., to the groups.
#
# *   $sort: Sorts documents according to specified fields in ascending or descending order.
#
# *   $project: Specifies which fields to include or exclude in the resulting documents, or can create new fields by transforming existing data.
#
# *   $set: Adds new fields or modifies existing fields in documents.
#
# *   $unset: Removes specified fields from documents.
#
# *   $unwind: Deconstructs an array field from the input documents to output one document per array element.
#
# *   $limit: Limits the number of documents passed to the next stage.
#
# *   $skip: Skips a specified number of documents before passing the remaining documents along.
#
# *   $count: Counts the number of documents passing through the pipeline.
#
# *   $sortByCount: Groups documents by a field and sorts them by the count of documents in each group, descending by default.
#
# *   $lookup: Performs joins with other collections.
#
# *   $facet: Processes multiple pipelines within a single stage on the same input, useful for multi-faceted aggregations.
#
# *   Each stage is represented by an operator starting with $ and is enclosed in {}. The stages run in the order they are listed, with the output of one stage becoming the input for the next.

# %% [markdown]
# Question 8.  What is sharding in MongoDB? How does it differ from replication?
#
# Answer:
#
# In MongoDB, sharding and replication are two distinct mechanisms designed to enhance scalability and availability, respectively. While both are critical for managing large-scale data and high-traffic applications, they serve different purposes. Below is a concise explanation of sharding, its role in MongoDB, and how it differs from replication.
#
# *   What is Sharding in MongoDB?
#
#     Sharding is a method for distributing data across multiple servers (or shards) to improve scalability and performance in MongoDB. It enables horizontal scaling by partitioning a large dataset into smaller, manageable chunks, called shards, which are stored on different servers. Each shard holds a subset of the data, allowing MongoDB to handle large datasets and high-throughput workloads efficiently.
#
# Key Components of Sharding
#
# *   Shard:
#
#     A single MongoDB instance or replica set that stores a portion of the collection's data.
#
#     Example: A users collection might be split so one shard holds users with IDs 1-1000, another holds 1001-2000, etc.
#
#
# *   Shard Key:
#
#     A field (or combination of fields) used to determine how data is distributed across shards.
#
#     Example: Choosing userId as a shard key splits documents based on userId values.
#
#     Types: Range-based (divides data into ranges, e.g., userId: 1-1000), Hashed (uses a hash of the shard key for even distribution), or Zoned (custom ranges for specific shards).
#
#
# *   Config Servers:
#
#     Store metadata about the sharded cluster, including the shard key ranges and shard locations.
#
#     Run as a replica set in production to ensure reliability.
#
#
# *   Mongos (Query Router):
#
#     Acts as the interface between clients and the sharded cluster, routing queries to the appropriate shards based on the shard key.
#
#     Clients interact with mongos, not individual shards.
#
#
# *   Chunks:
#
#     Subsets of data within a shard, defined by ranges of the shard key.
#
#     MongoDB automatically balances chunks across shards to prevent any single shard from becoming a bottleneck.
#
# *   How Sharding Works:
#
#     A collection is sharded by selecting a shard key, which determines how documents are distributed.
#
#     MongoDB splits the data into chunks based on the shard key and distributes them across shards.
#
#     The mongos router directs queries to the relevant shards, aggregates results if needed, and returns them to the client.
#
#     Balancer: A background process redistributes chunks to maintain even data distribution across shards as data grows or nodes are added/removed.
#
# *   Benefits of Sharding:
#
#     Scalability: Handles large datasets and high write/read throughput by distributing data across multiple servers.
#
#     Performance: Parallelizes queries across shards, reducing response times for large-scale applications.
#
#     Storage Capacity: Increases storage by adding more shards, unlike vertical scaling, which is limited by single-server capacity.
#
#     Use Cases: Ideal for applications with massive data growth, such as social media platforms, e-commerce systems, or IoT data storage.
#
# *   Example
#
#     For a products collection with millions of documents:
#
#     Shard key: productId (hashed for even distribution).
#     Data is split into chunks (e.g., 64 MB each) and distributed across 3 shards.
#     A query like db.products.find({ productId: "ABC123" }) is routed by mongos to the shard containing the relevant chunk.
#
#
# How does sharding differ from replication:
#
# *   Purpose:
#
#     Sharding is for horizontal scaling and increasing capacity, while replication is for high availability and data redundancy.
#
# *   Data Distribution:
#
#     Sharding splits different data across multiple servers, while replication copies the same data across multiple servers.
#
# *   Performance Goal:
#
#     Sharding is designed to increase read/write throughput and storage capacity, while replication is designed to provide failover and read scalability.
#
# *   Data on Each Server:
#
#     Sharding means each shard contains only a subset of the total data, while replication means each replica contains the complete dataset.
#
# *   Write Operations:
#
#     Sharding distributes writes across multiple shards based on the shard key, while replication sends all writes to the primary node only.
#
# *   Read Operations:
#
#     Sharding routes reads to the appropriate shard(s) containing the data, while replication allows reads from primary or secondary nodes.
#
# *   Failure Handling:
#
#     Sharding means if one shard fails, only that portion of data is unavailable, while replication means if the primary fails, a secondary is automatically elected as the new primary.
#
# *   Complexity:
#
#     Sharding requires careful shard key selection and is more complex to manage, while replication is simpler to configure and maintain.
#
# *   Scalability Type:
#
#     Sharding provides horizontal scaling by adding more shards, while replication provides vertical scaling and read distribution.
#
# *   Primary Use Case:
#
#     Sharding is used when your dataset or workload exceeds a single server's capacity, while replication is used when you need continuous availability and data protection.

# %% [markdown]
# Question 9. What is PyMongo, and why is it used?
#
# Answer:
#
# *   PyMongo is the official Python driver and toolkit for working with MongoDB databases from Python applications.
#
# *   It provides the necessary modules and functions to connect, query, manipulate, and manage MongoDB data directly from Python code. PyMongo allows developers to perform database operations like CRUD (create, read, update, delete), aggregation, indexing, and specialized data operations through a simple and Pythonic API.
#
# *   PyMongo is used to:
#
#     * Establish connections to MongoDB servers or clusters.
#
#     * Execute queries, insert and update documents, and manage collections or databases.
#
#     * Perform aggregation operations and utilize advanced MongoDB capabilities (e.g., GridFS, monitoring, encryption).
#
#     * Enable application development that leverages MongoDB's NoSQL architecture from Python, the preferred language for data science and backend programming.
#
# *   In summary, PyMongo is essential for any Python project requiring direct, efficient, and flexible access to MongoDB databases, and is recommended by MongoDB for native Python integration.

# %% [markdown]
# Question 10. What are the ACID properties in the context of MongoDB transactions?
#
# Answer:
#
# In the context of databases, ACID properties (Atomicity, Consistency, Isolation, Durability) are a set of principles that ensure reliable and predictable transaction processing. MongoDB, traditionally a NoSQL database optimized for flexibility and scalability, introduced support for multi-document ACID transactions starting with version 4.0 (for replica sets) and version 4.2 (for sharded clusters). These transactions allow MongoDB to provide the same reliability guarantees as traditional relational databases for specific use cases. Below is a concise explanation of the ACID properties in the context of MongoDB transactions.
# ACID Properties in MongoDB Transactions
#
# *   Atomicity:
#
#     * Definition: Ensures that all operations within a transaction are completed successfully as a single, indivisible unit. If any operation fails, the entire transaction is rolled back, and no changes are applied to the database.
#
#     * In MongoDB: A transaction involving multiple document updates (e.g., updating orders and inventory collections) is treated as a single unit. If any operation fails (e.g., due to a network error or constraint violation), MongoDB rolls back all changes made in the transaction.
#
#     * Example: Transferring funds between two accounts:
#
#         javascriptconst session = client.startSession();
#         session.withTransaction(async () => {
#         await db.accounts.updateOne({ _id: "account1" }, { $inc: { balance: -100 } }, { session });
#         await db.accounts.updateOne({ _id: "account2" }, { $inc: { balance: 100 } }, { session });
#       });
#
#       If the second update fails, the first update is undone, ensuring no partial changes.
#
#
# *   Consistency:
#
#     * Definition: Guarantees that a transaction brings the database from one valid state to another, maintaining all predefined rules, constraints, and data integrity.
#
#     * In MongoDB: Transactions ensure that the database remains consistent with its schema (if any), indexes, and unique constraints. For example, a transaction respects unique indexes and ensures data integrity across multiple documents.
#
#     * Example: If a unique index exists on the email field in a users collection, a transaction attempting to insert duplicate emails will fail, preserving consistency.
#
#     * MongoDB's eventual consistency model (in non-transactional operations) shifts to strong consistency within transactions when using appropriate read/write concerns (e.g., majority).
#
#
# *   Isolation:
#
#     * Definition: Ensures that transactions are executed in isolation from one another, preventing partial changes from being visible to other operations until the transaction is complete.
#
#     * In MongoDB: MongoDB uses snapshot isolation for transactions. Each transaction operates on a consistent snapshot of the data, ensuring that reads and writes are isolated from concurrent operations. Other transactions or queries cannot see uncommitted changes.
#
#     * Example: If one transaction updates a user's balance, another transaction cannot read the intermediate state until the first transaction commits.
#
#     * Implementation: MongoDB's snapshot isolation prevents issues like dirty reads or non-repeatable reads, though long-running transactions may encounter conflicts in high-concurrency scenarios.
#
#
# *   Durability:
#
#     * Definition: Guarantees that once a transaction is committed, its changes are permanently saved to the database, even in the event of a system failure.
#
#     * In MongoDB: Transactions are durable when committed with a write concern of majority, ensuring changes are replicated to a majority of nodes in a replica set. This guarantees that committed changes persist even if a server crashes.
#
#     * Example: After committing a transaction that updates inventory, the changes are written to the primary node’s journal and replicated to secondaries (with w: "majority"), ensuring they survive a crash.
#
#     * MongoDB Atlas enhances durability with automated backups and cross-region replication.

# %% [markdown]
# Question 11. What is the purpose of MongoDB's explain() function?
#
# Answer:
#
# The MongoDB explain() function is a diagnostic tool used to analyze and understand how MongoDB executes a query or operation. It provides detailed information about the query execution plan, including how MongoDB processes the query, which indexes (if any) are used, and the performance characteristics of the operation. This helps developers optimize queries, identify performance bottlenecks, and improve database efficiency.
# Purpose of the explain() Function
#
# The primary purposes of explain() are:
#
# *   Query Performance Analysis:
#
#     * Reveals how MongoDB retrieves data, whether it uses an index, performs a collection scan, or requires multiple steps.
#
#     * Helps identify slow queries that may need optimization, such as adding indexes or restructuring queries.
#
#
# *   Index Usage Verification:
#
#     * Shows whether an index is used for a query and, if so, which one. This ensures queries are leveraging indexes to avoid inefficient full collection scans.
#
#     * Example: Confirm if a query on db.users.find({ age: 25 }) uses an index on the age field.
#
#
# *   Execution Statistics:
#
#     * Provides metrics like the number of documents scanned, returned, or modified, as well as execution time, helping to quantify query efficiency.
#
#     * Useful for comparing different query strategies or index configurations.
#
#
# *   Troubleshooting and Debugging:
#
#     * Helps diagnose issues like why a query is slow, why it returns unexpected results, or why it consumes excessive resources.
#
#     * Identifies issues like missing indexes or suboptimal shard key usage in sharded clusters.
#
#
# *   Optimization Guidance:
#
#     * Informs decisions about creating or modifying indexes, rewriting queries, or adjusting data models to improve performance.
#
#     * Works with MongoDB Atlas's Performance Advisor, which uses explain()-like insights to recommend optimizations.
#
#
#
# *   How explain() Works:
#
#     The explain() method is appended to a MongoDB query or command (e.g., find(), aggregate(), update()).
#
#     It returns a document describing the query plan without executing the query (unless in "executionStats" or "allPlansExecution" modes).
#
#     Syntax: db.collection.<operation>.explain(<mode>)
#
#     Example: db.users.find({ age: 25 }).explain("executionStats")

# %% [markdown]
# Question 12. How does MongoDB handle schema validation?
#
# Answer:
#
# MongoDB handles schema validation by allowing developers to define explicit validation rules on collections to ensure that inserted and updated documents conform to a specified structure. While MongoDB's default mode is schemaless, schema validation enables enforcement of field requirements, data types, value ranges, and custom expressions to maintain data consistency and integrity within a collection.
#
# Mechanism of Schema Validation:
#
# *   Schema validation rules are typically specified using the $jsonSchema operator either when creating a new collection or by modifying an existing collection using the collMod command.
#
# *   The schema can enforce required fields, allowed data types, minimum/maximum values, array constraints, and complex validation expressions using JSON Schema draft specifications.
#
# *   Validation rules can be strict (applies to all documents, including existing) or moderate (applies only to new or updated documents but not to unmodified ones).
#
# *   Validation Control Options
#
#     * validationLevel: Determines whether rules apply to all documents (strict) or just to newly inserted/modified documents (moderate).
#
#     * validationAction: Specifies whether to reject documents that fail validation (error, default), or to allow but log such violations (warn).
#
#     * Example:
#
#       When creating a collection with validation, the command might look like:
#
#           db.createCollection(
#           "posts", {
#           validator: {
#             $jsonSchema: {
#               bsonType: "object",
#               required: [ "title", "body" ],
#               properties: {
#                 title: { bsonType: "string" },
#                 body: { bsonType: "string" },
#                 likes: { bsonType: "int", minimum: 0 }
#               }
#             }
#           }})
#
#       This ensures every document in the "posts" collection must have "title" and "body" as strings, and "likes" as a non-negative integer.
#
# *   By utilizing schema validation, MongoDB supports enforcement of structure and quality within otherwise flexible collections, providing important control over data integrity in NoSQL applications.

# %% [markdown]
# Question 13. What is the difference between a primary and a secondary node in a replica set?
#
# Answer:
#
# In MongoDB, a replica set is a group of servers (nodes) that maintain identical copies of data to ensure high availability and fault tolerance. The nodes in a replica set are categorized primarily as primary and secondary nodes, each with distinct roles. Below is a concise explanation of the differences between primary and secondary nodes in a MongoDB replica set.
#
#
# *    Primary node processes all write operations from clients, while secondary nodes do not process writes but replicate the primary's oplog to maintain a synchronized data copy.
#
# *    Primary node maintains the authoritative copy of the data, while secondary nodes hold a copy that may have slight replication lag due to asynchronous replication.
#
# *    Primary node records all changes in the oplog (operation log), a special capped collection, while secondary nodes apply these oplog entries to stay synchronized with the primary.
#
# *    Primary node handles read operations by default for strong consistency, ensuring clients see the latest data, while secondary nodes can serve read operations only if configured with read preferences like 'secondary' or 'secondaryPreferred', potentially providing eventual consistency.
#
# *   Primary node serves as the default client interaction point for both reads and writes, while secondary nodes only serve reads when explicitly targeted via read preference settings.
#
# *   Primary node can become unavailable, triggering a replica set election, while secondary nodes can become the new primary during an election if they have up-to-date data and sufficient priority.
#
# *   Primary node processes critical transactions, such as updating account balances in a banking application, while secondary nodes might serve read requests, like a user's transaction history, to reduce load on the primary.
#
# *   Primary node typically requires higher resources to handle write workloads, while secondary nodes offload read-heavy workloads, such as analytics or reporting, to improve performance.
#
# *   Example Context
#
#     In a banking application:
#
#     Primary node processes a transaction to update account balances, while secondary nodes replicate this change from the primary’s oplog.
#
#     Primary node serves a read request for the latest balance to ensure strong consistency, while secondary nodes might serve a read for transaction history, potentially with slight replication lag.

# %% [markdown]
# Question 14.  What security mechanisms does MongoDB provide for data protection?
#
# Answer:
#
# MongoDB provides multiple robust security mechanisms to protect data throughout its lifecycle, ensuring confidentiality, integrity, and availability.
#
# Key Security Mechanisms in MongoDB for Data Protection
#
# *   Authentication:
#
#     Validates identity of users or applications accessing the database. Supported methods include SCRAM, X.509 certificate authentication, LDAP proxy, and Kerberos, enabling integration with existing identity management systems.
#
# *   Authorization and Role-Based Access Control (RBAC):
#
#     Controls user permissions based on roles assigned, restricting access to database resources and operations to only authorized users. Fine-grained access can be set to cater to different roles within an organization.
#
# *   Encryption:
#
#     MongoDB encrypts data at all stages:
#
#     * Data at rest:
#
#       Using AES-256 encryption via WiredTiger storage engine to secure data files on disk.
#
#     * Data in transit:
#
#       TLS/SSL encrypts data traveling between clients and servers.
#
#     * Data in use:
#
#       Client-Side Field Level Encryption (CSFLE) allows encrypting specific fields before sending to MongoDB, protecting sensitive data from internal or external threats.
#
#     * Queryable Encryption lets clients query encrypted data without decrypting it, enhancing security without losing query functionality.
#
# *   Auditing and Monitoring:
#
#     MongoDB Enterprise enables detailed logging and auditing of database activities, including authentication, authorization, and data operations, facilitating security forensics and compliance.
#
# *   Network Security:
#
#     Features include firewall integration, private networking, IP whitelisting, and network isolation to protect clusters from unauthorized network access.
#
# *   Data Resiliency and Availability:
#
#     Replication with automatic failover ensures high availability and data durability, while encrypted backups and point-in-time recovery enhance data protection.
#
# * MongoDB Atlas, the managed cloud service, further integrates these security features with automated compliance, governance controls, and continuous monitoring to enable secure and compliant data management.
#
# *   Together, these mechanisms create a defense-in-depth approach, effectively safeguarding MongoDB data in diverse deployment environments and meeting stringent regulatory compliance requirements.

# %% [markdown]
# Question 15. Explain the concept of embedded documents and when they should be used?
#
# Answer:
#
# Embedded documents in MongoDB are documents contained within other documents, allowing for a nested or hierarchical data structure. This design embeds related data directly inside a parent document, rather than using references to link separate documents.
#
# Concept of Embedded Documents:
#
# *   An embedded document is stored as a value in a field of a parent document.
#
# *   They support nesting up to 100 levels deep, with a maximum document size of 16MB.
#
# *   Embedded documents can contain various data types, including other embedded documents and arrays, enabling complex data models.
#
# When to Use Embedded Documents:
#
# *   Related Data Access:
#
#     When related data is frequently accessed or updated together, embedding reduces the need for multiple queries or joins, improving performance.
#
# *   Schema Flexibility:
#
#     Embedding allows for flexible, denormalized schemas suitable for hierarchical data structures or one-to-many relationships, such as orders with multiple items or user profiles with addresses.
#
# *   Atomic Operations:
#
#     When updates or deletions need to be atomic across related data, embedding ensures these operations can be performed on a single document.
#
# *   Practical Examples:
#
#     A Passenger document may embed an address document for quick retrieval.
#
#     A Car document might embed an engine sub-document describing engine specifications.
#
#     A Customer document could include an array of orders, each containing embedded order details.
#
# In short, embedded documents should be used when data entities are tightly related, frequently accessed together, or when atomic updates for related data are needed, optimizing read performance and simplifying data management.

# %% [markdown]
# Question 16.  What is the purpose of MongoDB's $lookup stage in aggregation?
#
# Answer:
#
# The purpose of MongoDB's $lookup stage in the aggregation pipeline is to perform a left outer join between two collections in the same database. It allows documents from the input (local) collection to be enriched by joining related documents from a foreign (lookup) collection based on matching fields.
#
# Key Points about $lookup:
#
# *   It joins documents from two collections using a specified local field and foreign field for matching.
#
# *   The joined data from the foreign collection is added as an array in a new field within each input document.
#
# *   Even if no matching documents are found, the input document is included with an empty array for the joined field.
#
# *   This stage enables relational-like join queries in the flexible, schema-less environment of MongoDB.
#
#     Common use cases include combining data for reporting, analytics, and denormalizing related information for easier access.
#
#     Syntax:
#
#
#         {
#         $lookup: {
#         from: "foreignCollection",
#         localField: "localField",
#         foreignField: "foreignField",
#         as: "outputArrayField"
#         }
#         }
#
# * Example:
#
#   If there is an orders collection with a customer_id field, and a customers collection where _id corresponds to customer IDs, $lookup can embed matching customer documents inside each order:
#
#
#
#       db.orders.aggregate([
#       {
#       $lookup: {
#         from: "customers",
#         localField: "customer_id",
#         foreignField: "_id",
#         as: "customer_details"
#       }
#       }]
#       )
#
#     This will add the array field customer_details containing customer info to each order document.
#
# *   In short, $lookup is used to combine and enrich data from multiple collections with a single aggregation query, enabling more powerful and expressive queries in MongoDB

# %% [markdown]
# Question 17. What are some common use cases for MongoDB?
#
# Answer:
#
# Some common use cases for MongoDB include:
#
# *   Content Management Systems (CMS):
#
#     MongoDB's flexible document model is ideal for storing varied content types such as text, images, videos, and metadata. It enables platforms to handle complex and evolving content schemas efficiently in real time.
#
# *   E-commerce Platforms:
#
#     MongoDB supports dynamic product catalogs, customer profiles, and transaction histories. Its horizontal scalability helps manage unpredictable traffic spikes and real-time analytics for customer behavior and inventory management. Companies like eBay use it to handle massive volumes of product listings and user data.
#
# *   Real-Time Analytics:
#
#     MongoDB's aggregation framework and scalability support fast data aggregation and insights from large, continuously changing datasets. It is used by businesses to monitor customer behavior, optimize operations, and serve personalized experiences.
#
# *   Internet of Things (IoT):
#
#     IoT generates huge volumes of semi-structured data from sensors and devices. MongoDB handles this variety and scale effectively, allowing real-time data capture, trend analysis, and predictive insights for connected systems such as smart homes and industrial IoT.
#
# *   Gaming Applications:
#
#     MongoDB effectively stores dynamic player profiles, game state, achievements, and real-time interaction data. Gaming companies like Electronic Arts use MongoDB to support fast data updates and personalized gaming experiences.
#
# *   Customer Relationship Management (CRM):
#
#     MongoDB allows flexible storage of customer profiles, interactions, and transaction history. It supports evolving data models as business requirements change, used by companies like LinkedIn for managing large-scale user data.
#
# *   Social Networks:
#
#     The database manages large volumes of unstructured user-generated content such as posts, comments, relationships, and multimedia. MongoDB enables rapid scaling and real-time workflows needed for social platforms' dynamic feeds and interactions.
#
# *   Financial Services and Modernization:
#
#     MongoDB powers scalable, real-time financial platforms, credit card processing, and digital channels modernization efforts, supporting millions of daily transactions with high availability and performance.

# %% [markdown]
# Question 18. What are the advantages of using MongoDB for horizontal scaling?
#
# Answer:
#
# The advantages of using MongoDB for horizontal scaling are primarily achieved through its sharding capability, which distributes data and workload across multiple servers. Key benefits include:
#
# *   Increased Capacity:
#
#     Horizontal scaling enables MongoDB to handle very large datasets by partitioning data across many servers (shards), preventing any single server from becoming a bottleneck and allowing continuous growth.
#
# *   Improved Performance:
#
#     By distributing read and write operations across shards, horizontal scaling enhances overall query throughput and response times, making it suitable for high-traffic applications.
#
# *   High Availability and Fault Tolerance:
#
#     If one shard fails, others continue operating, reducing downtime and providing resilience through built-in replication within each shard.
#
# *   Cost Efficiency:
#
#     Instead of investing heavily in more powerful hardware, horizontal scaling allows using multiple commodity servers, which can be more budget-friendly as the data or traffic grows.
#
# *   Near-Continuous Availability:
#
#     Sharded clusters can be maintained with minimal downtime, supporting applications that require high availability.
#
# *   Flexibility for Large-Scale Applications:
#
#     Horizontal scaling supports diverse use cases like social media, e-commerce, IoT, and analytics that require rapid, unpredictable data growth handling.
#
# *   Load Balancing:
#
#     MongoDB automatically balances data and workload among shards to optimize resource usage and prevent any shard from being overloaded.

# %% [markdown]
# Question 19.  How do MongoDB transactions differ from SQL transactions?
#
# Answer:
#
# MongoDB and SQL databases both support transactions for data integrity, but their approaches differ due to MongoDB's NoSQL document model and SQL's relational structure. MongoDB introduced multi-document ACID transactions in v4.0 (replica sets) and v4.2 (sharded clusters), while SQL transactions are core to relational databases. Below is a concise comparison, halved to ~300 words.
#
# Key Differences
#
# *   Scope:
#
#     * MongoDB: Multi-document transactions are opt-in, atomic at the document level by default.
#
#     * SQL: Multi-row, multi-table transactions are standard. Example:
#
#
# *   Atomicity:
#
#     * MongoDB: Single-document operations are atomic; multi-document transactions ensure all operations succeed or fail.
#
#     * SQL: All operations within a transaction are atomic, covering rows and tables.
#
#
# *   Consistency:
#
#     *  MongoDB: Uses snapshot isolation with readConcern: "snapshot" for strong consistency; non-transactional operations may be eventually consistent.
#
#     * SQL: Enforces strict consistency, often using locking or MVCC.
#
#
# *   Isolation:
#
#     * MongoDB: Snapshot isolation prevents concurrent changes from being visible.
#
#     * SQL: Offers multiple isolation levels (e.g., Read Committed, Serializable) for flexibility.
#
#
# *   Durability:
#
#     * MongoDB: Requires writeConcern: "majority" for durability.
#
#     * SQL: Commits are durable by default, written to disk.
#
#
# *   Performance:
#
#     * MongoDB: Transactions are resource-heavy, best for specific use cases.
#
#     * SQL: Optimized for relational workloads, performance varies by isolation level.
#
#
# *   Data Model:
#
#     * MongoDB: Flexible, schema-less documents reduce join complexity.
#
#     * SQL: Normalized tables require joins and strict schemas.
#
#
# *   Implementation:
#
#     * MongoDB: Requires explicit sessions (startSession()).
#
#     * SQL: Uses simple BEGIN, COMMIT, ROLLBACK.

# %% [markdown]
# Question 20. What are the main differences between capped collections and regular collections?
#
# Answer:
#
# In MongoDB, capped collections and regular collections are two types of collections used to store documents, but they serve different purposes and have distinct characteristics. Capped collections are designed for specific use cases requiring fixed-size, high-performance storage with automatic data expiration, while regular collections offer greater flexibility for general-purpose use. Below is a concise comparison of the main differences between capped collections and regular collections in MongoDB.
#
# *   Capped collections have a fixed size with automatic overwriting of old documents, while regular collections grow dynamically without size limits.
#
#
# *   Capped collections evict the oldest documents when full, while regular collections retain all documents until explicitly deleted.
#
# *   Capped collections restrict updates to maintain document size and prohibit deletions, while regular collections allow unrestricted CRUD operations.
#
#
# *   Capped collections optimize for high-throughput writes and sequential reads, while regular collections support diverse access patterns with potential fragmentation.
#
#
# *   Capped collections have limited indexing flexibility due to their design, while regular collections support extensive indexing for varied queries.
#
# *   Capped collections are ideal for transient data like logs or caching, while regular collections suit persistent storage for applications like e-commerce.
#
#
# *   Capped collections retain schema-less nature but limit operational flexibility, while regular collections offer full schema and operational flexibility.
#
#
# *   Capped collections have sharding limitations due to their fixed-size design, while regular collections are more adaptable to distributed environments.
#
# *   Example:
#
#     Capped collection: db.createCollection("logs", { capped: true, size: 1048576 }); – Overwrites old logs when full.
#
#     Regularcollection: db.createCollection("users"); – Grows dynamically, supports full CRUD.

# %% [markdown]
# Question 21. What is the purpose of the $match stage in MongoDB's aggregation pipeline?
#
# Answer:
#
# The $match stage in MongoDB's aggregation pipeline filters documents in a collection to include only those that meet specified criteria, passing them to the next stage. It is similar to the find() method but operates within the aggregation framework, enabling efficient data processing by reducing the dataset early in the pipeline. Below is a concise explanation of its purpose, functionality, and use cases.
#
# Purpose of the $match Stage:
#
# *  Filter Documents:
#
#     $match selects documents based on conditions, such as equality, range, or logical operators, narrowing down the dataset for subsequent pipeline stages.
#
#     Example: Filter users aged 25 or older:
#
#     { $match: { age: { $gte: 25 } } }
#
#
#
# *   Optimize Pipeline Performance:
#
#     By placing this stage early in the pipeline, it reduces the number of documents processed by later stages (e.g., $group, $sort), improving efficiency.
#
#     Example: Filtering before grouping saves computational resources.
#
#
# *   Enable Complex Queries:
#
#     Supports MongoDB's query operators (e.g., $eq, $gt, $in, $regex) to express complex conditions, making it versatile for analytics and reporting.
#
#     Example: Match documents with specific categories:
#
#     { $match: { category: { $in: ["electronics", "books"] } } }
#
#
#
# *   Prepare Data for Aggregation:
#
#     Acts as the first step in data transformation, ensuring only relevant documents are processed for tasks like grouping, joining, or sorting.
#
# *   In short, $match serves as the primary mechanism to narrow down datasets in aggregation pipelines, enabling focused, performant downstream data processing and transformation.

# %% [markdown]
# Question 22. How can you secure access to a MongoDB database?
#
# Answer:
#
# To secure access to a MongoDB database, several key mechanisms and best practices should be implemented:
#
# *   Authentication:
#
#     * Use MongoDB's built-in authentication mechanisms to verify the identity of users and applications. The default method is SCRAM (Salted Challenge Response Authentication Mechanism) with SHA-256 encryption.
#
#     * Other supported authentication methods include X.509 certificate authentication, Kerberos, LDAP proxy, and OpenID Connect for integration with enterprise identity providers.
#
#     * Create separate user accounts for different roles and entities instead of shared accounts, easing access management and auditing.
#
# *   Authorization and Role-Based Access Control (RBAC):
#
#     * Define granular user roles with specific privileges to minimize the risk of excessive permissions.
#
#     * Assign roles based on the principle of least privilege, allowing users access only to the databases and operations required for their tasks.
#
# *   Network Security:
#
#     * Use firewalls, IP whitelisting, and Virtual Private Network (VPN) or private networking to restrict network access to the MongoDB server.
#
#     * Enable TLS/SSL to encrypt data in transit between clients and the database server.
#
# *   Encryption:
#
#     * Enable encryption at rest using MongoDB’s WiredTiger storage engine with AES-256 encryption.
#
#     * Use client-side field-level encryption (CSFLE) for encrypting sensitive fields before data is sent to the server for added security.
#
# *   Auditing and Monitoring:
#
#     * Enable auditing features to log authentication attempts, authorization changes, and data modifications.
#
#     * Use monitoring tools to detect unusual access patterns and potential security incidents.
#
# *   Configuration Best Practices:
#
#     * Enable authorization in the MongoDB configuration file to enforce authentication.
#
#     * Regularly update MongoDB and its components to the latest stable releases to patch security vulnerabilities.
#
#     * Use strong passwords and enforce password policies.

# %% [markdown]
# Question 23. What is MongoDB’s WiredTiger storage engine, and why is it important?
#
# Answer:
#
# MongoDB's WiredTiger storage engine is the default and most widely used storage engine since MongoDB version 3.2. It is important for several reasons related to performance, scalability, and data management:
#
# *   What is WiredTiger?
#
#     * WiredTiger is a modern, high-performance storage engine that uses a document-level concurrency model, meaning multiple write operations can occur simultaneously on different documents within the same collection, improving throughput.
#
#     * It combines advanced concepts from B-Tree and Log-Structured Merge (LSM) tree storage engines, providing efficient indexing and access to data.
#
#     * WiredTiger uses multiversion concurrency control (MVCC), enabling snapshot isolation for readers without blocking writers.
#
#     * It employs write-ahead logging (WAL) and checkpointing to ensure data durability and crash recovery.
#
#     * Supports data compression (e.g., Snappy, zlib) to reduce storage space and I/O bandwidth usage.
#
# *   Why is WiredTiger Important?
#
#     Improved Concurrency:
#
#     * Document-level locking reduces contention, allowing multiple clients to read and write concurrently, which significantly enhances performance on multi-core systems.
#
#     Better Compression:
#
#     * Compression reduces disk space usage and enhances I/O efficiency, enabling more data to be stored and accessed with less resource usage.
#
#     Durability and Reliability:
#
#     * Write-ahead logging and checkpoint mechanisms ensure that data is safely written to disk and recoverable after crashes.
#
#     Optimized for Modern Hardware:
#
#     * WiredTiger leverages modern operating system page caches and manages both internal cache and filesystem cache effectively.
#
#     Scalability:
#
#     * Supports large datasets and high-throughput workloads, making it suitable for many enterprise applications.

# %% [markdown]
# # Practical Questions

# %% [markdown]
# Question 1. Write a Python script to load the Superstore dataset from a CSV file into MongoDB
#
# Answer:

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.15.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading pymongo-4.15.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 24.3 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 26.2 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.8.0 pymongo-4.15.3

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.1.1)

# %% [markdown]
# **Please note that I am using Mongodb atlas since google colab couldn't access mongodb server on my local machine**

# %%
import pandas as pd
from pymongo import MongoClient
import os
from dotenv import load_dotenv

# Load environment variables from .env file in current directory

load_dotenv('/content/sample_data/.env')


# Get MongoDB URI from environment variable (no quotes needed in .env)
mongo_uri = os.getenv('MONGODB_URI')

# Connect to MongoDB Atlas
client = MongoClient(mongo_uri)

# Access database and collection
db = client['superstore_db']
collection = db['Orders']

# Example CSV file URL
csv_file_path = 'https://drive.google.com/uc?export=download&id=1bJ-X2ONfnE5YbsNe2bCK39IfoBHexYQO'

# Read CSV with proper encoding
df = pd.read_csv(csv_file_path, encoding='latin1')

# Convert date columns
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], errors='coerce')

# Convert DataFrame to list of dicts
records = df.to_dict(orient='records')

# Insert records into MongoDB collection
result = collection.insert_many(records)

print(f"Inserted {len(result.inserted_ids)} records into MongoDB collection 'Orders'.")
# Out:
# Inserted 9994 records into MongoDB collection 'Orders'.

# %% [markdown]
# # Note: Since output documents are longer in size I have limit the display to 100 records only but have given the count retrieved from collection. This is because due to long size of output github could not render the files. This is for question 2, 4 and 5

# %% [markdown]
# Question 2. Retrieve and print all documents from the Orders collection
#
# Answer:

# %%
# Retrieve and print all documents from orders collection

# Accessing database and collection
db = client['superstore_db']
collection = db['Orders']

# Count documents matching the query directly
count = collection.count_documents({})

print(f"Number documents from orders collection : {count}")
print("---------------------------------------------")

print("Printing just 100 documents out of all 9994")

for document in collection.find().limit(100):
    print(document)
# Out:
# Number documents from orders collection : 9994
# ---------------------------------------------
# Printing just 100 documents out of all 9994
# {'_id': ObjectId('68e63b562e1853074f2a7fb1'), 'Row ID': 1, 'Order ID': 'CA-2016-152156', 'Order Date': datetime.datetime(2016, 11, 8, 0, 0), 'Ship Date': datetime.datetime(2016, 11, 11, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'CG-12520', 'Customer Name': 'Claire Gute', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Henderson', 'State': 'Kentucky', 'Postal Code': 42420, 'Region': 'South', 'Product ID': 'FUR-BO-10001798', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Bush Somerset Collection Bookcase', 'Sales': 261.96, 'Quantity': 2, 'Discount': 0.0, 'Profit': 41.9136}
# {'_id': ObjectId('68e63b562e1853074f2a7fb2'), 'Row ID': 2, 'Order ID': 'CA-2016-152156', 'Order Date': datetime.datetime(2016, 11, 8, 0, 0), 'Ship Date': datetime.datetime(2016, 11, 11, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'CG-12520', 'Customer Name': 'Claire Gute', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Henderson', 'State': 'Kentucky', 'Postal Code': 42420, 'Region': 'South', 'Product ID': 'FUR-CH-10000454', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back', 'Sales': 731.94, 'Quantity': 3, 'Discount': 0.0, 'Profit': 219.582}
# {'_id': ObjectId('68e63b562e1853074f2a7fb3'), 'Row ID': 3, 'Order ID': 'CA-2016-138688', 'Order Date': datetime.datetime(2016, 6, 12, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 16, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'DV-13045', 'Customer Name': 'Darrin Van Huff', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90036, 'Region': 'West', 'Product ID': 'OFF-LA-10000240', 'Category': 'Office Supplies', 'Sub-Category': 'Labels', 'Product Name': 'Self-Adhesive Address Labels for Typewriters by Universal', 'Sales': 14.62, 'Quantity': 2, 'Discount': 0.0, 'Profit': 6.8714}
# {'_id': ObjectId('68e63b562e1853074f2a7fb4'), 'Row ID': 4, 'Order ID': 'US-2015-108966', 'Order Date': datetime.datetime(2015, 10, 11, 0, 0), 'Ship Date': datetime.datetime(2015, 10, 18, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'SO-20335', 'Customer Name': "Sean O'Donnell", 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Fort Lauderdale', 'State': 'Florida', 'Postal Code': 33311, 'Region': 'South', 'Product ID': 'FUR-TA-10000577', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bretford CR4500 Series Slim Rectangular Table', 'Sales': 957.5775, 'Quantity': 5, 'Discount': 0.45, 'Profit': -383.031}
# {'_id': ObjectId('68e63b562e1853074f2a7fb5'), 'Row ID': 5, 'Order ID': 'US-2015-108966', 'Order Date': datetime.datetime(2015, 10, 11, 0, 0), 'Ship Date': datetime.datetime(2015, 10, 18, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'SO-20335', 'Customer Name': "Sean O'Donnell", 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Fort Lauderdale', 'State': 'Florida', 'Postal Code': 33311, 'Region': 'South', 'Product ID': 'OFF-ST-10000760', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': "Eldon Fold 'N Roll Cart System", 'Sales': 22.368, 'Quantity': 2, 'Discount': 0.2, 'Profit': 2.5164}
# {'_id': ObjectId('68e63b562e1853074f2a7fb6'), 'Row ID': 6, 'Order ID': 'CA-2014-115812', 'Order Date': datetime.datetime(2014, 6, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'FUR-FU-10001487', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Eldon Expressions Wood and Plastic Desk Accessories, Cherry Wood', 'Sales': 48.86, 'Quantity': 7, 'Discount': 0.0, 'Profit': 14.1694}
# {'_id': ObjectId('68e63b562e1853074f2a7fb7'), 'Row ID': 7, 'Order ID': 'CA-2014-115812', 'Order Date': datetime.datetime(2014, 6, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'OFF-AR-10002833', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Newell 322', 'Sales': 7.28, 'Quantity': 4, 'Discount': 0.0, 'Profit': 1.9656}
# {'_id': ObjectId('68e63b562e1853074f2a7fb8'), 'Row ID': 8, 'Order ID': 'CA-2014-115812', 'Order Date': datetime.datetime(2014, 6, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'TEC-PH-10002275', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Mitel 5320 IP Phone VoIP phone', 'Sales': 907.152, 'Quantity': 6, 'Discount': 0.2, 'Profit': 90.7152}
# {'_id': ObjectId('68e63b562e1853074f2a7fb9'), 'Row ID': 9, 'Order ID': 'CA-2014-115812', 'Order Date': datetime.datetime(2014, 6, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'OFF-BI-10003910', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'DXL Angle-View Binders with Locking Rings by Samsill', 'Sales': 18.504, 'Quantity': 3, 'Discount': 0.2, 'Profit': 5.7825}
# {'_id': ObjectId('68e63b562e1853074f2a7fba'), 'Row ID': 10, 'Order ID': 'CA-2014-115812', 'Order Date': datetime.datetime(2014, 6, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'OFF-AP-10002892', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': 'Belkin F5C206VTEL 6 Outlet Surge', 'Sales': 114.9, 'Quantity': 5, 'Discount': 0.0, 'Profit': 34.47}
# {'_id': ObjectId('68e63b562e1853074f2a7fbb'), 'Row ID': 11, 'Order ID': 'CA-2014-115812', 'Order Date': datetime.datetime(2014, 6, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'FUR-TA-10001539', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Chromcraft Rectangular Conference Tables', 'Sales': 1706.184, 'Quantity': 9, 'Discount': 0.2, 'Profit': 85.3092}
# {'_id': ObjectId('68e63b562e1853074f2a7fbc'), 'Row ID': 12, 'Order ID': 'CA-2014-115812', 'Order Date': datetime.datetime(2014, 6, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'TEC-PH-10002033', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Konftel 250 Conference\xa0phone\xa0- Charcoal black', 'Sales': 911.424, 'Quantity': 4, 'Discount': 0.2, 'Profit': 68.3568}
# {'_id': ObjectId('68e63b562e1853074f2a7fbd'), 'Row ID': 13, 'Order ID': 'CA-2017-114412', 'Order Date': datetime.datetime(2017, 4, 15, 0, 0), 'Ship Date': datetime.datetime(2017, 4, 20, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'AA-10480', 'Customer Name': 'Andrew Allen', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Concord', 'State': 'North Carolina', 'Postal Code': 28027, 'Region': 'South', 'Product ID': 'OFF-PA-10002365', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 1967', 'Sales': 15.552, 'Quantity': 3, 'Discount': 0.2, 'Profit': 5.4432}
# {'_id': ObjectId('68e63b562e1853074f2a7fbe'), 'Row ID': 14, 'Order ID': 'CA-2016-161389', 'Order Date': datetime.datetime(2016, 12, 5, 0, 0), 'Ship Date': datetime.datetime(2016, 12, 10, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'IM-15070', 'Customer Name': 'Irene Maddox', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98103, 'Region': 'West', 'Product ID': 'OFF-BI-10003656', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Fellowes PB200 Plastic Comb Binding Machine', 'Sales': 407.976, 'Quantity': 3, 'Discount': 0.2, 'Profit': 132.5922}
# {'_id': ObjectId('68e63b562e1853074f2a7fbf'), 'Row ID': 15, 'Order ID': 'US-2015-118983', 'Order Date': datetime.datetime(2015, 11, 22, 0, 0), 'Ship Date': datetime.datetime(2015, 11, 26, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'HP-14815', 'Customer Name': 'Harold Pawlan', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Fort Worth', 'State': 'Texas', 'Postal Code': 76106, 'Region': 'Central', 'Product ID': 'OFF-AP-10002311', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': 'Holmes Replacement Filter for HEPA Air Cleaner, Very Large Room, HEPA Filter', 'Sales': 68.81, 'Quantity': 5, 'Discount': 0.8, 'Profit': -123.858}
# {'_id': ObjectId('68e63b562e1853074f2a7fc0'), 'Row ID': 16, 'Order ID': 'US-2015-118983', 'Order Date': datetime.datetime(2015, 11, 22, 0, 0), 'Ship Date': datetime.datetime(2015, 11, 26, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'HP-14815', 'Customer Name': 'Harold Pawlan', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Fort Worth', 'State': 'Texas', 'Postal Code': 76106, 'Region': 'Central', 'Product ID': 'OFF-BI-10000756', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Storex DuraTech Recycled Plastic Frosted Binders', 'Sales': 2.544, 'Quantity': 3, 'Discount': 0.8, 'Profit': -3.816}
# {'_id': ObjectId('68e63b562e1853074f2a7fc1'), 'Row ID': 17, 'Order ID': 'CA-2014-105893', 'Order Date': datetime.datetime(2014, 11, 11, 0, 0), 'Ship Date': datetime.datetime(2014, 11, 18, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'PK-19075', 'Customer Name': 'Pete Kriz', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Madison', 'State': 'Wisconsin', 'Postal Code': 53711, 'Region': 'Central', 'Product ID': 'OFF-ST-10004186', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Stur-D-Stor Shelving, Vertical 5-Shelf: 72"H x 36"W x 18 1/2"D', 'Sales': 665.88, 'Quantity': 6, 'Discount': 0.0, 'Profit': 13.3176}
# {'_id': ObjectId('68e63b562e1853074f2a7fc2'), 'Row ID': 18, 'Order ID': 'CA-2014-167164', 'Order Date': datetime.datetime(2014, 5, 13, 0, 0), 'Ship Date': datetime.datetime(2014, 5, 15, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'AG-10270', 'Customer Name': 'Alejandro Grove', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'West Jordan', 'State': 'Utah', 'Postal Code': 84084, 'Region': 'West', 'Product ID': 'OFF-ST-10000107', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Fellowes Super Stor/Drawer', 'Sales': 55.5, 'Quantity': 2, 'Discount': 0.0, 'Profit': 9.99}
# {'_id': ObjectId('68e63b562e1853074f2a7fc3'), 'Row ID': 19, 'Order ID': 'CA-2014-143336', 'Order Date': datetime.datetime(2014, 8, 27, 0, 0), 'Ship Date': datetime.datetime(2014, 9, 1, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'ZD-21925', 'Customer Name': 'Zuschuss Donatelli', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94109, 'Region': 'West', 'Product ID': 'OFF-AR-10003056', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Newell 341', 'Sales': 8.56, 'Quantity': 2, 'Discount': 0.0, 'Profit': 2.4824}
# {'_id': ObjectId('68e63b562e1853074f2a7fc4'), 'Row ID': 20, 'Order ID': 'CA-2014-143336', 'Order Date': datetime.datetime(2014, 8, 27, 0, 0), 'Ship Date': datetime.datetime(2014, 9, 1, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'ZD-21925', 'Customer Name': 'Zuschuss Donatelli', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94109, 'Region': 'West', 'Product ID': 'TEC-PH-10001949', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Cisco SPA 501G IP Phone', 'Sales': 213.48, 'Quantity': 3, 'Discount': 0.2, 'Profit': 16.011}
# {'_id': ObjectId('68e63b562e1853074f2a7fc5'), 'Row ID': 21, 'Order ID': 'CA-2014-143336', 'Order Date': datetime.datetime(2014, 8, 27, 0, 0), 'Ship Date': datetime.datetime(2014, 9, 1, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'ZD-21925', 'Customer Name': 'Zuschuss Donatelli', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94109, 'Region': 'West', 'Product ID': 'OFF-BI-10002215', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Wilson Jones Hanging View Binder, White, 1"', 'Sales': 22.72, 'Quantity': 4, 'Discount': 0.2, 'Profit': 7.384}
# {'_id': ObjectId('68e63b562e1853074f2a7fc6'), 'Row ID': 22, 'Order ID': 'CA-2016-137330', 'Order Date': datetime.datetime(2016, 12, 9, 0, 0), 'Ship Date': datetime.datetime(2016, 12, 13, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'KB-16585', 'Customer Name': 'Ken Black', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Fremont', 'State': 'Nebraska', 'Postal Code': 68025, 'Region': 'Central', 'Product ID': 'OFF-AR-10000246', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Newell 318', 'Sales': 19.46, 'Quantity': 7, 'Discount': 0.0, 'Profit': 5.0596}
# {'_id': ObjectId('68e63b562e1853074f2a7fc7'), 'Row ID': 23, 'Order ID': 'CA-2016-137330', 'Order Date': datetime.datetime(2016, 12, 9, 0, 0), 'Ship Date': datetime.datetime(2016, 12, 13, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'KB-16585', 'Customer Name': 'Ken Black', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Fremont', 'State': 'Nebraska', 'Postal Code': 68025, 'Region': 'Central', 'Product ID': 'OFF-AP-10001492', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': "Acco Six-Outlet Power Strip, 4' Cord Length", 'Sales': 60.34, 'Quantity': 7, 'Discount': 0.0, 'Profit': 15.6884}
# {'_id': ObjectId('68e63b562e1853074f2a7fc8'), 'Row ID': 24, 'Order ID': 'US-2017-156909', 'Order Date': datetime.datetime(2017, 7, 16, 0, 0), 'Ship Date': datetime.datetime(2017, 7, 18, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'SF-20065', 'Customer Name': 'Sandra Flanagan', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'FUR-CH-10002774', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Global Deluxe Stacking Chair, Gray', 'Sales': 71.372, 'Quantity': 2, 'Discount': 0.3, 'Profit': -1.0196}
# {'_id': ObjectId('68e63b562e1853074f2a7fc9'), 'Row ID': 25, 'Order ID': 'CA-2015-106320', 'Order Date': datetime.datetime(2015, 9, 25, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 30, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'EB-13870', 'Customer Name': 'Emily Burns', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Orem', 'State': 'Utah', 'Postal Code': 84057, 'Region': 'West', 'Product ID': 'FUR-TA-10000577', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bretford CR4500 Series Slim Rectangular Table', 'Sales': 1044.63, 'Quantity': 3, 'Discount': 0.0, 'Profit': 240.2649}
# {'_id': ObjectId('68e63b562e1853074f2a7fca'), 'Row ID': 26, 'Order ID': 'CA-2016-121755', 'Order Date': datetime.datetime(2016, 1, 16, 0, 0), 'Ship Date': datetime.datetime(2016, 1, 20, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'EH-13945', 'Customer Name': 'Eric Hoffmann', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90049, 'Region': 'West', 'Product ID': 'OFF-BI-10001634', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Wilson Jones Active Use Binders', 'Sales': 11.648, 'Quantity': 2, 'Discount': 0.2, 'Profit': 4.2224}
# {'_id': ObjectId('68e63b562e1853074f2a7fcb'), 'Row ID': 27, 'Order ID': 'CA-2016-121755', 'Order Date': datetime.datetime(2016, 1, 16, 0, 0), 'Ship Date': datetime.datetime(2016, 1, 20, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'EH-13945', 'Customer Name': 'Eric Hoffmann', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90049, 'Region': 'West', 'Product ID': 'TEC-AC-10003027', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Imation\xa08GB Mini TravelDrive USB 2.0\xa0Flash Drive', 'Sales': 90.57, 'Quantity': 3, 'Discount': 0.0, 'Profit': 11.7741}
# {'_id': ObjectId('68e63b562e1853074f2a7fcc'), 'Row ID': 28, 'Order ID': 'US-2015-150630', 'Order Date': datetime.datetime(2015, 9, 17, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 21, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'FUR-BO-10004834', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish', 'Sales': 3083.43, 'Quantity': 7, 'Discount': 0.5, 'Profit': -1665.0522}
# {'_id': ObjectId('68e63b562e1853074f2a7fcd'), 'Row ID': 29, 'Order ID': 'US-2015-150630', 'Order Date': datetime.datetime(2015, 9, 17, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 21, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'OFF-BI-10000474', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Avery Recycled Flexi-View Covers for Binding Systems', 'Sales': 9.618, 'Quantity': 2, 'Discount': 0.7, 'Profit': -7.0532}
# {'_id': ObjectId('68e63b562e1853074f2a7fce'), 'Row ID': 30, 'Order ID': 'US-2015-150630', 'Order Date': datetime.datetime(2015, 9, 17, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 21, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'FUR-FU-10004848', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Howard Miller 13-3/4" Diameter Brushed Chrome Round Wall Clock', 'Sales': 124.2, 'Quantity': 3, 'Discount': 0.2, 'Profit': 15.525}
# {'_id': ObjectId('68e63b562e1853074f2a7fcf'), 'Row ID': 31, 'Order ID': 'US-2015-150630', 'Order Date': datetime.datetime(2015, 9, 17, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 21, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'OFF-EN-10001509', 'Category': 'Office Supplies', 'Sub-Category': 'Envelopes', 'Product Name': 'Poly String Tie Envelopes', 'Sales': 3.264, 'Quantity': 2, 'Discount': 0.2, 'Profit': 1.1016}
# {'_id': ObjectId('68e63b562e1853074f2a7fd0'), 'Row ID': 32, 'Order ID': 'US-2015-150630', 'Order Date': datetime.datetime(2015, 9, 17, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 21, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'OFF-AR-10004042', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'BOSTON Model 1800 Electric Pencil Sharpeners, Putty/Woodgrain', 'Sales': 86.304, 'Quantity': 6, 'Discount': 0.2, 'Profit': 9.7092}
# {'_id': ObjectId('68e63b562e1853074f2a7fd1'), 'Row ID': 33, 'Order ID': 'US-2015-150630', 'Order Date': datetime.datetime(2015, 9, 17, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 21, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'OFF-BI-10001525', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Acco Pressboard Covers with Storage Hooks, 14 7/8" x 11", Executive Red', 'Sales': 6.858, 'Quantity': 6, 'Discount': 0.7, 'Profit': -5.715}
# {'_id': ObjectId('68e63b562e1853074f2a7fd2'), 'Row ID': 34, 'Order ID': 'US-2015-150630', 'Order Date': datetime.datetime(2015, 9, 17, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 21, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'OFF-AR-10001683', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Lumber Crayons', 'Sales': 15.76, 'Quantity': 2, 'Discount': 0.2, 'Profit': 3.546}
# {'_id': ObjectId('68e63b562e1853074f2a7fd3'), 'Row ID': 35, 'Order ID': 'CA-2017-107727', 'Order Date': datetime.datetime(2017, 10, 19, 0, 0), 'Ship Date': datetime.datetime(2017, 10, 23, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'MA-17560', 'Customer Name': 'Matt Abelman', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77095, 'Region': 'Central', 'Product ID': 'OFF-PA-10000249', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Easy-staple paper', 'Sales': 29.472, 'Quantity': 3, 'Discount': 0.2, 'Profit': 9.9468}
# {'_id': ObjectId('68e63b562e1853074f2a7fd4'), 'Row ID': 36, 'Order ID': 'CA-2016-117590', 'Order Date': datetime.datetime(2016, 12, 8, 0, 0), 'Ship Date': datetime.datetime(2016, 12, 10, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'GH-14485', 'Customer Name': 'Gene Hale', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Richardson', 'State': 'Texas', 'Postal Code': 75080, 'Region': 'Central', 'Product ID': 'TEC-PH-10004977', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'GE 30524EE4', 'Sales': 1097.544, 'Quantity': 7, 'Discount': 0.2, 'Profit': 123.4737}
# {'_id': ObjectId('68e63b562e1853074f2a7fd5'), 'Row ID': 37, 'Order ID': 'CA-2016-117590', 'Order Date': datetime.datetime(2016, 12, 8, 0, 0), 'Ship Date': datetime.datetime(2016, 12, 10, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'GH-14485', 'Customer Name': 'Gene Hale', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Richardson', 'State': 'Texas', 'Postal Code': 75080, 'Region': 'Central', 'Product ID': 'FUR-FU-10003664', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': "Electrix Architect's Clamp-On Swing Arm Lamp, Black", 'Sales': 190.92, 'Quantity': 5, 'Discount': 0.6, 'Profit': -147.963}
# {'_id': ObjectId('68e63b562e1853074f2a7fd6'), 'Row ID': 38, 'Order ID': 'CA-2015-117415', 'Order Date': datetime.datetime(2015, 12, 27, 0, 0), 'Ship Date': datetime.datetime(2015, 12, 31, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'SN-20710', 'Customer Name': 'Steve Nguyen', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'OFF-EN-10002986', 'Category': 'Office Supplies', 'Sub-Category': 'Envelopes', 'Product Name': '#10-4 1/8" x 9 1/2" Premium Diagonal Seam Envelopes', 'Sales': 113.328, 'Quantity': 9, 'Discount': 0.2, 'Profit': 35.415}
# {'_id': ObjectId('68e63b562e1853074f2a7fd7'), 'Row ID': 39, 'Order ID': 'CA-2015-117415', 'Order Date': datetime.datetime(2015, 12, 27, 0, 0), 'Ship Date': datetime.datetime(2015, 12, 31, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'SN-20710', 'Customer Name': 'Steve Nguyen', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'FUR-BO-10002545', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Atlantic Metals Mobile 3-Shelf Bookcases, Custom Colors', 'Sales': 532.3992, 'Quantity': 3, 'Discount': 0.32, 'Profit': -46.9764}
# {'_id': ObjectId('68e63b562e1853074f2a7fd8'), 'Row ID': 40, 'Order ID': 'CA-2015-117415', 'Order Date': datetime.datetime(2015, 12, 27, 0, 0), 'Ship Date': datetime.datetime(2015, 12, 31, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'SN-20710', 'Customer Name': 'Steve Nguyen', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'FUR-CH-10004218', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': "Global Fabric Manager's Chair, Dark Gray", 'Sales': 212.058, 'Quantity': 3, 'Discount': 0.3, 'Profit': -15.147}
# {'_id': ObjectId('68e63b562e1853074f2a7fd9'), 'Row ID': 41, 'Order ID': 'CA-2015-117415', 'Order Date': datetime.datetime(2015, 12, 27, 0, 0), 'Ship Date': datetime.datetime(2015, 12, 31, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'SN-20710', 'Customer Name': 'Steve Nguyen', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'TEC-PH-10000486', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Plantronics HL10 Handset Lifter', 'Sales': 371.168, 'Quantity': 4, 'Discount': 0.2, 'Profit': 41.7564}
# {'_id': ObjectId('68e63b562e1853074f2a7fda'), 'Row ID': 42, 'Order ID': 'CA-2017-120999', 'Order Date': datetime.datetime(2017, 9, 10, 0, 0), 'Ship Date': datetime.datetime(2017, 9, 15, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'LC-16930', 'Customer Name': 'Linda Cazamias', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Naperville', 'State': 'Illinois', 'Postal Code': 60540, 'Region': 'Central', 'Product ID': 'TEC-PH-10004093', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Panasonic Kx-TS550', 'Sales': 147.168, 'Quantity': 4, 'Discount': 0.2, 'Profit': 16.5564}
# {'_id': ObjectId('68e63b562e1853074f2a7fdb'), 'Row ID': 43, 'Order ID': 'CA-2016-101343', 'Order Date': datetime.datetime(2016, 7, 17, 0, 0), 'Ship Date': datetime.datetime(2016, 7, 22, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'RA-19885', 'Customer Name': 'Ruben Ausman', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90049, 'Region': 'West', 'Product ID': 'OFF-ST-10003479', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Eldon Base for stackable storage shelf, platinum', 'Sales': 77.88, 'Quantity': 2, 'Discount': 0.0, 'Profit': 3.894}
# {'_id': ObjectId('68e63b562e1853074f2a7fdc'), 'Row ID': 44, 'Order ID': 'CA-2017-139619', 'Order Date': datetime.datetime(2017, 9, 19, 0, 0), 'Ship Date': datetime.datetime(2017, 9, 23, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'ES-14080', 'Customer Name': 'Erin Smith', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Melbourne', 'State': 'Florida', 'Postal Code': 32935, 'Region': 'South', 'Product ID': 'OFF-ST-10003282', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Advantus 10-Drawer Portable Organizer, Chrome Metal Frame, Smoke Drawers', 'Sales': 95.616, 'Quantity': 2, 'Discount': 0.2, 'Profit': 9.5616}
# {'_id': ObjectId('68e63b562e1853074f2a7fdd'), 'Row ID': 45, 'Order ID': 'CA-2016-118255', 'Order Date': datetime.datetime(2016, 3, 11, 0, 0), 'Ship Date': datetime.datetime(2016, 3, 13, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'ON-18715', 'Customer Name': 'Odella Nelson', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Eagan', 'State': 'Minnesota', 'Postal Code': 55122, 'Region': 'Central', 'Product ID': 'TEC-AC-10000171', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Verbatim 25 GB 6x Blu-ray Single Layer Recordable Disc, 25/Pack', 'Sales': 45.98, 'Quantity': 2, 'Discount': 0.0, 'Profit': 19.7714}
# {'_id': ObjectId('68e63b562e1853074f2a7fde'), 'Row ID': 46, 'Order ID': 'CA-2016-118255', 'Order Date': datetime.datetime(2016, 3, 11, 0, 0), 'Ship Date': datetime.datetime(2016, 3, 13, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'ON-18715', 'Customer Name': 'Odella Nelson', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Eagan', 'State': 'Minnesota', 'Postal Code': 55122, 'Region': 'Central', 'Product ID': 'OFF-BI-10003291', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Wilson Jones Leather-Like Binders with DublLock Round Rings', 'Sales': 17.46, 'Quantity': 2, 'Discount': 0.0, 'Profit': 8.2062}
# {'_id': ObjectId('68e63b562e1853074f2a7fdf'), 'Row ID': 47, 'Order ID': 'CA-2014-146703', 'Order Date': datetime.datetime(2014, 10, 20, 0, 0), 'Ship Date': datetime.datetime(2014, 10, 25, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'PO-18865', 'Customer Name': "Patrick O'Donnell", 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Westland', 'State': 'Michigan', 'Postal Code': 48185, 'Region': 'Central', 'Product ID': 'OFF-ST-10001713', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Gould Plastics 9-Pocket Panel Bin, 18-3/8w x 5-1/4d x 20-1/2h, Black', 'Sales': 211.96, 'Quantity': 4, 'Discount': 0.0, 'Profit': 8.4784}
# {'_id': ObjectId('68e63b562e1853074f2a7fe0'), 'Row ID': 48, 'Order ID': 'CA-2016-169194', 'Order Date': datetime.datetime(2016, 6, 20, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 25, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'LH-16900', 'Customer Name': 'Lena Hernandez', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Dover', 'State': 'Delaware', 'Postal Code': 19901, 'Region': 'East', 'Product ID': 'TEC-AC-10002167', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Imation\xa08gb Micro Traveldrive Usb 2.0\xa0Flash Drive', 'Sales': 45.0, 'Quantity': 3, 'Discount': 0.0, 'Profit': 4.95}
# {'_id': ObjectId('68e63b562e1853074f2a7fe1'), 'Row ID': 49, 'Order ID': 'CA-2016-169194', 'Order Date': datetime.datetime(2016, 6, 20, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 25, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'LH-16900', 'Customer Name': 'Lena Hernandez', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Dover', 'State': 'Delaware', 'Postal Code': 19901, 'Region': 'East', 'Product ID': 'TEC-PH-10003988', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'LF Elite 3D Dazzle Designer Hard Case Cover, Lf Stylus Pen and Wiper For Apple Iphone 5c Mini Lite', 'Sales': 21.8, 'Quantity': 2, 'Discount': 0.0, 'Profit': 6.104}
# {'_id': ObjectId('68e63b562e1853074f2a7fe2'), 'Row ID': 50, 'Order ID': 'CA-2015-115742', 'Order Date': datetime.datetime(2015, 4, 18, 0, 0), 'Ship Date': datetime.datetime(2015, 4, 22, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'DP-13000', 'Customer Name': 'Darren Powers', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'New Albany', 'State': 'Indiana', 'Postal Code': 47150, 'Region': 'Central', 'Product ID': 'OFF-BI-10004410', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'C-Line Peel & Stick Add-On Filing Pockets, 8-3/4 x 5-1/8, 10/Pack', 'Sales': 38.22, 'Quantity': 6, 'Discount': 0.0, 'Profit': 17.9634}
# {'_id': ObjectId('68e63b562e1853074f2a7fe3'), 'Row ID': 51, 'Order ID': 'CA-2015-115742', 'Order Date': datetime.datetime(2015, 4, 18, 0, 0), 'Ship Date': datetime.datetime(2015, 4, 22, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'DP-13000', 'Customer Name': 'Darren Powers', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'New Albany', 'State': 'Indiana', 'Postal Code': 47150, 'Region': 'Central', 'Product ID': 'OFF-LA-10002762', 'Category': 'Office Supplies', 'Sub-Category': 'Labels', 'Product Name': 'Avery 485', 'Sales': 75.18, 'Quantity': 6, 'Discount': 0.0, 'Profit': 35.3346}
# {'_id': ObjectId('68e63b562e1853074f2a7fe4'), 'Row ID': 52, 'Order ID': 'CA-2015-115742', 'Order Date': datetime.datetime(2015, 4, 18, 0, 0), 'Ship Date': datetime.datetime(2015, 4, 22, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'DP-13000', 'Customer Name': 'Darren Powers', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'New Albany', 'State': 'Indiana', 'Postal Code': 47150, 'Region': 'Central', 'Product ID': 'FUR-FU-10001706', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Longer-Life Soft White Bulbs', 'Sales': 6.16, 'Quantity': 2, 'Discount': 0.0, 'Profit': 2.9568}
# {'_id': ObjectId('68e63b562e1853074f2a7fe5'), 'Row ID': 53, 'Order ID': 'CA-2015-115742', 'Order Date': datetime.datetime(2015, 4, 18, 0, 0), 'Ship Date': datetime.datetime(2015, 4, 22, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'DP-13000', 'Customer Name': 'Darren Powers', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'New Albany', 'State': 'Indiana', 'Postal Code': 47150, 'Region': 'Central', 'Product ID': 'FUR-CH-10003061', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Global Leather Task Chair, Black', 'Sales': 89.99, 'Quantity': 1, 'Discount': 0.0, 'Profit': 17.0981}
# {'_id': ObjectId('68e63b562e1853074f2a7fe6'), 'Row ID': 54, 'Order ID': 'CA-2016-105816', 'Order Date': datetime.datetime(2016, 12, 11, 0, 0), 'Ship Date': datetime.datetime(2016, 12, 17, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JM-15265', 'Customer Name': 'Janet Molinari', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10024, 'Region': 'East', 'Product ID': 'OFF-FA-10000304', 'Category': 'Office Supplies', 'Sub-Category': 'Fasteners', 'Product Name': 'Advantus Push Pins', 'Sales': 15.26, 'Quantity': 7, 'Discount': 0.0, 'Profit': 6.2566}
# {'_id': ObjectId('68e63b562e1853074f2a7fe7'), 'Row ID': 55, 'Order ID': 'CA-2016-105816', 'Order Date': datetime.datetime(2016, 12, 11, 0, 0), 'Ship Date': datetime.datetime(2016, 12, 17, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JM-15265', 'Customer Name': 'Janet Molinari', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10024, 'Region': 'East', 'Product ID': 'TEC-PH-10002447', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'AT&T CL83451 4-Handset Telephone', 'Sales': 1029.95, 'Quantity': 5, 'Discount': 0.0, 'Profit': 298.6855}
# {'_id': ObjectId('68e63b562e1853074f2a7fe8'), 'Row ID': 56, 'Order ID': 'CA-2016-111682', 'Order Date': datetime.datetime(2016, 6, 17, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 18, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'TB-21055', 'Customer Name': 'Ted Butterfield', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Troy', 'State': 'New York', 'Postal Code': 12180, 'Region': 'East', 'Product ID': 'OFF-ST-10000604', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Home/Office Personal File Carts', 'Sales': 208.56, 'Quantity': 6, 'Discount': 0.0, 'Profit': 52.14}
# {'_id': ObjectId('68e63b562e1853074f2a7fe9'), 'Row ID': 57, 'Order ID': 'CA-2016-111682', 'Order Date': datetime.datetime(2016, 6, 17, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 18, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'TB-21055', 'Customer Name': 'Ted Butterfield', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Troy', 'State': 'New York', 'Postal Code': 12180, 'Region': 'East', 'Product ID': 'OFF-PA-10001569', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 232', 'Sales': 32.4, 'Quantity': 5, 'Discount': 0.0, 'Profit': 15.552}
# {'_id': ObjectId('68e63b562e1853074f2a7fea'), 'Row ID': 58, 'Order ID': 'CA-2016-111682', 'Order Date': datetime.datetime(2016, 6, 17, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 18, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'TB-21055', 'Customer Name': 'Ted Butterfield', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Troy', 'State': 'New York', 'Postal Code': 12180, 'Region': 'East', 'Product ID': 'FUR-CH-10003968', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Novimex Turbo Task Chair', 'Sales': 319.41, 'Quantity': 5, 'Discount': 0.1, 'Profit': 7.098}
# {'_id': ObjectId('68e63b562e1853074f2a7feb'), 'Row ID': 59, 'Order ID': 'CA-2016-111682', 'Order Date': datetime.datetime(2016, 6, 17, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 18, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'TB-21055', 'Customer Name': 'Ted Butterfield', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Troy', 'State': 'New York', 'Postal Code': 12180, 'Region': 'East', 'Product ID': 'OFF-PA-10000587', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Array Parchment Paper, Assorted Colors', 'Sales': 14.56, 'Quantity': 2, 'Discount': 0.0, 'Profit': 6.9888}
# {'_id': ObjectId('68e63b562e1853074f2a7fec'), 'Row ID': 60, 'Order ID': 'CA-2016-111682', 'Order Date': datetime.datetime(2016, 6, 17, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 18, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'TB-21055', 'Customer Name': 'Ted Butterfield', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Troy', 'State': 'New York', 'Postal Code': 12180, 'Region': 'East', 'Product ID': 'TEC-AC-10002167', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Imation\xa08gb Micro Traveldrive Usb 2.0\xa0Flash Drive', 'Sales': 30.0, 'Quantity': 2, 'Discount': 0.0, 'Profit': 3.3}
# {'_id': ObjectId('68e63b562e1853074f2a7fed'), 'Row ID': 61, 'Order ID': 'CA-2016-111682', 'Order Date': datetime.datetime(2016, 6, 17, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 18, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'TB-21055', 'Customer Name': 'Ted Butterfield', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Troy', 'State': 'New York', 'Postal Code': 12180, 'Region': 'East', 'Product ID': 'OFF-BI-10001460', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Plastic Binding Combs', 'Sales': 48.48, 'Quantity': 4, 'Discount': 0.2, 'Profit': 16.362}
# {'_id': ObjectId('68e63b562e1853074f2a7fee'), 'Row ID': 62, 'Order ID': 'CA-2016-111682', 'Order Date': datetime.datetime(2016, 6, 17, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 18, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'TB-21055', 'Customer Name': 'Ted Butterfield', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Troy', 'State': 'New York', 'Postal Code': 12180, 'Region': 'East', 'Product ID': 'OFF-AR-10001868', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Prang Dustless Chalk Sticks', 'Sales': 1.68, 'Quantity': 1, 'Discount': 0.0, 'Profit': 0.84}
# {'_id': ObjectId('68e63b562e1853074f2a7fef'), 'Row ID': 63, 'Order ID': 'CA-2015-135545', 'Order Date': datetime.datetime(2015, 11, 24, 0, 0), 'Ship Date': datetime.datetime(2015, 11, 30, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'KM-16720', 'Customer Name': 'Kunst Miller', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'TEC-AC-10004633', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Verbatim 25 GB 6x Blu-ray Single Layer Recordable Disc, 3/Pack', 'Sales': 13.98, 'Quantity': 2, 'Discount': 0.0, 'Profit': 6.1512}
# {'_id': ObjectId('68e63b562e1853074f2a7ff0'), 'Row ID': 64, 'Order ID': 'CA-2015-135545', 'Order Date': datetime.datetime(2015, 11, 24, 0, 0), 'Ship Date': datetime.datetime(2015, 11, 30, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'KM-16720', 'Customer Name': 'Kunst Miller', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'OFF-BI-10001078', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Acco PRESSTEX Data Binder with Storage Hooks, Dark Blue, 14 7/8" X 11"', 'Sales': 25.824, 'Quantity': 6, 'Discount': 0.2, 'Profit': 9.3612}
# {'_id': ObjectId('68e63b562e1853074f2a7ff1'), 'Row ID': 65, 'Order ID': 'CA-2015-135545', 'Order Date': datetime.datetime(2015, 11, 24, 0, 0), 'Ship Date': datetime.datetime(2015, 11, 30, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'KM-16720', 'Customer Name': 'Kunst Miller', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'OFF-PA-10003892', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 1943', 'Sales': 146.73, 'Quantity': 3, 'Discount': 0.0, 'Profit': 68.9631}
# {'_id': ObjectId('68e63b562e1853074f2a7ff2'), 'Row ID': 66, 'Order ID': 'CA-2015-135545', 'Order Date': datetime.datetime(2015, 11, 24, 0, 0), 'Ship Date': datetime.datetime(2015, 11, 30, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'KM-16720', 'Customer Name': 'Kunst Miller', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'FUR-FU-10000397', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Luxo Economy Swing Arm Lamp', 'Sales': 79.76, 'Quantity': 4, 'Discount': 0.0, 'Profit': 22.3328}
# {'_id': ObjectId('68e63b562e1853074f2a7ff3'), 'Row ID': 67, 'Order ID': 'US-2015-164175', 'Order Date': datetime.datetime(2015, 4, 30, 0, 0), 'Ship Date': datetime.datetime(2015, 5, 5, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'PS-18970', 'Customer Name': 'Paul Stevenson', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Chicago', 'State': 'Illinois', 'Postal Code': 60610, 'Region': 'Central', 'Product ID': 'FUR-CH-10001146', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': "Global Value Mid-Back Manager's Chair, Gray", 'Sales': 213.115, 'Quantity': 5, 'Discount': 0.3, 'Profit': -15.2225}
# {'_id': ObjectId('68e63b562e1853074f2a7ff4'), 'Row ID': 68, 'Order ID': 'CA-2014-106376', 'Order Date': datetime.datetime(2014, 12, 5, 0, 0), 'Ship Date': datetime.datetime(2014, 12, 10, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BS-11590', 'Customer Name': 'Brendan Sweed', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Gilbert', 'State': 'Arizona', 'Postal Code': 85234, 'Region': 'West', 'Product ID': 'OFF-AR-10002671', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Hunt BOSTON Model 1606 High-Volume Electric Pencil Sharpener, Beige', 'Sales': 1113.024, 'Quantity': 8, 'Discount': 0.2, 'Profit': 111.3024}
# {'_id': ObjectId('68e63b562e1853074f2a7ff5'), 'Row ID': 69, 'Order ID': 'CA-2014-106376', 'Order Date': datetime.datetime(2014, 12, 5, 0, 0), 'Ship Date': datetime.datetime(2014, 12, 10, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BS-11590', 'Customer Name': 'Brendan Sweed', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Gilbert', 'State': 'Arizona', 'Postal Code': 85234, 'Region': 'West', 'Product ID': 'TEC-PH-10002726', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'netTALK DUO VoIP Telephone Service', 'Sales': 167.968, 'Quantity': 4, 'Discount': 0.2, 'Profit': 62.988}
# {'_id': ObjectId('68e63b562e1853074f2a7ff6'), 'Row ID': 70, 'Order ID': 'CA-2016-119823', 'Order Date': datetime.datetime(2016, 6, 4, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 6, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'KD-16270', 'Customer Name': 'Karen Daniels', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Springfield', 'State': 'Virginia', 'Postal Code': 22153, 'Region': 'South', 'Product ID': 'OFF-PA-10000482', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Snap-A-Way Black Print Carbonless Ruled Speed Letter, Triplicate', 'Sales': 75.88, 'Quantity': 2, 'Discount': 0.0, 'Profit': 35.6636}
# {'_id': ObjectId('68e63b562e1853074f2a7ff7'), 'Row ID': 71, 'Order ID': 'CA-2016-106075', 'Order Date': datetime.datetime(2016, 9, 18, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 23, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'HM-14980', 'Customer Name': 'Henry MacAllister', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10009, 'Region': 'East', 'Product ID': 'OFF-BI-10004654', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Avery Binding System Hidden Tab Executive Style Index Sets', 'Sales': 4.616, 'Quantity': 1, 'Discount': 0.2, 'Profit': 1.731}
# {'_id': ObjectId('68e63b562e1853074f2a7ff8'), 'Row ID': 72, 'Order ID': 'CA-2017-114440', 'Order Date': datetime.datetime(2017, 9, 14, 0, 0), 'Ship Date': datetime.datetime(2017, 9, 17, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Jackson', 'State': 'Michigan', 'Postal Code': 49201, 'Region': 'Central', 'Product ID': 'OFF-PA-10004675', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Telephone Message Books with Fax/Mobile Section, 5 1/2" x 3 3/16"', 'Sales': 19.05, 'Quantity': 3, 'Discount': 0.0, 'Profit': 8.763}
# {'_id': ObjectId('68e63b562e1853074f2a7ff9'), 'Row ID': 73, 'Order ID': 'US-2015-134026', 'Order Date': datetime.datetime(2015, 4, 26, 0, 0), 'Ship Date': datetime.datetime(2015, 5, 2, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JE-15745', 'Customer Name': 'Joel Eaton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Memphis', 'State': 'Tennessee', 'Postal Code': 38109, 'Region': 'South', 'Product ID': 'FUR-CH-10000513', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': "High-Back Leather Manager's Chair", 'Sales': 831.936, 'Quantity': 8, 'Discount': 0.2, 'Profit': -114.3912}
# {'_id': ObjectId('68e63b562e1853074f2a7ffa'), 'Row ID': 74, 'Order ID': 'US-2015-134026', 'Order Date': datetime.datetime(2015, 4, 26, 0, 0), 'Ship Date': datetime.datetime(2015, 5, 2, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JE-15745', 'Customer Name': 'Joel Eaton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Memphis', 'State': 'Tennessee', 'Postal Code': 38109, 'Region': 'South', 'Product ID': 'FUR-FU-10003708', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Tenex Traditional Chairmats for Medium Pile Carpet, Standard Lip, 36" x 48"', 'Sales': 97.04, 'Quantity': 2, 'Discount': 0.2, 'Profit': 1.213}
# {'_id': ObjectId('68e63b562e1853074f2a7ffb'), 'Row ID': 75, 'Order ID': 'US-2015-134026', 'Order Date': datetime.datetime(2015, 4, 26, 0, 0), 'Ship Date': datetime.datetime(2015, 5, 2, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JE-15745', 'Customer Name': 'Joel Eaton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Memphis', 'State': 'Tennessee', 'Postal Code': 38109, 'Region': 'South', 'Product ID': 'OFF-ST-10004123', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Safco Industrial Wire Shelving System', 'Sales': 72.784, 'Quantity': 1, 'Discount': 0.2, 'Profit': -18.196}
# {'_id': ObjectId('68e63b562e1853074f2a7ffc'), 'Row ID': 76, 'Order ID': 'US-2017-118038', 'Order Date': datetime.datetime(2017, 12, 9, 0, 0), 'Ship Date': datetime.datetime(2017, 12, 11, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'KB-16600', 'Customer Name': 'Ken Brennan', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'OFF-BI-10004182', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Economy Binders', 'Sales': 1.248, 'Quantity': 3, 'Discount': 0.8, 'Profit': -1.9344}
# {'_id': ObjectId('68e63b562e1853074f2a7ffd'), 'Row ID': 77, 'Order ID': 'US-2017-118038', 'Order Date': datetime.datetime(2017, 12, 9, 0, 0), 'Ship Date': datetime.datetime(2017, 12, 11, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'KB-16600', 'Customer Name': 'Ken Brennan', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'FUR-FU-10000260', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': '6" Cubicle Wall Clock, Black', 'Sales': 9.708, 'Quantity': 3, 'Discount': 0.6, 'Profit': -5.8248}
# {'_id': ObjectId('68e63b562e1853074f2a7ffe'), 'Row ID': 78, 'Order ID': 'US-2017-118038', 'Order Date': datetime.datetime(2017, 12, 9, 0, 0), 'Ship Date': datetime.datetime(2017, 12, 11, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'KB-16600', 'Customer Name': 'Ken Brennan', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'OFF-ST-10000615', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'SimpliFile Personal File, Black Granite, 15w x 6-15/16d x 11-1/4h', 'Sales': 27.24, 'Quantity': 3, 'Discount': 0.2, 'Profit': 2.724}
# {'_id': ObjectId('68e63b562e1853074f2a7fff'), 'Row ID': 79, 'Order ID': 'US-2014-147606', 'Order Date': datetime.datetime(2014, 11, 26, 0, 0), 'Ship Date': datetime.datetime(2014, 12, 1, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'JE-15745', 'Customer Name': 'Joel Eaton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77070, 'Region': 'Central', 'Product ID': 'FUR-FU-10003194', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Eldon Expressions Desk Accessory, Wood Pencil Holder, Oak', 'Sales': 19.3, 'Quantity': 5, 'Discount': 0.6, 'Profit': -14.475}
# {'_id': ObjectId('68e63b562e1853074f2a8000'), 'Row ID': 80, 'Order ID': 'CA-2016-127208', 'Order Date': datetime.datetime(2016, 6, 12, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 15, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'SC-20770', 'Customer Name': 'Stewart Carmichael', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Decatur', 'State': 'Alabama', 'Postal Code': 35601, 'Region': 'South', 'Product ID': 'OFF-AP-10002118', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': '1.7 Cubic Foot Compact "Cube" Office Refrigerators', 'Sales': 208.16, 'Quantity': 1, 'Discount': 0.0, 'Profit': 56.2032}
# {'_id': ObjectId('68e63b562e1853074f2a8001'), 'Row ID': 81, 'Order ID': 'CA-2016-127208', 'Order Date': datetime.datetime(2016, 6, 12, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 15, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'SC-20770', 'Customer Name': 'Stewart Carmichael', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Decatur', 'State': 'Alabama', 'Postal Code': 35601, 'Region': 'South', 'Product ID': 'OFF-BI-10002309', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Avery Heavy-Duty EZD  Binder With Locking Rings', 'Sales': 16.74, 'Quantity': 3, 'Discount': 0.0, 'Profit': 8.0352}
# {'_id': ObjectId('68e63b562e1853074f2a8002'), 'Row ID': 82, 'Order ID': 'CA-2014-139451', 'Order Date': datetime.datetime(2014, 10, 12, 0, 0), 'Ship Date': datetime.datetime(2014, 10, 16, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'DN-13690', 'Customer Name': 'Duane Noonan', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94122, 'Region': 'West', 'Product ID': 'OFF-AR-10002053', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Premium Writing Pencils, Soft, #2 by Central Association for the Blind', 'Sales': 14.9, 'Quantity': 5, 'Discount': 0.0, 'Profit': 4.172}
# {'_id': ObjectId('68e63b562e1853074f2a8003'), 'Row ID': 83, 'Order ID': 'CA-2014-139451', 'Order Date': datetime.datetime(2014, 10, 12, 0, 0), 'Ship Date': datetime.datetime(2014, 10, 16, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'DN-13690', 'Customer Name': 'Duane Noonan', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94122, 'Region': 'West', 'Product ID': 'OFF-ST-10002370', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Sortfiler Multipurpose Personal File Organizer, Black', 'Sales': 21.39, 'Quantity': 1, 'Discount': 0.0, 'Profit': 6.2031}
# {'_id': ObjectId('68e63b562e1853074f2a8004'), 'Row ID': 84, 'Order ID': 'CA-2015-149734', 'Order Date': datetime.datetime(2015, 9, 3, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 8, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JC-16105', 'Customer Name': 'Julie Creighton', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Durham', 'State': 'North Carolina', 'Postal Code': 27707, 'Region': 'South', 'Product ID': 'OFF-EN-10000927', 'Category': 'Office Supplies', 'Sub-Category': 'Envelopes', 'Product Name': "Jet-Pak Recycled Peel 'N' Seal Padded Mailers", 'Sales': 200.984, 'Quantity': 7, 'Discount': 0.2, 'Profit': 62.8075}
# {'_id': ObjectId('68e63b562e1853074f2a8005'), 'Row ID': 85, 'Order ID': 'US-2017-119662', 'Order Date': datetime.datetime(2017, 11, 13, 0, 0), 'Ship Date': datetime.datetime(2017, 11, 16, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'CS-12400', 'Customer Name': 'Christopher Schild', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Chicago', 'State': 'Illinois', 'Postal Code': 60623, 'Region': 'Central', 'Product ID': 'OFF-ST-10003656', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Safco Industrial Wire Shelving', 'Sales': 230.376, 'Quantity': 3, 'Discount': 0.2, 'Profit': -48.9549}
# {'_id': ObjectId('68e63b562e1853074f2a8006'), 'Row ID': 86, 'Order ID': 'CA-2017-140088', 'Order Date': datetime.datetime(2017, 5, 28, 0, 0), 'Ship Date': datetime.datetime(2017, 5, 30, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'PO-18865', 'Customer Name': "Patrick O'Donnell", 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Columbia', 'State': 'South Carolina', 'Postal Code': 29203, 'Region': 'South', 'Product ID': 'FUR-CH-10000863', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Novimex Swivel Fabric Task Chair', 'Sales': 301.96, 'Quantity': 2, 'Discount': 0.0, 'Profit': 33.2156}
# {'_id': ObjectId('68e63b562e1853074f2a8007'), 'Row ID': 87, 'Order ID': 'CA-2017-155558', 'Order Date': datetime.datetime(2017, 10, 26, 0, 0), 'Ship Date': datetime.datetime(2017, 11, 2, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'PG-18895', 'Customer Name': 'Paul Gonzalez', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Rochester', 'State': 'Minnesota', 'Postal Code': 55901, 'Region': 'Central', 'Product ID': 'TEC-AC-10001998', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Logitech\xa0LS21 Speaker System - PC Multimedia - 2.1-CH - Wired', 'Sales': 19.99, 'Quantity': 1, 'Discount': 0.0, 'Profit': 6.7966}
# {'_id': ObjectId('68e63b562e1853074f2a8008'), 'Row ID': 88, 'Order ID': 'CA-2017-155558', 'Order Date': datetime.datetime(2017, 10, 26, 0, 0), 'Ship Date': datetime.datetime(2017, 11, 2, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'PG-18895', 'Customer Name': 'Paul Gonzalez', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Rochester', 'State': 'Minnesota', 'Postal Code': 55901, 'Region': 'Central', 'Product ID': 'OFF-LA-10000134', 'Category': 'Office Supplies', 'Sub-Category': 'Labels', 'Product Name': 'Avery 511', 'Sales': 6.16, 'Quantity': 2, 'Discount': 0.0, 'Profit': 2.9568}
# {'_id': ObjectId('68e63b562e1853074f2a8009'), 'Row ID': 89, 'Order ID': 'CA-2016-159695', 'Order Date': datetime.datetime(2016, 4, 5, 0, 0), 'Ship Date': datetime.datetime(2016, 4, 10, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'GM-14455', 'Customer Name': 'Gary Mitchum', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77095, 'Region': 'Central', 'Product ID': 'OFF-ST-10003442', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Eldon Portable Mobile Manager', 'Sales': 158.368, 'Quantity': 7, 'Discount': 0.2, 'Profit': 13.8572}
# {'_id': ObjectId('68e63b562e1853074f2a800a'), 'Row ID': 90, 'Order ID': 'CA-2016-109806', 'Order Date': datetime.datetime(2016, 9, 17, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 22, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JS-15685', 'Customer Name': 'Jim Sink', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90036, 'Region': 'West', 'Product ID': 'OFF-AR-10004930', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Turquoise Lead Holder with Pocket Clip', 'Sales': 20.1, 'Quantity': 3, 'Discount': 0.0, 'Profit': 6.633}
# {'_id': ObjectId('68e63b562e1853074f2a800b'), 'Row ID': 91, 'Order ID': 'CA-2016-109806', 'Order Date': datetime.datetime(2016, 9, 17, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 22, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JS-15685', 'Customer Name': 'Jim Sink', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90036, 'Region': 'West', 'Product ID': 'TEC-PH-10004093', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Panasonic Kx-TS550', 'Sales': 73.584, 'Quantity': 2, 'Discount': 0.2, 'Profit': 8.2782}
# {'_id': ObjectId('68e63b562e1853074f2a800c'), 'Row ID': 92, 'Order ID': 'CA-2016-109806', 'Order Date': datetime.datetime(2016, 9, 17, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 22, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JS-15685', 'Customer Name': 'Jim Sink', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90036, 'Region': 'West', 'Product ID': 'OFF-PA-10000304', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 1995', 'Sales': 6.48, 'Quantity': 1, 'Discount': 0.0, 'Profit': 3.1104}
# {'_id': ObjectId('68e63b562e1853074f2a800d'), 'Row ID': 93, 'Order ID': 'CA-2015-149587', 'Order Date': datetime.datetime(2015, 1, 31, 0, 0), 'Ship Date': datetime.datetime(2015, 2, 5, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'KB-16315', 'Customer Name': 'Karl Braun', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Minneapolis', 'State': 'Minnesota', 'Postal Code': 55407, 'Region': 'Central', 'Product ID': 'OFF-PA-10003177', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 1999', 'Sales': 12.96, 'Quantity': 2, 'Discount': 0.0, 'Profit': 6.2208}
# {'_id': ObjectId('68e63b562e1853074f2a800e'), 'Row ID': 94, 'Order ID': 'CA-2015-149587', 'Order Date': datetime.datetime(2015, 1, 31, 0, 0), 'Ship Date': datetime.datetime(2015, 2, 5, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'KB-16315', 'Customer Name': 'Karl Braun', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Minneapolis', 'State': 'Minnesota', 'Postal Code': 55407, 'Region': 'Central', 'Product ID': 'FUR-FU-10003799', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Seth Thomas 13 1/2" Wall Clock', 'Sales': 53.34, 'Quantity': 3, 'Discount': 0.0, 'Profit': 16.5354}
# {'_id': ObjectId('68e63b562e1853074f2a800f'), 'Row ID': 95, 'Order ID': 'CA-2015-149587', 'Order Date': datetime.datetime(2015, 1, 31, 0, 0), 'Ship Date': datetime.datetime(2015, 2, 5, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'KB-16315', 'Customer Name': 'Karl Braun', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Minneapolis', 'State': 'Minnesota', 'Postal Code': 55407, 'Region': 'Central', 'Product ID': 'OFF-BI-10002852', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Ibico Standard Transparent Covers', 'Sales': 32.96, 'Quantity': 2, 'Discount': 0.0, 'Profit': 16.1504}
# {'_id': ObjectId('68e63b562e1853074f2a8010'), 'Row ID': 96, 'Order ID': 'US-2017-109484', 'Order Date': datetime.datetime(2017, 11, 6, 0, 0), 'Ship Date': datetime.datetime(2017, 11, 12, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'RB-19705', 'Customer Name': 'Roger Barcio', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Portland', 'State': 'Oregon', 'Postal Code': 97206, 'Region': 'West', 'Product ID': 'OFF-BI-10004738', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Flexible Leather- Look Classic Collection Ring Binder', 'Sales': 5.682, 'Quantity': 1, 'Discount': 0.7, 'Profit': -3.788}
# {'_id': ObjectId('68e63b562e1853074f2a8011'), 'Row ID': 97, 'Order ID': 'CA-2017-161018', 'Order Date': datetime.datetime(2017, 11, 9, 0, 0), 'Ship Date': datetime.datetime(2017, 11, 11, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'PN-18775', 'Customer Name': 'Parhena Norris', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10009, 'Region': 'East', 'Product ID': 'FUR-FU-10000629', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': '9-3/4 Diameter Round Wall Clock', 'Sales': 96.53, 'Quantity': 7, 'Discount': 0.0, 'Profit': 40.5426}
# {'_id': ObjectId('68e63b562e1853074f2a8012'), 'Row ID': 98, 'Order ID': 'CA-2017-157833', 'Order Date': datetime.datetime(2017, 6, 17, 0, 0), 'Ship Date': datetime.datetime(2017, 6, 20, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'KD-16345', 'Customer Name': 'Katherine Ducich', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94122, 'Region': 'West', 'Product ID': 'OFF-BI-10001721', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Trimflex Flexible Post Binders', 'Sales': 51.312, 'Quantity': 3, 'Discount': 0.2, 'Profit': 17.9592}
# {'_id': ObjectId('68e63b562e1853074f2a8013'), 'Row ID': 99, 'Order ID': 'CA-2016-149223', 'Order Date': datetime.datetime(2016, 9, 6, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 11, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'ER-13855', 'Customer Name': 'Elpida Rittenbach', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Saint Paul', 'State': 'Minnesota', 'Postal Code': 55106, 'Region': 'Central', 'Product ID': 'OFF-AP-10000358', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': 'Fellowes Basic Home/Office Series Surge Protectors', 'Sales': 77.88, 'Quantity': 6, 'Discount': 0.0, 'Profit': 22.5852}
# {'_id': ObjectId('68e63b562e1853074f2a8014'), 'Row ID': 100, 'Order ID': 'CA-2016-158568', 'Order Date': datetime.datetime(2016, 8, 29, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 2, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'RB-19465', 'Customer Name': 'Rick Bensley', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Chicago', 'State': 'Illinois', 'Postal Code': 60610, 'Region': 'Central', 'Product ID': 'OFF-PA-10003256', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Avery Personal Creations Heavyweight Cards', 'Sales': 64.624, 'Quantity': 7, 'Discount': 0.2, 'Profit': 22.6184}

# %% [markdown]
# Question 3.  Count and display the total number of documents in the Orders collection
#
# Answer:

# %%
# Accessing database and collection
db = client['superstore_db']
collection = db['Orders']

# Count all documents
total_docs = collection.count_documents({})

# Display the count
print(f"Total number of documents in the collection 'Orders': {total_docs}")
# Out:
# Total number of documents in the collection 'Orders': 9994

# %% [markdown]
# Question 4. Write a query to fetch all orders from the "West" region
#
# Answer:

# %%
# Accessing database and collection
db = client['superstore_db']
collection = db['Orders']

# Query to fetch all orders where Region is "West"
query = {"Region": "West"}

# Count documents matching the query directly
count = collection.count_documents(query)

print(f"Number of orders where region is west : {count}")
print("---------------------------------------------")

# Execute the query
west_orders = collection.find(query)


print(f"Printing just 100 orders from the west region although there are {count}")

# Print the results
for order in collection.find(query).limit(100):
    print(order)
# Out:
# Number of orders where region is west : 3203
# ---------------------------------------------
# Printing just 100 orders from the west region although there are 3203
# {'_id': ObjectId('68e63b562e1853074f2a7fb3'), 'Row ID': 3, 'Order ID': 'CA-2016-138688', 'Order Date': datetime.datetime(2016, 6, 12, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 16, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'DV-13045', 'Customer Name': 'Darrin Van Huff', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90036, 'Region': 'West', 'Product ID': 'OFF-LA-10000240', 'Category': 'Office Supplies', 'Sub-Category': 'Labels', 'Product Name': 'Self-Adhesive Address Labels for Typewriters by Universal', 'Sales': 14.62, 'Quantity': 2, 'Discount': 0.0, 'Profit': 6.8714}
# {'_id': ObjectId('68e63b562e1853074f2a7fb6'), 'Row ID': 6, 'Order ID': 'CA-2014-115812', 'Order Date': datetime.datetime(2014, 6, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'FUR-FU-10001487', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Eldon Expressions Wood and Plastic Desk Accessories, Cherry Wood', 'Sales': 48.86, 'Quantity': 7, 'Discount': 0.0, 'Profit': 14.1694}
# {'_id': ObjectId('68e63b562e1853074f2a7fb7'), 'Row ID': 7, 'Order ID': 'CA-2014-115812', 'Order Date': datetime.datetime(2014, 6, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'OFF-AR-10002833', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Newell 322', 'Sales': 7.28, 'Quantity': 4, 'Discount': 0.0, 'Profit': 1.9656}
# {'_id': ObjectId('68e63b562e1853074f2a7fb8'), 'Row ID': 8, 'Order ID': 'CA-2014-115812', 'Order Date': datetime.datetime(2014, 6, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'TEC-PH-10002275', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Mitel 5320 IP Phone VoIP phone', 'Sales': 907.152, 'Quantity': 6, 'Discount': 0.2, 'Profit': 90.7152}
# {'_id': ObjectId('68e63b562e1853074f2a7fb9'), 'Row ID': 9, 'Order ID': 'CA-2014-115812', 'Order Date': datetime.datetime(2014, 6, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'OFF-BI-10003910', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'DXL Angle-View Binders with Locking Rings by Samsill', 'Sales': 18.504, 'Quantity': 3, 'Discount': 0.2, 'Profit': 5.7825}
# {'_id': ObjectId('68e63b562e1853074f2a7fba'), 'Row ID': 10, 'Order ID': 'CA-2014-115812', 'Order Date': datetime.datetime(2014, 6, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'OFF-AP-10002892', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': 'Belkin F5C206VTEL 6 Outlet Surge', 'Sales': 114.9, 'Quantity': 5, 'Discount': 0.0, 'Profit': 34.47}
# {'_id': ObjectId('68e63b562e1853074f2a7fbb'), 'Row ID': 11, 'Order ID': 'CA-2014-115812', 'Order Date': datetime.datetime(2014, 6, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'FUR-TA-10001539', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Chromcraft Rectangular Conference Tables', 'Sales': 1706.184, 'Quantity': 9, 'Discount': 0.2, 'Profit': 85.3092}
# {'_id': ObjectId('68e63b562e1853074f2a7fbc'), 'Row ID': 12, 'Order ID': 'CA-2014-115812', 'Order Date': datetime.datetime(2014, 6, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'TEC-PH-10002033', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Konftel 250 Conference\xa0phone\xa0- Charcoal black', 'Sales': 911.424, 'Quantity': 4, 'Discount': 0.2, 'Profit': 68.3568}
# {'_id': ObjectId('68e63b562e1853074f2a7fbe'), 'Row ID': 14, 'Order ID': 'CA-2016-161389', 'Order Date': datetime.datetime(2016, 12, 5, 0, 0), 'Ship Date': datetime.datetime(2016, 12, 10, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'IM-15070', 'Customer Name': 'Irene Maddox', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98103, 'Region': 'West', 'Product ID': 'OFF-BI-10003656', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Fellowes PB200 Plastic Comb Binding Machine', 'Sales': 407.976, 'Quantity': 3, 'Discount': 0.2, 'Profit': 132.5922}
# {'_id': ObjectId('68e63b562e1853074f2a7fc2'), 'Row ID': 18, 'Order ID': 'CA-2014-167164', 'Order Date': datetime.datetime(2014, 5, 13, 0, 0), 'Ship Date': datetime.datetime(2014, 5, 15, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'AG-10270', 'Customer Name': 'Alejandro Grove', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'West Jordan', 'State': 'Utah', 'Postal Code': 84084, 'Region': 'West', 'Product ID': 'OFF-ST-10000107', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Fellowes Super Stor/Drawer', 'Sales': 55.5, 'Quantity': 2, 'Discount': 0.0, 'Profit': 9.99}
# {'_id': ObjectId('68e63b562e1853074f2a7fc3'), 'Row ID': 19, 'Order ID': 'CA-2014-143336', 'Order Date': datetime.datetime(2014, 8, 27, 0, 0), 'Ship Date': datetime.datetime(2014, 9, 1, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'ZD-21925', 'Customer Name': 'Zuschuss Donatelli', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94109, 'Region': 'West', 'Product ID': 'OFF-AR-10003056', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Newell 341', 'Sales': 8.56, 'Quantity': 2, 'Discount': 0.0, 'Profit': 2.4824}
# {'_id': ObjectId('68e63b562e1853074f2a7fc4'), 'Row ID': 20, 'Order ID': 'CA-2014-143336', 'Order Date': datetime.datetime(2014, 8, 27, 0, 0), 'Ship Date': datetime.datetime(2014, 9, 1, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'ZD-21925', 'Customer Name': 'Zuschuss Donatelli', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94109, 'Region': 'West', 'Product ID': 'TEC-PH-10001949', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Cisco SPA 501G IP Phone', 'Sales': 213.48, 'Quantity': 3, 'Discount': 0.2, 'Profit': 16.011}
# {'_id': ObjectId('68e63b562e1853074f2a7fc5'), 'Row ID': 21, 'Order ID': 'CA-2014-143336', 'Order Date': datetime.datetime(2014, 8, 27, 0, 0), 'Ship Date': datetime.datetime(2014, 9, 1, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'ZD-21925', 'Customer Name': 'Zuschuss Donatelli', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94109, 'Region': 'West', 'Product ID': 'OFF-BI-10002215', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Wilson Jones Hanging View Binder, White, 1"', 'Sales': 22.72, 'Quantity': 4, 'Discount': 0.2, 'Profit': 7.384}
# {'_id': ObjectId('68e63b562e1853074f2a7fc9'), 'Row ID': 25, 'Order ID': 'CA-2015-106320', 'Order Date': datetime.datetime(2015, 9, 25, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 30, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'EB-13870', 'Customer Name': 'Emily Burns', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Orem', 'State': 'Utah', 'Postal Code': 84057, 'Region': 'West', 'Product ID': 'FUR-TA-10000577', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bretford CR4500 Series Slim Rectangular Table', 'Sales': 1044.63, 'Quantity': 3, 'Discount': 0.0, 'Profit': 240.2649}
# {'_id': ObjectId('68e63b562e1853074f2a7fca'), 'Row ID': 26, 'Order ID': 'CA-2016-121755', 'Order Date': datetime.datetime(2016, 1, 16, 0, 0), 'Ship Date': datetime.datetime(2016, 1, 20, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'EH-13945', 'Customer Name': 'Eric Hoffmann', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90049, 'Region': 'West', 'Product ID': 'OFF-BI-10001634', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Wilson Jones Active Use Binders', 'Sales': 11.648, 'Quantity': 2, 'Discount': 0.2, 'Profit': 4.2224}
# {'_id': ObjectId('68e63b562e1853074f2a7fcb'), 'Row ID': 27, 'Order ID': 'CA-2016-121755', 'Order Date': datetime.datetime(2016, 1, 16, 0, 0), 'Ship Date': datetime.datetime(2016, 1, 20, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'EH-13945', 'Customer Name': 'Eric Hoffmann', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90049, 'Region': 'West', 'Product ID': 'TEC-AC-10003027', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Imation\xa08GB Mini TravelDrive USB 2.0\xa0Flash Drive', 'Sales': 90.57, 'Quantity': 3, 'Discount': 0.0, 'Profit': 11.7741}
# {'_id': ObjectId('68e63b562e1853074f2a7fdb'), 'Row ID': 43, 'Order ID': 'CA-2016-101343', 'Order Date': datetime.datetime(2016, 7, 17, 0, 0), 'Ship Date': datetime.datetime(2016, 7, 22, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'RA-19885', 'Customer Name': 'Ruben Ausman', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90049, 'Region': 'West', 'Product ID': 'OFF-ST-10003479', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Eldon Base for stackable storage shelf, platinum', 'Sales': 77.88, 'Quantity': 2, 'Discount': 0.0, 'Profit': 3.894}
# {'_id': ObjectId('68e63b562e1853074f2a7fef'), 'Row ID': 63, 'Order ID': 'CA-2015-135545', 'Order Date': datetime.datetime(2015, 11, 24, 0, 0), 'Ship Date': datetime.datetime(2015, 11, 30, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'KM-16720', 'Customer Name': 'Kunst Miller', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'TEC-AC-10004633', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Verbatim 25 GB 6x Blu-ray Single Layer Recordable Disc, 3/Pack', 'Sales': 13.98, 'Quantity': 2, 'Discount': 0.0, 'Profit': 6.1512}
# {'_id': ObjectId('68e63b562e1853074f2a7ff0'), 'Row ID': 64, 'Order ID': 'CA-2015-135545', 'Order Date': datetime.datetime(2015, 11, 24, 0, 0), 'Ship Date': datetime.datetime(2015, 11, 30, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'KM-16720', 'Customer Name': 'Kunst Miller', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'OFF-BI-10001078', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Acco PRESSTEX Data Binder with Storage Hooks, Dark Blue, 14 7/8" X 11"', 'Sales': 25.824, 'Quantity': 6, 'Discount': 0.2, 'Profit': 9.3612}
# {'_id': ObjectId('68e63b562e1853074f2a7ff1'), 'Row ID': 65, 'Order ID': 'CA-2015-135545', 'Order Date': datetime.datetime(2015, 11, 24, 0, 0), 'Ship Date': datetime.datetime(2015, 11, 30, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'KM-16720', 'Customer Name': 'Kunst Miller', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'OFF-PA-10003892', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 1943', 'Sales': 146.73, 'Quantity': 3, 'Discount': 0.0, 'Profit': 68.9631}
# {'_id': ObjectId('68e63b562e1853074f2a7ff2'), 'Row ID': 66, 'Order ID': 'CA-2015-135545', 'Order Date': datetime.datetime(2015, 11, 24, 0, 0), 'Ship Date': datetime.datetime(2015, 11, 30, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'KM-16720', 'Customer Name': 'Kunst Miller', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'FUR-FU-10000397', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Luxo Economy Swing Arm Lamp', 'Sales': 79.76, 'Quantity': 4, 'Discount': 0.0, 'Profit': 22.3328}
# {'_id': ObjectId('68e63b562e1853074f2a7ff4'), 'Row ID': 68, 'Order ID': 'CA-2014-106376', 'Order Date': datetime.datetime(2014, 12, 5, 0, 0), 'Ship Date': datetime.datetime(2014, 12, 10, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BS-11590', 'Customer Name': 'Brendan Sweed', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Gilbert', 'State': 'Arizona', 'Postal Code': 85234, 'Region': 'West', 'Product ID': 'OFF-AR-10002671', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Hunt BOSTON Model 1606 High-Volume Electric Pencil Sharpener, Beige', 'Sales': 1113.024, 'Quantity': 8, 'Discount': 0.2, 'Profit': 111.3024}
# {'_id': ObjectId('68e63b562e1853074f2a7ff5'), 'Row ID': 69, 'Order ID': 'CA-2014-106376', 'Order Date': datetime.datetime(2014, 12, 5, 0, 0), 'Ship Date': datetime.datetime(2014, 12, 10, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BS-11590', 'Customer Name': 'Brendan Sweed', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Gilbert', 'State': 'Arizona', 'Postal Code': 85234, 'Region': 'West', 'Product ID': 'TEC-PH-10002726', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'netTALK DUO VoIP Telephone Service', 'Sales': 167.968, 'Quantity': 4, 'Discount': 0.2, 'Profit': 62.988}
# {'_id': ObjectId('68e63b562e1853074f2a8002'), 'Row ID': 82, 'Order ID': 'CA-2014-139451', 'Order Date': datetime.datetime(2014, 10, 12, 0, 0), 'Ship Date': datetime.datetime(2014, 10, 16, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'DN-13690', 'Customer Name': 'Duane Noonan', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94122, 'Region': 'West', 'Product ID': 'OFF-AR-10002053', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Premium Writing Pencils, Soft, #2 by Central Association for the Blind', 'Sales': 14.9, 'Quantity': 5, 'Discount': 0.0, 'Profit': 4.172}
# {'_id': ObjectId('68e63b562e1853074f2a8003'), 'Row ID': 83, 'Order ID': 'CA-2014-139451', 'Order Date': datetime.datetime(2014, 10, 12, 0, 0), 'Ship Date': datetime.datetime(2014, 10, 16, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'DN-13690', 'Customer Name': 'Duane Noonan', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94122, 'Region': 'West', 'Product ID': 'OFF-ST-10002370', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Sortfiler Multipurpose Personal File Organizer, Black', 'Sales': 21.39, 'Quantity': 1, 'Discount': 0.0, 'Profit': 6.2031}
# {'_id': ObjectId('68e63b562e1853074f2a800a'), 'Row ID': 90, 'Order ID': 'CA-2016-109806', 'Order Date': datetime.datetime(2016, 9, 17, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 22, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JS-15685', 'Customer Name': 'Jim Sink', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90036, 'Region': 'West', 'Product ID': 'OFF-AR-10004930', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Turquoise Lead Holder with Pocket Clip', 'Sales': 20.1, 'Quantity': 3, 'Discount': 0.0, 'Profit': 6.633}
# {'_id': ObjectId('68e63b562e1853074f2a800b'), 'Row ID': 91, 'Order ID': 'CA-2016-109806', 'Order Date': datetime.datetime(2016, 9, 17, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 22, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JS-15685', 'Customer Name': 'Jim Sink', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90036, 'Region': 'West', 'Product ID': 'TEC-PH-10004093', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Panasonic Kx-TS550', 'Sales': 73.584, 'Quantity': 2, 'Discount': 0.2, 'Profit': 8.2782}
# {'_id': ObjectId('68e63b562e1853074f2a800c'), 'Row ID': 92, 'Order ID': 'CA-2016-109806', 'Order Date': datetime.datetime(2016, 9, 17, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 22, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JS-15685', 'Customer Name': 'Jim Sink', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90036, 'Region': 'West', 'Product ID': 'OFF-PA-10000304', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 1995', 'Sales': 6.48, 'Quantity': 1, 'Discount': 0.0, 'Profit': 3.1104}
# {'_id': ObjectId('68e63b562e1853074f2a8010'), 'Row ID': 96, 'Order ID': 'US-2017-109484', 'Order Date': datetime.datetime(2017, 11, 6, 0, 0), 'Ship Date': datetime.datetime(2017, 11, 12, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'RB-19705', 'Customer Name': 'Roger Barcio', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Portland', 'State': 'Oregon', 'Postal Code': 97206, 'Region': 'West', 'Product ID': 'OFF-BI-10004738', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Flexible Leather- Look Classic Collection Ring Binder', 'Sales': 5.682, 'Quantity': 1, 'Discount': 0.7, 'Profit': -3.788}
# {'_id': ObjectId('68e63b562e1853074f2a8012'), 'Row ID': 98, 'Order ID': 'CA-2017-157833', 'Order Date': datetime.datetime(2017, 6, 17, 0, 0), 'Ship Date': datetime.datetime(2017, 6, 20, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'KD-16345', 'Customer Name': 'Katherine Ducich', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94122, 'Region': 'West', 'Product ID': 'OFF-BI-10001721', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Trimflex Flexible Post Binders', 'Sales': 51.312, 'Quantity': 3, 'Discount': 0.2, 'Profit': 17.9592}
# {'_id': ObjectId('68e63b562e1853074f2a8018'), 'Row ID': 104, 'Order ID': 'US-2015-156867', 'Order Date': datetime.datetime(2015, 11, 13, 0, 0), 'Ship Date': datetime.datetime(2015, 11, 17, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'LC-16870', 'Customer Name': 'Lena Cacioppo', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Aurora', 'State': 'Colorado', 'Postal Code': 80013, 'Region': 'West', 'Product ID': 'TEC-AC-10001552', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Logitech K350 2.4Ghz Wireless Keyboard', 'Sales': 238.896, 'Quantity': 6, 'Discount': 0.2, 'Profit': -26.8758}
# {'_id': ObjectId('68e63b562e1853074f2a8019'), 'Row ID': 105, 'Order ID': 'US-2015-156867', 'Order Date': datetime.datetime(2015, 11, 13, 0, 0), 'Ship Date': datetime.datetime(2015, 11, 17, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'LC-16870', 'Customer Name': 'Lena Cacioppo', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Aurora', 'State': 'Colorado', 'Postal Code': 80013, 'Region': 'West', 'Product ID': 'FUR-FU-10004006', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Deflect-o DuraMat Lighweight, Studded, Beveled Mat for Low Pile Carpeting', 'Sales': 102.36, 'Quantity': 3, 'Discount': 0.2, 'Profit': -3.8385}
# {'_id': ObjectId('68e63b562e1853074f2a801a'), 'Row ID': 106, 'Order ID': 'US-2015-156867', 'Order Date': datetime.datetime(2015, 11, 13, 0, 0), 'Ship Date': datetime.datetime(2015, 11, 17, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'LC-16870', 'Customer Name': 'Lena Cacioppo', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Aurora', 'State': 'Colorado', 'Postal Code': 80013, 'Region': 'West', 'Product ID': 'OFF-BI-10002794', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Avery Trapezoid Ring Binder, 3" Capacity, Black, 1040 sheets', 'Sales': 36.882, 'Quantity': 3, 'Discount': 0.7, 'Profit': -25.8174}
# {'_id': ObjectId('68e63b562e1853074f2a8026'), 'Row ID': 118, 'Order ID': 'CA-2015-110457', 'Order Date': datetime.datetime(2015, 3, 2, 0, 0), 'Ship Date': datetime.datetime(2015, 3, 6, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'DK-13090', 'Customer Name': 'Dave Kipp', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98103, 'Region': 'West', 'Product ID': 'FUR-TA-10001768', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Hon Racetrack Conference Tables', 'Sales': 787.53, 'Quantity': 3, 'Discount': 0.0, 'Profit': 165.3813}
# {'_id': ObjectId('68e63b562e1853074f2a802f'), 'Row ID': 127, 'Order ID': 'US-2017-107272', 'Order Date': datetime.datetime(2017, 11, 5, 0, 0), 'Ship Date': datetime.datetime(2017, 11, 12, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'TS-21610', 'Customer Name': 'Troy Staebel', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Phoenix', 'State': 'Arizona', 'Postal Code': 85023, 'Region': 'West', 'Product ID': 'OFF-BI-10003274', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Avery Durable Slant Ring Binders, No Labels', 'Sales': 2.388, 'Quantity': 2, 'Discount': 0.7, 'Profit': -1.8308}
# {'_id': ObjectId('68e63b562e1853074f2a8030'), 'Row ID': 128, 'Order ID': 'US-2017-107272', 'Order Date': datetime.datetime(2017, 11, 5, 0, 0), 'Ship Date': datetime.datetime(2017, 11, 12, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'TS-21610', 'Customer Name': 'Troy Staebel', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Phoenix', 'State': 'Arizona', 'Postal Code': 85023, 'Region': 'West', 'Product ID': 'OFF-ST-10002974', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Trav-L-File Heavy-Duty Shuttle II, Black', 'Sales': 243.992, 'Quantity': 7, 'Discount': 0.2, 'Profit': 30.499}
# {'_id': ObjectId('68e63b562e1853074f2a8031'), 'Row ID': 129, 'Order ID': 'US-2016-125969', 'Order Date': datetime.datetime(2016, 11, 6, 0, 0), 'Ship Date': datetime.datetime(2016, 11, 10, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'LS-16975', 'Customer Name': 'Lindsay Shagiari', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'FUR-CH-10001146', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Global Task Chair, Black', 'Sales': 81.424, 'Quantity': 2, 'Discount': 0.2, 'Profit': -9.1602}
# {'_id': ObjectId('68e63b562e1853074f2a8032'), 'Row ID': 130, 'Order ID': 'US-2016-125969', 'Order Date': datetime.datetime(2016, 11, 6, 0, 0), 'Ship Date': datetime.datetime(2016, 11, 10, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'LS-16975', 'Customer Name': 'Lindsay Shagiari', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'FUR-FU-10003773', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Eldon Cleatmat Plus Chair Mats for High Pile Carpets', 'Sales': 238.56, 'Quantity': 3, 'Discount': 0.0, 'Profit': 26.2416}
# {'_id': ObjectId('68e63b562e1853074f2a8036'), 'Row ID': 134, 'Order ID': 'CA-2016-145583', 'Order Date': datetime.datetime(2016, 10, 13, 0, 0), 'Ship Date': datetime.datetime(2016, 10, 19, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'LC-16885', 'Customer Name': 'Lena Creighton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Roseville', 'State': 'California', 'Postal Code': 95661, 'Region': 'West', 'Product ID': 'OFF-PA-10001804', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 195', 'Sales': 20.04, 'Quantity': 3, 'Discount': 0.0, 'Profit': 9.6192}
# {'_id': ObjectId('68e63b562e1853074f2a8037'), 'Row ID': 135, 'Order ID': 'CA-2016-145583', 'Order Date': datetime.datetime(2016, 10, 13, 0, 0), 'Ship Date': datetime.datetime(2016, 10, 19, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'LC-16885', 'Customer Name': 'Lena Creighton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Roseville', 'State': 'California', 'Postal Code': 95661, 'Region': 'West', 'Product ID': 'OFF-PA-10001736', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 1880', 'Sales': 35.44, 'Quantity': 1, 'Discount': 0.0, 'Profit': 16.6568}
# {'_id': ObjectId('68e63b562e1853074f2a8038'), 'Row ID': 136, 'Order ID': 'CA-2016-145583', 'Order Date': datetime.datetime(2016, 10, 13, 0, 0), 'Ship Date': datetime.datetime(2016, 10, 19, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'LC-16885', 'Customer Name': 'Lena Creighton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Roseville', 'State': 'California', 'Postal Code': 95661, 'Region': 'West', 'Product ID': 'OFF-AR-10001149', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Sanford Colorific Colored Pencils, 12/Box', 'Sales': 11.52, 'Quantity': 4, 'Discount': 0.0, 'Profit': 3.456}
# {'_id': ObjectId('68e63b562e1853074f2a8039'), 'Row ID': 137, 'Order ID': 'CA-2016-145583', 'Order Date': datetime.datetime(2016, 10, 13, 0, 0), 'Ship Date': datetime.datetime(2016, 10, 19, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'LC-16885', 'Customer Name': 'Lena Creighton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Roseville', 'State': 'California', 'Postal Code': 95661, 'Region': 'West', 'Product ID': 'OFF-FA-10002988', 'Category': 'Office Supplies', 'Sub-Category': 'Fasteners', 'Product Name': 'Ideal Clamps', 'Sales': 4.02, 'Quantity': 2, 'Discount': 0.0, 'Profit': 1.9698}
# {'_id': ObjectId('68e63b562e1853074f2a803a'), 'Row ID': 138, 'Order ID': 'CA-2016-145583', 'Order Date': datetime.datetime(2016, 10, 13, 0, 0), 'Ship Date': datetime.datetime(2016, 10, 19, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'LC-16885', 'Customer Name': 'Lena Creighton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Roseville', 'State': 'California', 'Postal Code': 95661, 'Region': 'West', 'Product ID': 'OFF-BI-10004781', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'GBC Wire Binding Strips', 'Sales': 76.176, 'Quantity': 3, 'Discount': 0.2, 'Profit': 26.6616}
# {'_id': ObjectId('68e63b562e1853074f2a803b'), 'Row ID': 139, 'Order ID': 'CA-2016-145583', 'Order Date': datetime.datetime(2016, 10, 13, 0, 0), 'Ship Date': datetime.datetime(2016, 10, 19, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'LC-16885', 'Customer Name': 'Lena Creighton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Roseville', 'State': 'California', 'Postal Code': 95661, 'Region': 'West', 'Product ID': 'OFF-SU-10001218', 'Category': 'Office Supplies', 'Sub-Category': 'Supplies', 'Product Name': 'Fiskars Softgrip Scissors', 'Sales': 65.88, 'Quantity': 6, 'Discount': 0.0, 'Profit': 18.4464}
# {'_id': ObjectId('68e63b562e1853074f2a803c'), 'Row ID': 140, 'Order ID': 'CA-2016-145583', 'Order Date': datetime.datetime(2016, 10, 13, 0, 0), 'Ship Date': datetime.datetime(2016, 10, 19, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'LC-16885', 'Customer Name': 'Lena Creighton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Roseville', 'State': 'California', 'Postal Code': 95661, 'Region': 'West', 'Product ID': 'FUR-FU-10001706', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Longer-Life Soft White Bulbs', 'Sales': 43.12, 'Quantity': 14, 'Discount': 0.0, 'Profit': 20.6976}
# {'_id': ObjectId('68e63b562e1853074f2a803e'), 'Row ID': 142, 'Order ID': 'CA-2017-106180', 'Order Date': datetime.datetime(2017, 9, 18, 0, 0), 'Ship Date': datetime.datetime(2017, 9, 23, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'SH-19975', 'Customer Name': 'Sally Hughsby', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94122, 'Region': 'West', 'Product ID': 'OFF-AR-10000940', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Newell 343', 'Sales': 8.82, 'Quantity': 3, 'Discount': 0.0, 'Profit': 2.3814}
# {'_id': ObjectId('68e63b562e1853074f2a803f'), 'Row ID': 143, 'Order ID': 'CA-2017-106180', 'Order Date': datetime.datetime(2017, 9, 18, 0, 0), 'Ship Date': datetime.datetime(2017, 9, 23, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'SH-19975', 'Customer Name': 'Sally Hughsby', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94122, 'Region': 'West', 'Product ID': 'OFF-EN-10004030', 'Category': 'Office Supplies', 'Sub-Category': 'Envelopes', 'Product Name': 'Convenience Packs of Business Envelopes', 'Sales': 10.86, 'Quantity': 3, 'Discount': 0.0, 'Profit': 5.1042}
# {'_id': ObjectId('68e63b562e1853074f2a8040'), 'Row ID': 144, 'Order ID': 'CA-2017-106180', 'Order Date': datetime.datetime(2017, 9, 18, 0, 0), 'Ship Date': datetime.datetime(2017, 9, 23, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'SH-19975', 'Customer Name': 'Sally Hughsby', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94122, 'Region': 'West', 'Product ID': 'OFF-PA-10004327', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 1911', 'Sales': 143.7, 'Quantity': 3, 'Discount': 0.0, 'Profit': 68.976}
# {'_id': ObjectId('68e63b562e1853074f2a8042'), 'Row ID': 146, 'Order ID': 'CA-2015-110744', 'Order Date': datetime.datetime(2015, 9, 7, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 12, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'HA-14920', 'Customer Name': 'Helen Andreada', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Pasadena', 'State': 'California', 'Postal Code': 91104, 'Region': 'West', 'Product ID': 'OFF-ST-10003656', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Safco Industrial Wire Shelving', 'Sales': 671.93, 'Quantity': 7, 'Discount': 0.0, 'Profit': 20.1579}
# {'_id': ObjectId('68e63b562e1853074f2a8048'), 'Row ID': 152, 'Order ID': 'CA-2016-158834', 'Order Date': datetime.datetime(2016, 3, 13, 0, 0), 'Ship Date': datetime.datetime(2016, 3, 16, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'TW-21025', 'Customer Name': 'Tamara Willingham', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Scottsdale', 'State': 'Arizona', 'Postal Code': 85254, 'Region': 'West', 'Product ID': 'OFF-AP-10000326', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': 'Belkin 7 Outlet SurgeMaster Surge Protector with Phone Protection', 'Sales': 157.92, 'Quantity': 5, 'Discount': 0.2, 'Profit': 17.766}
# {'_id': ObjectId('68e63b562e1853074f2a8049'), 'Row ID': 153, 'Order ID': 'CA-2016-158834', 'Order Date': datetime.datetime(2016, 3, 13, 0, 0), 'Ship Date': datetime.datetime(2016, 3, 16, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'TW-21025', 'Customer Name': 'Tamara Willingham', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Scottsdale', 'State': 'Arizona', 'Postal Code': 85254, 'Region': 'West', 'Product ID': 'TEC-PH-10001254', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Jabra BIZ 2300 Duo QD Duo Corded\xa0Headset', 'Sales': 203.184, 'Quantity': 2, 'Discount': 0.2, 'Profit': 15.2388}
# {'_id': ObjectId('68e63b562e1853074f2a804a'), 'Row ID': 154, 'Order ID': 'CA-2015-124919', 'Order Date': datetime.datetime(2015, 5, 31, 0, 0), 'Ship Date': datetime.datetime(2015, 6, 2, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'SP-20650', 'Customer Name': 'Stephanie Phelps', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Jose', 'State': 'California', 'Postal Code': 95123, 'Region': 'West', 'Product ID': 'OFF-PA-10001950', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Southworth 25% Cotton Antique Laid Paper & Envelopes', 'Sales': 58.38, 'Quantity': 7, 'Discount': 0.0, 'Profit': 26.271}
# {'_id': ObjectId('68e63b562e1853074f2a804b'), 'Row ID': 155, 'Order ID': 'CA-2015-124919', 'Order Date': datetime.datetime(2015, 5, 31, 0, 0), 'Ship Date': datetime.datetime(2015, 6, 2, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'SP-20650', 'Customer Name': 'Stephanie Phelps', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Jose', 'State': 'California', 'Postal Code': 95123, 'Region': 'West', 'Product ID': 'OFF-PA-10002254', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 1883', 'Sales': 105.52, 'Quantity': 4, 'Discount': 0.0, 'Profit': 48.5392}
# {'_id': ObjectId('68e63b562e1853074f2a804c'), 'Row ID': 156, 'Order ID': 'CA-2015-124919', 'Order Date': datetime.datetime(2015, 5, 31, 0, 0), 'Ship Date': datetime.datetime(2015, 6, 2, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'SP-20650', 'Customer Name': 'Stephanie Phelps', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Jose', 'State': 'California', 'Postal Code': 95123, 'Region': 'West', 'Product ID': 'OFF-ST-10001590', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Tenex Personal Project File with Scoop Front Design, Black', 'Sales': 80.88, 'Quantity': 6, 'Discount': 0.0, 'Profit': 21.0288}
# {'_id': ObjectId('68e63b562e1853074f2a804d'), 'Row ID': 157, 'Order ID': 'CA-2015-118948', 'Order Date': datetime.datetime(2015, 5, 28, 0, 0), 'Ship Date': datetime.datetime(2015, 6, 3, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'NK-18490', 'Customer Name': 'Neil Knudson', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98105, 'Region': 'West', 'Product ID': 'OFF-AR-10001547', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Newell 311', 'Sales': 6.63, 'Quantity': 3, 'Discount': 0.0, 'Profit': 1.7901}
# {'_id': ObjectId('68e63b562e1853074f2a804e'), 'Row ID': 158, 'Order ID': 'CA-2014-104269', 'Order Date': datetime.datetime(2014, 3, 1, 0, 0), 'Ship Date': datetime.datetime(2014, 3, 6, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'DB-13060', 'Customer Name': 'Dave Brooks', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98115, 'Region': 'West', 'Product ID': 'FUR-CH-10004063', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': "Global Deluxe High-Back Manager's Chair", 'Sales': 457.568, 'Quantity': 2, 'Discount': 0.2, 'Profit': 51.4764}
# {'_id': ObjectId('68e63b562e1853074f2a8051'), 'Row ID': 161, 'Order ID': 'CA-2016-162733', 'Order Date': datetime.datetime(2016, 5, 11, 0, 0), 'Ship Date': datetime.datetime(2016, 5, 12, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'TT-21070', 'Customer Name': 'Ted Trevino', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90045, 'Region': 'West', 'Product ID': 'OFF-PA-10002751', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 1920', 'Sales': 5.98, 'Quantity': 1, 'Discount': 0.0, 'Profit': 2.691}
# {'_id': ObjectId('68e63b562e1853074f2a8053'), 'Row ID': 163, 'Order ID': 'CA-2016-154508', 'Order Date': datetime.datetime(2016, 11, 16, 0, 0), 'Ship Date': datetime.datetime(2016, 11, 20, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'RD-19900', 'Customer Name': 'Ruben Dartt', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Carlsbad', 'State': 'New Mexico', 'Postal Code': 88220, 'Region': 'West', 'Product ID': 'OFF-EN-10001990', 'Category': 'Office Supplies', 'Sub-Category': 'Envelopes', 'Product Name': 'Staple envelope', 'Sales': 28.4, 'Quantity': 5, 'Discount': 0.0, 'Profit': 13.348}
# {'_id': ObjectId('68e63b562e1853074f2a8054'), 'Row ID': 164, 'Order ID': 'CA-2016-113817', 'Order Date': datetime.datetime(2016, 11, 7, 0, 0), 'Ship Date': datetime.datetime(2016, 11, 11, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'MJ-17740', 'Customer Name': 'Max Jones', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98115, 'Region': 'West', 'Product ID': 'OFF-BI-10004002', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Wilson Jones International Size A4 Ring Binders', 'Sales': 27.68, 'Quantity': 2, 'Discount': 0.2, 'Profit': 9.688}
# {'_id': ObjectId('68e63b562e1853074f2a805c'), 'Row ID': 172, 'Order ID': 'CA-2014-118962', 'Order Date': datetime.datetime(2014, 8, 5, 0, 0), 'Ship Date': datetime.datetime(2014, 8, 9, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'CS-12130', 'Customer Name': 'Chad Sievert', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'OFF-PA-10000659', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Adams Phone Message Book, Professional, 400 Message Capacity, 5 3/6\x94 x 11\x94', 'Sales': 20.94, 'Quantity': 3, 'Discount': 0.0, 'Profit': 9.8418}
# {'_id': ObjectId('68e63b562e1853074f2a805d'), 'Row ID': 173, 'Order ID': 'CA-2014-118962', 'Order Date': datetime.datetime(2014, 8, 5, 0, 0), 'Ship Date': datetime.datetime(2014, 8, 9, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'CS-12130', 'Customer Name': 'Chad Sievert', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'OFF-PA-10001144', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 1913', 'Sales': 110.96, 'Quantity': 2, 'Discount': 0.0, 'Profit': 53.2608}
# {'_id': ObjectId('68e63b562e1853074f2a805e'), 'Row ID': 174, 'Order ID': 'CA-2014-118962', 'Order Date': datetime.datetime(2014, 8, 5, 0, 0), 'Ship Date': datetime.datetime(2014, 8, 9, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'CS-12130', 'Customer Name': 'Chad Sievert', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'FUR-CH-10003817', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Global Value Steno Chair, Gray', 'Sales': 340.144, 'Quantity': 7, 'Discount': 0.2, 'Profit': 21.259}
# {'_id': ObjectId('68e63b562e1853074f2a806b'), 'Row ID': 187, 'Order ID': 'CA-2014-123260', 'Order Date': datetime.datetime(2014, 8, 26, 0, 0), 'Ship Date': datetime.datetime(2014, 8, 30, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'FM-14290', 'Customer Name': 'Frank Merwin', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'TEC-AC-10002323', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'SanDisk Ultra 32 GB MicroSDHC Class 10 Memory Card', 'Sales': 176.8, 'Quantity': 8, 'Discount': 0.0, 'Profit': 22.984}
# {'_id': ObjectId('68e63b562e1853074f2a8073'), 'Row ID': 195, 'Order ID': 'CA-2015-131457', 'Order Date': datetime.datetime(2015, 10, 31, 0, 0), 'Ship Date': datetime.datetime(2015, 11, 6, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'MZ-17515', 'Customer Name': 'Mary Zewe', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Redlands', 'State': 'California', 'Postal Code': 92374, 'Region': 'West', 'Product ID': 'OFF-EN-10001509', 'Category': 'Office Supplies', 'Sub-Category': 'Envelopes', 'Product Name': 'Poly String Tie Envelopes', 'Sales': 14.28, 'Quantity': 7, 'Discount': 0.0, 'Profit': 6.7116}
# {'_id': ObjectId('68e63b562e1853074f2a807a'), 'Row ID': 202, 'Order ID': 'CA-2014-133690', 'Order Date': datetime.datetime(2014, 8, 3, 0, 0), 'Ship Date': datetime.datetime(2014, 8, 5, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'BS-11755', 'Customer Name': 'Bruce Stewart', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Denver', 'State': 'Colorado', 'Postal Code': 80219, 'Region': 'West', 'Product ID': 'FUR-TA-10004289', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables', 'Sales': 218.75, 'Quantity': 2, 'Discount': 0.5, 'Profit': -161.875}
# {'_id': ObjectId('68e63b562e1853074f2a807b'), 'Row ID': 203, 'Order ID': 'CA-2014-133690', 'Order Date': datetime.datetime(2014, 8, 3, 0, 0), 'Ship Date': datetime.datetime(2014, 8, 5, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'BS-11755', 'Customer Name': 'Bruce Stewart', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Denver', 'State': 'Colorado', 'Postal Code': 80219, 'Region': 'West', 'Product ID': 'OFF-AP-10003622', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': 'Bravo II Megaboss 12-Amp Hard Body Upright, Replacement Belts, 2 Belts per Pack', 'Sales': 2.6, 'Quantity': 1, 'Discount': 0.2, 'Profit': 0.2925}
# {'_id': ObjectId('68e63b562e1853074f2a807e'), 'Row ID': 206, 'Order ID': 'CA-2017-108329', 'Order Date': datetime.datetime(2017, 12, 9, 0, 0), 'Ship Date': datetime.datetime(2017, 12, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'LE-16810', 'Customer Name': 'Laurel Elliston', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Whittier', 'State': 'California', 'Postal Code': 90604, 'Region': 'West', 'Product ID': 'TEC-PH-10001918', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Nortel Business Series Terminal T7208 Digital phone', 'Sales': 444.768, 'Quantity': 4, 'Discount': 0.2, 'Profit': 44.4768}
# {'_id': ObjectId('68e63b562e1853074f2a808a'), 'Row ID': 218, 'Order ID': 'CA-2016-130162', 'Order Date': datetime.datetime(2016, 10, 28, 0, 0), 'Ship Date': datetime.datetime(2016, 11, 1, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JH-15910', 'Customer Name': 'Jonathan Howell', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'OFF-ST-10001328', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Personal Filing Tote with Lid, Black/Gray', 'Sales': 93.06, 'Quantity': 6, 'Discount': 0.0, 'Profit': 26.0568}
# {'_id': ObjectId('68e63b562e1853074f2a808b'), 'Row ID': 219, 'Order ID': 'CA-2016-130162', 'Order Date': datetime.datetime(2016, 10, 28, 0, 0), 'Ship Date': datetime.datetime(2016, 11, 1, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JH-15910', 'Customer Name': 'Jonathan Howell', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'TEC-PH-10002563', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Adtran 1202752G1', 'Sales': 302.376, 'Quantity': 3, 'Discount': 0.2, 'Profit': 22.6782}
# {'_id': ObjectId('68e63b562e1853074f2a809d'), 'Row ID': 237, 'Order ID': 'CA-2017-160514', 'Order Date': datetime.datetime(2017, 11, 12, 0, 0), 'Ship Date': datetime.datetime(2017, 11, 16, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'DB-13120', 'Customer Name': 'David Bremer', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Santa Clara', 'State': 'California', 'Postal Code': 95051, 'Region': 'West', 'Product ID': 'OFF-PA-10002479', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 4200 Series MultiUse Premium Copy Paper (20Lb. and 84 Bright)', 'Sales': 10.56, 'Quantity': 2, 'Discount': 0.0, 'Profit': 4.752}
# {'_id': ObjectId('68e63b562e1853074f2a80aa'), 'Row ID': 250, 'Order ID': 'CA-2016-154739', 'Order Date': datetime.datetime(2016, 12, 10, 0, 0), 'Ship Date': datetime.datetime(2016, 12, 15, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'LH-17155', 'Customer Name': 'Logan Haushalter', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94109, 'Region': 'West', 'Product ID': 'FUR-CH-10002965', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Global Leather Highback Executive Chair with Pneumatic Height Adjustment, Black', 'Sales': 321.568, 'Quantity': 2, 'Discount': 0.2, 'Profit': 28.1372}
# {'_id': ObjectId('68e63b562e1853074f2a80ab'), 'Row ID': 251, 'Order ID': 'CA-2016-145625', 'Order Date': datetime.datetime(2016, 9, 11, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 17, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'KC-16540', 'Customer Name': 'Kelly Collister', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Diego', 'State': 'California', 'Postal Code': 92037, 'Region': 'West', 'Product ID': 'OFF-PA-10004569', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Wirebound Message Books, Two 4 1/4" x 5" Forms per Page', 'Sales': 7.61, 'Quantity': 1, 'Discount': 0.0, 'Profit': 3.5767}
# {'_id': ObjectId('68e63b562e1853074f2a80ac'), 'Row ID': 252, 'Order ID': 'CA-2016-145625', 'Order Date': datetime.datetime(2016, 9, 11, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 17, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'KC-16540', 'Customer Name': 'Kelly Collister', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Diego', 'State': 'California', 'Postal Code': 92037, 'Region': 'West', 'Product ID': 'TEC-AC-10003832', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Logitech\xa0P710e Mobile Speakerphone', 'Sales': 3347.37, 'Quantity': 13, 'Discount': 0.0, 'Profit': 636.0003}
# {'_id': ObjectId('68e63b562e1853074f2a80ba'), 'Row ID': 266, 'Order ID': 'CA-2015-155040', 'Order Date': datetime.datetime(2015, 11, 10, 0, 0), 'Ship Date': datetime.datetime(2015, 11, 15, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'AH-10210', 'Customer Name': 'Alan Hwang', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Brentwood', 'State': 'California', 'Postal Code': 94513, 'Region': 'West', 'Product ID': 'TEC-AC-10004469', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Microsoft Sculpt Comfort Mouse', 'Sales': 79.9, 'Quantity': 2, 'Discount': 0.0, 'Profit': 35.156}
# {'_id': ObjectId('68e63b562e1853074f2a80bf'), 'Row ID': 271, 'Order ID': 'CA-2017-163979', 'Order Date': datetime.datetime(2017, 12, 28, 0, 0), 'Ship Date': datetime.datetime(2018, 1, 2, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'KH-16690', 'Customer Name': 'Kristen Hastings', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'OFF-ST-10003208', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Adjustable Depth Letter/Legal Cart', 'Sales': 725.84, 'Quantity': 4, 'Discount': 0.0, 'Profit': 210.4936}
# {'_id': ObjectId('68e63b562e1853074f2a80c0'), 'Row ID': 272, 'Order ID': 'CA-2015-155334', 'Order Date': datetime.datetime(2015, 7, 30, 0, 0), 'Ship Date': datetime.datetime(2015, 7, 31, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'HA-14920', 'Customer Name': 'Helen Andreada', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94109, 'Region': 'West', 'Product ID': 'TEC-AC-10003628', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Logitech 910-002974 M325 Wireless Mouse for Web Scrolling', 'Sales': 209.93, 'Quantity': 7, 'Discount': 0.0, 'Profit': 92.3692}
# {'_id': ObjectId('68e63b562e1853074f2a80c1'), 'Row ID': 273, 'Order ID': 'CA-2015-155334', 'Order Date': datetime.datetime(2015, 7, 30, 0, 0), 'Ship Date': datetime.datetime(2015, 7, 31, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'HA-14920', 'Customer Name': 'Helen Andreada', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94109, 'Region': 'West', 'Product ID': 'FUR-FU-10003274', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Regeneration Desk Collection', 'Sales': 5.28, 'Quantity': 3, 'Discount': 0.0, 'Profit': 2.3232}
# {'_id': ObjectId('68e63b562e1853074f2a80c2'), 'Row ID': 274, 'Order ID': 'CA-2015-155334', 'Order Date': datetime.datetime(2015, 7, 30, 0, 0), 'Ship Date': datetime.datetime(2015, 7, 31, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'HA-14920', 'Customer Name': 'Helen Andreada', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94109, 'Region': 'West', 'Product ID': 'OFF-BI-10002557', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Presstex Flexible Ring Binders', 'Sales': 10.92, 'Quantity': 3, 'Discount': 0.2, 'Profit': 4.095}
# {'_id': ObjectId('68e63b562e1853074f2a80c3'), 'Row ID': 275, 'Order ID': 'CA-2017-118136', 'Order Date': datetime.datetime(2017, 9, 16, 0, 0), 'Ship Date': datetime.datetime(2017, 9, 17, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'BB-10990', 'Customer Name': 'Barry Blumstein', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Inglewood', 'State': 'California', 'Postal Code': 90301, 'Region': 'West', 'Product ID': 'OFF-PA-10002615', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Ampad Gold Fibre Wirebound Steno Books, 6" x 9", Gregg Ruled', 'Sales': 8.82, 'Quantity': 2, 'Discount': 0.0, 'Profit': 4.0572}
# {'_id': ObjectId('68e63b562e1853074f2a80c4'), 'Row ID': 276, 'Order ID': 'CA-2017-118136', 'Order Date': datetime.datetime(2017, 9, 16, 0, 0), 'Ship Date': datetime.datetime(2017, 9, 17, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'BB-10990', 'Customer Name': 'Barry Blumstein', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Inglewood', 'State': 'California', 'Postal Code': 90301, 'Region': 'West', 'Product ID': 'OFF-AR-10001427', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Newell 330', 'Sales': 5.98, 'Quantity': 1, 'Discount': 0.0, 'Profit': 1.5548}
# {'_id': ObjectId('68e63b562e1853074f2a80cb'), 'Row ID': 283, 'Order ID': 'CA-2015-130890', 'Order Date': datetime.datetime(2015, 11, 2, 0, 0), 'Ship Date': datetime.datetime(2015, 11, 6, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JO-15280', 'Customer Name': "Jas O'Carroll", 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'FUR-TA-10002903', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bevis Round Bullnose 29" High Table Top', 'Sales': 1038.84, 'Quantity': 5, 'Discount': 0.2, 'Profit': 51.942}
# {'_id': ObjectId('68e63b562e1853074f2a80cc'), 'Row ID': 284, 'Order ID': 'CA-2015-130883', 'Order Date': datetime.datetime(2015, 9, 26, 0, 0), 'Ship Date': datetime.datetime(2015, 10, 2, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Portland', 'State': 'Oregon', 'Postal Code': 97206, 'Region': 'West', 'Product ID': 'OFF-PA-10000474', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Easy-staple paper', 'Sales': 141.76, 'Quantity': 5, 'Discount': 0.2, 'Profit': 47.844}
# {'_id': ObjectId('68e63b562e1853074f2a80cd'), 'Row ID': 285, 'Order ID': 'CA-2015-130883', 'Order Date': datetime.datetime(2015, 9, 26, 0, 0), 'Ship Date': datetime.datetime(2015, 10, 2, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Portland', 'State': 'Oregon', 'Postal Code': 97206, 'Region': 'West', 'Product ID': 'TEC-AC-10001956', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Microsoft Arc Touch Mouse', 'Sales': 239.8, 'Quantity': 5, 'Discount': 0.2, 'Profit': 47.96}
# {'_id': ObjectId('68e63b562e1853074f2a80ce'), 'Row ID': 286, 'Order ID': 'CA-2015-130883', 'Order Date': datetime.datetime(2015, 9, 26, 0, 0), 'Ship Date': datetime.datetime(2015, 10, 2, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Portland', 'State': 'Oregon', 'Postal Code': 97206, 'Region': 'West', 'Product ID': 'OFF-PA-10004100', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 216', 'Sales': 31.104, 'Quantity': 6, 'Discount': 0.2, 'Profit': 10.8864}
# {'_id': ObjectId('68e63b562e1853074f2a80d6'), 'Row ID': 294, 'Order ID': 'CA-2014-111451', 'Order Date': datetime.datetime(2014, 12, 26, 0, 0), 'Ship Date': datetime.datetime(2014, 12, 28, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'KL-16555', 'Customer Name': 'Kelly Lampkin', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Colorado Springs', 'State': 'Colorado', 'Postal Code': 80906, 'Region': 'West', 'Product ID': 'FUR-FU-10004091', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Howard Miller 13" Diameter Goldtone Round Wall Clock', 'Sales': 300.416, 'Quantity': 8, 'Discount': 0.2, 'Profit': 78.8592}
# {'_id': ObjectId('68e63b562e1853074f2a80d7'), 'Row ID': 295, 'Order ID': 'CA-2014-111451', 'Order Date': datetime.datetime(2014, 12, 26, 0, 0), 'Ship Date': datetime.datetime(2014, 12, 28, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'KL-16555', 'Customer Name': 'Kelly Lampkin', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Colorado Springs', 'State': 'Colorado', 'Postal Code': 80906, 'Region': 'West', 'Product ID': 'FUR-CH-10001891', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Global Deluxe Office Fabric Chairs', 'Sales': 230.352, 'Quantity': 3, 'Discount': 0.2, 'Profit': 20.1558}
# {'_id': ObjectId('68e63b562e1853074f2a80d8'), 'Row ID': 296, 'Order ID': 'CA-2014-111451', 'Order Date': datetime.datetime(2014, 12, 26, 0, 0), 'Ship Date': datetime.datetime(2014, 12, 28, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'KL-16555', 'Customer Name': 'Kelly Lampkin', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Colorado Springs', 'State': 'Colorado', 'Postal Code': 80906, 'Region': 'West', 'Product ID': 'FUR-FU-10002918', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Eldon ClusterMat Chair Mat with Cordless Antistatic Protection', 'Sales': 218.352, 'Quantity': 3, 'Discount': 0.2, 'Profit': -24.5646}
# {'_id': ObjectId('68e63b562e1853074f2a80d9'), 'Row ID': 297, 'Order ID': 'CA-2014-111451', 'Order Date': datetime.datetime(2014, 12, 26, 0, 0), 'Ship Date': datetime.datetime(2014, 12, 28, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'KL-16555', 'Customer Name': 'Kelly Lampkin', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Colorado Springs', 'State': 'Colorado', 'Postal Code': 80906, 'Region': 'West', 'Product ID': 'OFF-BI-10004593', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Ibico Laser Imprintable Binding System Covers', 'Sales': 78.6, 'Quantity': 5, 'Discount': 0.7, 'Profit': -62.88}
# {'_id': ObjectId('68e63b562e1853074f2a80da'), 'Row ID': 298, 'Order ID': 'CA-2014-111451', 'Order Date': datetime.datetime(2014, 12, 26, 0, 0), 'Ship Date': datetime.datetime(2014, 12, 28, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'KL-16555', 'Customer Name': 'Kelly Lampkin', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Colorado Springs', 'State': 'Colorado', 'Postal Code': 80906, 'Region': 'West', 'Product ID': 'OFF-FA-10004854', 'Category': 'Office Supplies', 'Sub-Category': 'Fasteners', 'Product Name': 'Vinyl Coated Wire Paper Clips in Organizer Box, 800/Box', 'Sales': 27.552, 'Quantity': 3, 'Discount': 0.2, 'Profit': 9.2988}
# {'_id': ObjectId('68e63b562e1853074f2a80e6'), 'Row ID': 310, 'Order ID': 'CA-2016-142902', 'Order Date': datetime.datetime(2016, 9, 12, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 14, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'BP-11185', 'Customer Name': 'Ben Peterman', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Arvada', 'State': 'Colorado', 'Postal Code': 80004, 'Region': 'West', 'Product ID': 'FUR-FU-10001918', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'C-Line Cubicle Keepers Polyproplyene Holder With Velcro Backings', 'Sales': 15.136, 'Quantity': 4, 'Discount': 0.2, 'Profit': 3.5948}
# {'_id': ObjectId('68e63b562e1853074f2a80e7'), 'Row ID': 311, 'Order ID': 'CA-2016-142902', 'Order Date': datetime.datetime(2016, 9, 12, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 14, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'BP-11185', 'Customer Name': 'Ben Peterman', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Arvada', 'State': 'Colorado', 'Postal Code': 80004, 'Region': 'West', 'Product ID': 'FUR-CH-10004086', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Hon 4070 Series Pagoda Armless Upholstered Stacking Chairs', 'Sales': 466.768, 'Quantity': 2, 'Discount': 0.2, 'Profit': 52.5114}
# {'_id': ObjectId('68e63b562e1853074f2a80e8'), 'Row ID': 312, 'Order ID': 'CA-2016-142902', 'Order Date': datetime.datetime(2016, 9, 12, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 14, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'BP-11185', 'Customer Name': 'Ben Peterman', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Arvada', 'State': 'Colorado', 'Postal Code': 80004, 'Region': 'West', 'Product ID': 'FUR-FU-10001756', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Eldon Expressions Desk Accessory, Wood Photo Frame, Mahogany', 'Sales': 15.232, 'Quantity': 1, 'Discount': 0.2, 'Profit': 1.7136}
# {'_id': ObjectId('68e63b562e1853074f2a80e9'), 'Row ID': 313, 'Order ID': 'CA-2016-142902', 'Order Date': datetime.datetime(2016, 9, 12, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 14, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'BP-11185', 'Customer Name': 'Ben Peterman', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Arvada', 'State': 'Colorado', 'Postal Code': 80004, 'Region': 'West', 'Product ID': 'OFF-LA-10000634', 'Category': 'Office Supplies', 'Sub-Category': 'Labels', 'Product Name': 'Avery 509', 'Sales': 6.264, 'Quantity': 3, 'Discount': 0.2, 'Profit': 2.0358}
# {'_id': ObjectId('68e63b562e1853074f2a80f3'), 'Row ID': 323, 'Order ID': 'CA-2014-156601', 'Order Date': datetime.datetime(2014, 9, 19, 0, 0), 'Ship Date': datetime.datetime(2014, 9, 24, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'FA-14230', 'Customer Name': 'Frank Atkinson', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Long Beach', 'State': 'California', 'Postal Code': 90805, 'Region': 'West', 'Product ID': 'OFF-FA-10000624', 'Category': 'Office Supplies', 'Sub-Category': 'Fasteners', 'Product Name': 'OIC Binder Clips', 'Sales': 7.16, 'Quantity': 2, 'Discount': 0.0, 'Profit': 3.58}
# {'_id': ObjectId('68e63b562e1853074f2a80f4'), 'Row ID': 324, 'Order ID': 'CA-2016-162138', 'Order Date': datetime.datetime(2016, 4, 23, 0, 0), 'Ship Date': datetime.datetime(2016, 4, 27, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'GK-14620', 'Customer Name': 'Grace Kelly', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Hesperia', 'State': 'California', 'Postal Code': 92345, 'Region': 'West', 'Product ID': 'OFF-BI-10004593', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Ibico Laser Imprintable Binding System Covers', 'Sales': 251.52, 'Quantity': 6, 'Discount': 0.2, 'Profit': 81.744}
# {'_id': ObjectId('68e63b562e1853074f2a80f5'), 'Row ID': 325, 'Order ID': 'CA-2016-162138', 'Order Date': datetime.datetime(2016, 4, 23, 0, 0), 'Ship Date': datetime.datetime(2016, 4, 27, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'GK-14620', 'Customer Name': 'Grace Kelly', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Hesperia', 'State': 'California', 'Postal Code': 92345, 'Region': 'West', 'Product ID': 'TEC-AC-10001908', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Logitech Wireless Headset h800', 'Sales': 99.99, 'Quantity': 1, 'Discount': 0.0, 'Profit': 34.9965}
# {'_id': ObjectId('68e63b562e1853074f2a80ff'), 'Row ID': 335, 'Order ID': 'CA-2015-137946', 'Order Date': datetime.datetime(2015, 9, 1, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 4, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'DB-13615', 'Customer Name': 'Doug Bickford', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90045, 'Region': 'West', 'Product ID': 'OFF-BI-10001922', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Storex Dura Pro Binders', 'Sales': 4.752, 'Quantity': 1, 'Discount': 0.2, 'Profit': 1.6038}
# {'_id': ObjectId('68e63b562e1853074f2a8100'), 'Row ID': 336, 'Order ID': 'CA-2015-137946', 'Order Date': datetime.datetime(2015, 9, 1, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 4, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'DB-13615', 'Customer Name': 'Doug Bickford', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90045, 'Region': 'West', 'Product ID': 'TEC-CO-10001449', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Hewlett Packard LaserJet 3310 Copier', 'Sales': 959.984, 'Quantity': 2, 'Discount': 0.2, 'Profit': 335.9944}
# {'_id': ObjectId('68e63b562e1853074f2a8101'), 'Row ID': 337, 'Order ID': 'CA-2015-137946', 'Order Date': datetime.datetime(2015, 9, 1, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 4, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'DB-13615', 'Customer Name': 'Doug Bickford', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90045, 'Region': 'West', 'Product ID': 'OFF-BI-10004140', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Avery Non-Stick Binders', 'Sales': 14.368, 'Quantity': 4, 'Discount': 0.2, 'Profit': 4.49}
# {'_id': ObjectId('68e63b562e1853074f2a8102'), 'Row ID': 338, 'Order ID': 'CA-2014-129924', 'Order Date': datetime.datetime(2014, 7, 12, 0, 0), 'Ship Date': datetime.datetime(2014, 7, 17, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'AC-10420', 'Customer Name': 'Alyssa Crouse', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94122, 'Region': 'West', 'Product ID': 'OFF-BI-10003314', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Tuff Stuff Recycled Round Ring Binders', 'Sales': 7.712, 'Quantity': 2, 'Discount': 0.2, 'Profit': 2.7956}

# %% [markdown]
# Question 5. Write a query to find orders where Sales is greater than 500.
#
# Answer:

# %%
query = {"Sales": {"$gt": 500}}

# Count documents matching the query directly
count = collection.count_documents(query)

print(f"Number of orders with Sales > 500: {count}")
print("---------------------------------------------")

# Fetch and print the matching documents
high_sales_orders = collection.find(query)

print("Printing just 100 orders where sales is greater than 500, although there are 1162 such orders.")

for order in collection.find(query).limit(100):
    print(order)
# Out:
# Number of orders with Sales > 500: 1162
# ---------------------------------------------
# Printing just 100 orders where sales is greater than 500, although there are 1162 such orders.
# {'_id': ObjectId('68e63b562e1853074f2a7fb2'), 'Row ID': 2, 'Order ID': 'CA-2016-152156', 'Order Date': datetime.datetime(2016, 11, 8, 0, 0), 'Ship Date': datetime.datetime(2016, 11, 11, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'CG-12520', 'Customer Name': 'Claire Gute', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Henderson', 'State': 'Kentucky', 'Postal Code': 42420, 'Region': 'South', 'Product ID': 'FUR-CH-10000454', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back', 'Sales': 731.94, 'Quantity': 3, 'Discount': 0.0, 'Profit': 219.582}
# {'_id': ObjectId('68e63b562e1853074f2a7fb4'), 'Row ID': 4, 'Order ID': 'US-2015-108966', 'Order Date': datetime.datetime(2015, 10, 11, 0, 0), 'Ship Date': datetime.datetime(2015, 10, 18, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'SO-20335', 'Customer Name': "Sean O'Donnell", 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Fort Lauderdale', 'State': 'Florida', 'Postal Code': 33311, 'Region': 'South', 'Product ID': 'FUR-TA-10000577', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bretford CR4500 Series Slim Rectangular Table', 'Sales': 957.5775, 'Quantity': 5, 'Discount': 0.45, 'Profit': -383.031}
# {'_id': ObjectId('68e63b562e1853074f2a7fb8'), 'Row ID': 8, 'Order ID': 'CA-2014-115812', 'Order Date': datetime.datetime(2014, 6, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'TEC-PH-10002275', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Mitel 5320 IP Phone VoIP phone', 'Sales': 907.152, 'Quantity': 6, 'Discount': 0.2, 'Profit': 90.7152}
# {'_id': ObjectId('68e63b562e1853074f2a7fbb'), 'Row ID': 11, 'Order ID': 'CA-2014-115812', 'Order Date': datetime.datetime(2014, 6, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'FUR-TA-10001539', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Chromcraft Rectangular Conference Tables', 'Sales': 1706.184, 'Quantity': 9, 'Discount': 0.2, 'Profit': 85.3092}
# {'_id': ObjectId('68e63b562e1853074f2a7fbc'), 'Row ID': 12, 'Order ID': 'CA-2014-115812', 'Order Date': datetime.datetime(2014, 6, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 14, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'TEC-PH-10002033', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Konftel 250 Conference\xa0phone\xa0- Charcoal black', 'Sales': 911.424, 'Quantity': 4, 'Discount': 0.2, 'Profit': 68.3568}
# {'_id': ObjectId('68e63b562e1853074f2a7fc1'), 'Row ID': 17, 'Order ID': 'CA-2014-105893', 'Order Date': datetime.datetime(2014, 11, 11, 0, 0), 'Ship Date': datetime.datetime(2014, 11, 18, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'PK-19075', 'Customer Name': 'Pete Kriz', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Madison', 'State': 'Wisconsin', 'Postal Code': 53711, 'Region': 'Central', 'Product ID': 'OFF-ST-10004186', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Stur-D-Stor Shelving, Vertical 5-Shelf: 72"H x 36"W x 18 1/2"D', 'Sales': 665.88, 'Quantity': 6, 'Discount': 0.0, 'Profit': 13.3176}
# {'_id': ObjectId('68e63b562e1853074f2a7fc9'), 'Row ID': 25, 'Order ID': 'CA-2015-106320', 'Order Date': datetime.datetime(2015, 9, 25, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 30, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'EB-13870', 'Customer Name': 'Emily Burns', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Orem', 'State': 'Utah', 'Postal Code': 84057, 'Region': 'West', 'Product ID': 'FUR-TA-10000577', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bretford CR4500 Series Slim Rectangular Table', 'Sales': 1044.63, 'Quantity': 3, 'Discount': 0.0, 'Profit': 240.2649}
# {'_id': ObjectId('68e63b562e1853074f2a7fcc'), 'Row ID': 28, 'Order ID': 'US-2015-150630', 'Order Date': datetime.datetime(2015, 9, 17, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 21, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'FUR-BO-10004834', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish', 'Sales': 3083.43, 'Quantity': 7, 'Discount': 0.5, 'Profit': -1665.0522}
# {'_id': ObjectId('68e63b562e1853074f2a7fd4'), 'Row ID': 36, 'Order ID': 'CA-2016-117590', 'Order Date': datetime.datetime(2016, 12, 8, 0, 0), 'Ship Date': datetime.datetime(2016, 12, 10, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'GH-14485', 'Customer Name': 'Gene Hale', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Richardson', 'State': 'Texas', 'Postal Code': 75080, 'Region': 'Central', 'Product ID': 'TEC-PH-10004977', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'GE 30524EE4', 'Sales': 1097.544, 'Quantity': 7, 'Discount': 0.2, 'Profit': 123.4737}
# {'_id': ObjectId('68e63b562e1853074f2a7fd7'), 'Row ID': 39, 'Order ID': 'CA-2015-117415', 'Order Date': datetime.datetime(2015, 12, 27, 0, 0), 'Ship Date': datetime.datetime(2015, 12, 31, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'SN-20710', 'Customer Name': 'Steve Nguyen', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'FUR-BO-10002545', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Atlantic Metals Mobile 3-Shelf Bookcases, Custom Colors', 'Sales': 532.3992, 'Quantity': 3, 'Discount': 0.32, 'Profit': -46.9764}
# {'_id': ObjectId('68e63b562e1853074f2a7fe7'), 'Row ID': 55, 'Order ID': 'CA-2016-105816', 'Order Date': datetime.datetime(2016, 12, 11, 0, 0), 'Ship Date': datetime.datetime(2016, 12, 17, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JM-15265', 'Customer Name': 'Janet Molinari', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10024, 'Region': 'East', 'Product ID': 'TEC-PH-10002447', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'AT&T CL83451 4-Handset Telephone', 'Sales': 1029.95, 'Quantity': 5, 'Discount': 0.0, 'Profit': 298.6855}
# {'_id': ObjectId('68e63b562e1853074f2a7ff4'), 'Row ID': 68, 'Order ID': 'CA-2014-106376', 'Order Date': datetime.datetime(2014, 12, 5, 0, 0), 'Ship Date': datetime.datetime(2014, 12, 10, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BS-11590', 'Customer Name': 'Brendan Sweed', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Gilbert', 'State': 'Arizona', 'Postal Code': 85234, 'Region': 'West', 'Product ID': 'OFF-AR-10002671', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Hunt BOSTON Model 1606 High-Volume Electric Pencil Sharpener, Beige', 'Sales': 1113.024, 'Quantity': 8, 'Discount': 0.2, 'Profit': 111.3024}
# {'_id': ObjectId('68e63b562e1853074f2a7ff9'), 'Row ID': 73, 'Order ID': 'US-2015-134026', 'Order Date': datetime.datetime(2015, 4, 26, 0, 0), 'Ship Date': datetime.datetime(2015, 5, 2, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JE-15745', 'Customer Name': 'Joel Eaton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Memphis', 'State': 'Tennessee', 'Postal Code': 38109, 'Region': 'South', 'Product ID': 'FUR-CH-10000513', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': "High-Back Leather Manager's Chair", 'Sales': 831.936, 'Quantity': 8, 'Discount': 0.2, 'Profit': -114.3912}
# {'_id': ObjectId('68e63b562e1853074f2a8026'), 'Row ID': 118, 'Order ID': 'CA-2015-110457', 'Order Date': datetime.datetime(2015, 3, 2, 0, 0), 'Ship Date': datetime.datetime(2015, 3, 6, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'DK-13090', 'Customer Name': 'Dave Kipp', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98103, 'Region': 'West', 'Product ID': 'FUR-TA-10001768', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Hon Racetrack Conference Tables', 'Sales': 787.53, 'Quantity': 3, 'Discount': 0.0, 'Profit': 165.3813}
# {'_id': ObjectId('68e63b562e1853074f2a802d'), 'Row ID': 125, 'Order ID': 'US-2014-152030', 'Order Date': datetime.datetime(2014, 12, 26, 0, 0), 'Ship Date': datetime.datetime(2014, 12, 28, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'AD-10180', 'Customer Name': 'Alan Dominguez', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'FUR-CH-10004063', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': "Global Deluxe High-Back Manager's Chair", 'Sales': 600.558, 'Quantity': 3, 'Discount': 0.3, 'Profit': -8.5794}
# {'_id': ObjectId('68e63b562e1853074f2a802e'), 'Row ID': 126, 'Order ID': 'US-2014-134614', 'Order Date': datetime.datetime(2014, 9, 20, 0, 0), 'Ship Date': datetime.datetime(2014, 9, 25, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'PF-19165', 'Customer Name': 'Philip Fox', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Bloomington', 'State': 'Illinois', 'Postal Code': 61701, 'Region': 'Central', 'Product ID': 'FUR-TA-10004534', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bevis 44 x 96 Conference Tables', 'Sales': 617.7, 'Quantity': 6, 'Discount': 0.5, 'Profit': -407.682}
# {'_id': ObjectId('68e63b562e1853074f2a8041'), 'Row ID': 145, 'Order ID': 'CA-2017-155376', 'Order Date': datetime.datetime(2017, 12, 22, 0, 0), 'Ship Date': datetime.datetime(2017, 12, 27, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'SG-20080', 'Customer Name': 'Sandra Glassco', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Independence', 'State': 'Missouri', 'Postal Code': 64055, 'Region': 'Central', 'Product ID': 'OFF-AP-10001058', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': 'Sanyo 2.5 Cubic Foot Mid-Size Office Refrigerators', 'Sales': 839.43, 'Quantity': 3, 'Discount': 0.0, 'Profit': 218.2518}
# {'_id': ObjectId('68e63b562e1853074f2a8042'), 'Row ID': 146, 'Order ID': 'CA-2015-110744', 'Order Date': datetime.datetime(2015, 9, 7, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 12, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'HA-14920', 'Customer Name': 'Helen Andreada', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Pasadena', 'State': 'California', 'Postal Code': 91104, 'Region': 'West', 'Product ID': 'OFF-ST-10003656', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Safco Industrial Wire Shelving', 'Sales': 671.93, 'Quantity': 7, 'Discount': 0.0, 'Profit': 20.1579}
# {'_id': ObjectId('68e63b562e1853074f2a8046'), 'Row ID': 150, 'Order ID': 'CA-2016-114489', 'Order Date': datetime.datetime(2016, 12, 5, 0, 0), 'Ship Date': datetime.datetime(2016, 12, 9, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JE-16165', 'Customer Name': 'Justin Ellison', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Franklin', 'State': 'Wisconsin', 'Postal Code': 53132, 'Region': 'Central', 'Product ID': 'FUR-CH-10000454', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back', 'Sales': 1951.84, 'Quantity': 8, 'Discount': 0.0, 'Profit': 585.552}
# {'_id': ObjectId('68e63b562e1853074f2a8050'), 'Row ID': 160, 'Order ID': 'CA-2016-114104', 'Order Date': datetime.datetime(2016, 11, 20, 0, 0), 'Ship Date': datetime.datetime(2016, 11, 24, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'NP-18670', 'Customer Name': 'Nora Paige', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Edmond', 'State': 'Oklahoma', 'Postal Code': 73034, 'Region': 'Central', 'Product ID': 'TEC-PH-10004536', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Avaya 5420 Digital phone', 'Sales': 944.93, 'Quantity': 7, 'Discount': 0.0, 'Profit': 236.2325}
# {'_id': ObjectId('68e63b562e1853074f2a8056'), 'Row ID': 166, 'Order ID': 'CA-2014-139892', 'Order Date': datetime.datetime(2014, 9, 8, 0, 0), 'Ship Date': datetime.datetime(2014, 9, 12, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BM-11140', 'Customer Name': 'Becky Martin', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Antonio', 'State': 'Texas', 'Postal Code': 78207, 'Region': 'Central', 'Product ID': 'TEC-MA-10000822', 'Category': 'Technology', 'Sub-Category': 'Machines', 'Product Name': 'Lexmark MX611dhe Monochrome Laser Printer', 'Sales': 8159.952, 'Quantity': 8, 'Discount': 0.4, 'Profit': -1359.992}
# {'_id': ObjectId('68e63b562e1853074f2a8058'), 'Row ID': 168, 'Order ID': 'CA-2014-139892', 'Order Date': datetime.datetime(2014, 9, 8, 0, 0), 'Ship Date': datetime.datetime(2014, 9, 12, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'BM-11140', 'Customer Name': 'Becky Martin', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Antonio', 'State': 'Texas', 'Postal Code': 78207, 'Region': 'Central', 'Product ID': 'FUR-CH-10004287', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'SAFCO Arco Folding Chair', 'Sales': 1740.06, 'Quantity': 9, 'Discount': 0.3, 'Profit': -24.858}
# {'_id': ObjectId('68e63b562e1853074f2a8067'), 'Row ID': 183, 'Order ID': 'CA-2014-158274', 'Order Date': datetime.datetime(2014, 11, 19, 0, 0), 'Ship Date': datetime.datetime(2014, 11, 24, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'RM-19675', 'Customer Name': 'Robert Marley', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Monroe', 'State': 'Louisiana', 'Postal Code': 71203, 'Region': 'South', 'Product ID': 'TEC-PH-10003273', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'AT&T TR1909W', 'Sales': 503.96, 'Quantity': 4, 'Discount': 0.0, 'Profit': 131.0296}
# {'_id': ObjectId('68e63b562e1853074f2a806e'), 'Row ID': 190, 'Order ID': 'CA-2015-102281', 'Order Date': datetime.datetime(2015, 10, 12, 0, 0), 'Ship Date': datetime.datetime(2015, 10, 14, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'MP-17470', 'Customer Name': 'Mark Packer', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10035, 'Region': 'East', 'Product ID': 'FUR-BO-10002613', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Atlantic Metals Mobile 4-Shelf Bookcases, Custom Colors', 'Sales': 899.136, 'Quantity': 4, 'Discount': 0.2, 'Profit': 112.392}
# {'_id': ObjectId('68e63b562e1853074f2a8071'), 'Row ID': 193, 'Order ID': 'CA-2015-102281', 'Order Date': datetime.datetime(2015, 10, 12, 0, 0), 'Ship Date': datetime.datetime(2015, 10, 14, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'MP-17470', 'Customer Name': 'Mark Packer', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10035, 'Region': 'East', 'Product ID': 'FUR-BO-10002545', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Atlantic Metals Mobile 3-Shelf Bookcases, Custom Colors', 'Sales': 626.352, 'Quantity': 3, 'Discount': 0.2, 'Profit': 46.9764}
# {'_id': ObjectId('68e63b562e1853074f2a8088'), 'Row ID': 216, 'Order ID': 'CA-2015-146262', 'Order Date': datetime.datetime(2015, 1, 2, 0, 0), 'Ship Date': datetime.datetime(2015, 1, 9, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'VW-21775', 'Customer Name': 'Victoria Wilson', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Medina', 'State': 'Ohio', 'Postal Code': 44256, 'Region': 'East', 'Product ID': 'TEC-MA-10000864', 'Category': 'Technology', 'Sub-Category': 'Machines', 'Product Name': 'Cisco 9971 IP Video Phone Charcoal', 'Sales': 1188.0, 'Quantity': 9, 'Discount': 0.7, 'Profit': -950.4}
# {'_id': ObjectId('68e63b562e1853074f2a8093'), 'Row ID': 227, 'Order ID': 'CA-2015-163055', 'Order Date': datetime.datetime(2015, 8, 9, 0, 0), 'Ship Date': datetime.datetime(2015, 8, 16, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'DS-13180', 'Customer Name': 'David Smith', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Detroit', 'State': 'Michigan', 'Postal Code': 48227, 'Region': 'Central', 'Product ID': 'FUR-TA-10003748', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bevis 36 x 72 Conference Tables', 'Sales': 622.45, 'Quantity': 5, 'Discount': 0.0, 'Profit': 136.939}
# {'_id': ObjectId('68e63b562e1853074f2a8099'), 'Row ID': 233, 'Order ID': 'US-2017-100930', 'Order Date': datetime.datetime(2017, 4, 7, 0, 0), 'Ship Date': datetime.datetime(2017, 4, 12, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'CS-12400', 'Customer Name': 'Christopher Schild', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Tampa', 'State': 'Florida', 'Postal Code': 33614, 'Region': 'South', 'Product ID': 'FUR-TA-10003473', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bretford Rectangular Conference Table Tops', 'Sales': 620.6145, 'Quantity': 3, 'Discount': 0.45, 'Profit': -248.2458}
# {'_id': ObjectId('68e63b562e1853074f2a809c'), 'Row ID': 236, 'Order ID': 'US-2017-100930', 'Order Date': datetime.datetime(2017, 4, 7, 0, 0), 'Ship Date': datetime.datetime(2017, 4, 12, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'CS-12400', 'Customer Name': 'Christopher Schild', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Tampa', 'State': 'Florida', 'Postal Code': 33614, 'Region': 'South', 'Product ID': 'TEC-AC-10003832', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Logitech\xa0P710e Mobile Speakerphone', 'Sales': 617.976, 'Quantity': 3, 'Discount': 0.2, 'Profit': -7.7247}
# {'_id': ObjectId('68e63b562e1853074f2a80a5'), 'Row ID': 245, 'Order ID': 'CA-2014-131926', 'Order Date': datetime.datetime(2014, 6, 1, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 6, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'DW-13480', 'Customer Name': 'Dianna Wilson', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Lakeville', 'State': 'Minnesota', 'Postal Code': 55044, 'Region': 'Central', 'Product ID': 'FUR-CH-10004063', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': "Global Deluxe High-Back Manager's Chair", 'Sales': 2001.86, 'Quantity': 7, 'Discount': 0.0, 'Profit': 580.5394}
# {'_id': ObjectId('68e63b562e1853074f2a80a8'), 'Row ID': 248, 'Order ID': 'CA-2014-131926', 'Order Date': datetime.datetime(2014, 6, 1, 0, 0), 'Ship Date': datetime.datetime(2014, 6, 6, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'DW-13480', 'Customer Name': 'Dianna Wilson', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Lakeville', 'State': 'Minnesota', 'Postal Code': 55044, 'Region': 'Central', 'Product ID': 'OFF-AP-10002945', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': "Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room", 'Sales': 1503.25, 'Quantity': 5, 'Discount': 0.0, 'Profit': 496.0725}
# {'_id': ObjectId('68e63b562e1853074f2a80ac'), 'Row ID': 252, 'Order ID': 'CA-2016-145625', 'Order Date': datetime.datetime(2016, 9, 11, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 17, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'KC-16540', 'Customer Name': 'Kelly Collister', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Diego', 'State': 'California', 'Postal Code': 92037, 'Region': 'West', 'Product ID': 'TEC-AC-10003832', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Logitech\xa0P710e Mobile Speakerphone', 'Sales': 3347.37, 'Quantity': 13, 'Discount': 0.0, 'Profit': 636.0003}
# {'_id': ObjectId('68e63b562e1853074f2a80b2'), 'Row ID': 258, 'Order ID': 'US-2015-159982', 'Order Date': datetime.datetime(2015, 11, 28, 0, 0), 'Ship Date': datetime.datetime(2015, 12, 4, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'DR-12880', 'Customer Name': 'Dan Reichenbach', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Chicago', 'State': 'Illinois', 'Postal Code': 60623, 'Region': 'Central', 'Product ID': 'TEC-PH-10001580', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Logitech Mobile Speakerphone P710e -\xa0speaker phone', 'Sales': 647.904, 'Quantity': 6, 'Discount': 0.2, 'Profit': 56.6916}
# {'_id': ObjectId('68e63b562e1853074f2a80b7'), 'Row ID': 263, 'Order ID': 'US-2014-106992', 'Order Date': datetime.datetime(2014, 9, 19, 0, 0), 'Ship Date': datetime.datetime(2014, 9, 21, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'SB-20290', 'Customer Name': 'Sean Braxton', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77036, 'Region': 'Central', 'Product ID': 'TEC-MA-10000822', 'Category': 'Technology', 'Sub-Category': 'Machines', 'Product Name': 'Lexmark MX611dhe Monochrome Laser Printer', 'Sales': 3059.982, 'Quantity': 3, 'Discount': 0.4, 'Profit': -509.997}
# {'_id': ObjectId('68e63b562e1853074f2a80b8'), 'Row ID': 264, 'Order ID': 'US-2014-106992', 'Order Date': datetime.datetime(2014, 9, 19, 0, 0), 'Ship Date': datetime.datetime(2014, 9, 21, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'SB-20290', 'Customer Name': 'Sean Braxton', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77036, 'Region': 'Central', 'Product ID': 'TEC-MA-10003353', 'Category': 'Technology', 'Sub-Category': 'Machines', 'Product Name': 'Xerox WorkCentre 6505DN Laser Multifunction Printer', 'Sales': 2519.958, 'Quantity': 7, 'Discount': 0.4, 'Profit': -251.9958}
# {'_id': ObjectId('68e63b562e1853074f2a80bf'), 'Row ID': 271, 'Order ID': 'CA-2017-163979', 'Order Date': datetime.datetime(2017, 12, 28, 0, 0), 'Ship Date': datetime.datetime(2018, 1, 2, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'KH-16690', 'Customer Name': 'Kristen Hastings', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'OFF-ST-10003208', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Adjustable Depth Letter/Legal Cart', 'Sales': 725.84, 'Quantity': 4, 'Discount': 0.0, 'Profit': 210.4936}
# {'_id': ObjectId('68e63b562e1853074f2a80ca'), 'Row ID': 282, 'Order ID': 'US-2015-161991', 'Order Date': datetime.datetime(2015, 9, 26, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 28, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'SC-20725', 'Customer Name': 'Steven Cartwright', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77070, 'Region': 'Central', 'Product ID': 'TEC-PH-10001760', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Bose SoundLink Bluetooth Speaker', 'Sales': 1114.4, 'Quantity': 7, 'Discount': 0.2, 'Profit': 376.11}
# {'_id': ObjectId('68e63b562e1853074f2a80cb'), 'Row ID': 283, 'Order ID': 'CA-2015-130890', 'Order Date': datetime.datetime(2015, 11, 2, 0, 0), 'Ship Date': datetime.datetime(2015, 11, 6, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JO-15280', 'Customer Name': "Jas O'Carroll", 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'FUR-TA-10002903', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bevis Round Bullnose 29" High Table Top', 'Sales': 1038.84, 'Quantity': 5, 'Discount': 0.2, 'Profit': 51.942}
# {'_id': ObjectId('68e63b562e1853074f2a80d1'), 'Row ID': 289, 'Order ID': 'CA-2016-112697', 'Order Date': datetime.datetime(2016, 12, 18, 0, 0), 'Ship Date': datetime.datetime(2016, 12, 20, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'AH-10195', 'Customer Name': 'Alan Haines', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Tamarac', 'State': 'Florida', 'Postal Code': 33319, 'Region': 'South', 'Product ID': 'OFF-SU-10000646', 'Category': 'Office Supplies', 'Sub-Category': 'Supplies', 'Product Name': 'Premier Automatic Letter Opener', 'Sales': 961.48, 'Quantity': 5, 'Discount': 0.2, 'Profit': -204.3145}
# {'_id': ObjectId('68e63b562e1853074f2a80dc'), 'Row ID': 300, 'Order ID': 'CA-2016-142545', 'Order Date': datetime.datetime(2016, 10, 28, 0, 0), 'Ship Date': datetime.datetime(2016, 11, 3, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JD-15895', 'Customer Name': 'Jonathan Doherty', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Belleville', 'State': 'New Jersey', 'Postal Code': 7109, 'Region': 'East', 'Product ID': 'OFF-ST-10002756', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Tennsco Stur-D-Stor Boltless Shelving, 5 Shelves, 24" Deep, Sand', 'Sales': 1082.48, 'Quantity': 8, 'Discount': 0.0, 'Profit': 10.8248}
# {'_id': ObjectId('68e63b562e1853074f2a80ef'), 'Row ID': 319, 'Order ID': 'CA-2014-164973', 'Order Date': datetime.datetime(2014, 11, 4, 0, 0), 'Ship Date': datetime.datetime(2014, 11, 9, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'NM-18445', 'Customer Name': 'Nathan Mautz', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10024, 'Region': 'East', 'Product ID': 'TEC-MA-10002927', 'Category': 'Technology', 'Sub-Category': 'Machines', 'Product Name': 'Canon imageCLASS MF7460 Monochrome Digital Laser Multifunction Copier', 'Sales': 3991.98, 'Quantity': 2, 'Discount': 0.0, 'Profit': 1995.99}
# {'_id': ObjectId('68e63b562e1853074f2a80f9'), 'Row ID': 329, 'Order ID': 'US-2016-141544', 'Order Date': datetime.datetime(2016, 8, 30, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 1, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'PO-18850', 'Customer Name': "Patrick O'Brill", 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19143, 'Region': 'East', 'Product ID': 'FUR-CH-10003312', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Hon 2090 \x93Pillow Soft\x94 Series Mid Back Swivel/Tilt Chairs', 'Sales': 786.744, 'Quantity': 4, 'Discount': 0.3, 'Profit': -258.5016}
# {'_id': ObjectId('68e63b562e1853074f2a8100'), 'Row ID': 336, 'Order ID': 'CA-2015-137946', 'Order Date': datetime.datetime(2015, 9, 1, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 4, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'DB-13615', 'Customer Name': 'Doug Bickford', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90045, 'Region': 'West', 'Product ID': 'TEC-CO-10001449', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Hewlett Packard LaserJet 3310 Copier', 'Sales': 959.984, 'Quantity': 2, 'Discount': 0.2, 'Profit': 335.9944}
# {'_id': ObjectId('68e63b562e1853074f2a8103'), 'Row ID': 339, 'Order ID': 'CA-2014-129924', 'Order Date': datetime.datetime(2014, 7, 12, 0, 0), 'Ship Date': datetime.datetime(2014, 7, 17, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'AC-10420', 'Customer Name': 'Alyssa Crouse', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94122, 'Region': 'West', 'Product ID': 'FUR-TA-10004575', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Hon 5100 Series Wood Tables', 'Sales': 698.352, 'Quantity': 3, 'Discount': 0.2, 'Profit': -17.4588}
# {'_id': ObjectId('68e63b562e1853074f2a8106'), 'Row ID': 342, 'Order ID': 'CA-2014-122336', 'Order Date': datetime.datetime(2014, 4, 13, 0, 0), 'Ship Date': datetime.datetime(2014, 4, 17, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'JD-15895', 'Customer Name': 'Jonathan Doherty', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'OFF-BI-10003656', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Fellowes PB200 Plastic Comb Binding Machine', 'Sales': 509.97, 'Quantity': 10, 'Discount': 0.7, 'Profit': -407.976}
# {'_id': ObjectId('68e63b562e1853074f2a8112'), 'Row ID': 354, 'Order ID': 'CA-2016-129714', 'Order Date': datetime.datetime(2016, 9, 1, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 3, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'AB-10060', 'Customer Name': 'Adam Bellavance', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10009, 'Region': 'East', 'Product ID': 'OFF-BI-10004995', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'GBC DocuBind P400 Electric Binding System', 'Sales': 4355.168, 'Quantity': 4, 'Discount': 0.2, 'Profit': 1415.4296}
# {'_id': ObjectId('68e63b562e1853074f2a8118'), 'Row ID': 360, 'Order ID': 'CA-2017-155698', 'Order Date': datetime.datetime(2017, 3, 8, 0, 0), 'Ship Date': datetime.datetime(2017, 3, 11, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'VB-21745', 'Customer Name': 'Victoria Brennan', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Columbus', 'State': 'Georgia', 'Postal Code': 31907, 'Region': 'South', 'Product ID': 'OFF-AP-10001124', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': 'Belkin 8 Outlet SurgeMaster II Gold Surge Protector with Phone Protection', 'Sales': 647.84, 'Quantity': 8, 'Discount': 0.0, 'Profit': 168.4384}
# {'_id': ObjectId('68e63b562e1853074f2a8122'), 'Row ID': 370, 'Order ID': 'CA-2016-155516', 'Order Date': datetime.datetime(2016, 10, 21, 0, 0), 'Ship Date': datetime.datetime(2016, 10, 21, 0, 0), 'Ship Mode': 'Same Day', 'Customer ID': 'MK-17905', 'Customer Name': 'Michael Kennedy', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Manchester', 'State': 'Connecticut', 'Postal Code': 6040, 'Region': 'East', 'Product ID': 'FUR-BO-10002545', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Atlantic Metals Mobile 3-Shelf Bookcases, Custom Colors', 'Sales': 1043.92, 'Quantity': 4, 'Discount': 0.0, 'Profit': 271.4192}
# {'_id': ObjectId('68e63b562e1853074f2a8126'), 'Row ID': 374, 'Order ID': 'US-2014-119137', 'Order Date': datetime.datetime(2014, 7, 23, 0, 0), 'Ship Date': datetime.datetime(2014, 7, 27, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'AG-10900', 'Customer Name': 'Arthur Gainer', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Tucson', 'State': 'Arizona', 'Postal Code': 85705, 'Region': 'West', 'Product ID': 'TEC-AC-10003911', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'NETGEAR AC1750 Dual Band Gigabit\xa0Smart WiFi Router', 'Sales': 1023.936, 'Quantity': 8, 'Discount': 0.2, 'Profit': 179.1888}
# {'_id': ObjectId('68e63b562e1853074f2a812a'), 'Row ID': 378, 'Order ID': 'US-2017-134481', 'Order Date': datetime.datetime(2017, 8, 27, 0, 0), 'Ship Date': datetime.datetime(2017, 9, 1, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'AR-10405', 'Customer Name': 'Allen Rosenblatt', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Franklin', 'State': 'Massachusetts', 'Postal Code': 2038, 'Region': 'East', 'Product ID': 'FUR-TA-10004915', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Office Impressions End Table, 20-1/2"H x 24"W x 20"D', 'Sales': 1488.424, 'Quantity': 7, 'Discount': 0.3, 'Profit': -297.6848}
# {'_id': ObjectId('68e63b562e1853074f2a8139'), 'Row ID': 393, 'Order ID': 'US-2014-135972', 'Order Date': datetime.datetime(2014, 9, 21, 0, 0), 'Ship Date': datetime.datetime(2014, 9, 23, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'JG-15115', 'Customer Name': 'Jack Garza', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Des Moines', 'State': 'Washington', 'Postal Code': 98198, 'Region': 'West', 'Product ID': 'TEC-CO-10002313', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Canon PC1080F Personal Copier', 'Sales': 1799.97, 'Quantity': 3, 'Discount': 0.0, 'Profit': 701.9883}
# {'_id': ObjectId('68e63b562e1853074f2a8140'), 'Row ID': 400, 'Order ID': 'CA-2016-108987', 'Order Date': datetime.datetime(2016, 9, 8, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 10, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'AG-10675', 'Customer Name': 'Anna Gayman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77036, 'Region': 'Central', 'Product ID': 'FUR-BO-10004834', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish', 'Sales': 2396.2656, 'Quantity': 4, 'Discount': 0.32, 'Profit': -317.1528}
# {'_id': ObjectId('68e63b562e1853074f2a8147'), 'Row ID': 407, 'Order ID': 'CA-2017-117457', 'Order Date': datetime.datetime(2017, 12, 8, 0, 0), 'Ship Date': datetime.datetime(2017, 12, 12, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'KH-16510', 'Customer Name': 'Keith Herrera', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'TEC-CO-10004115', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Sharp AL-1530CS Digital Copier', 'Sales': 1199.976, 'Quantity': 3, 'Discount': 0.2, 'Profit': 434.9913}
# {'_id': ObjectId('68e63b562e1853074f2a8149'), 'Row ID': 409, 'Order ID': 'CA-2017-117457', 'Order Date': datetime.datetime(2017, 12, 8, 0, 0), 'Ship Date': datetime.datetime(2017, 12, 12, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'KH-16510', 'Customer Name': 'Keith Herrera', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'FUR-TA-10002041', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bevis Round Conference Table Top, X-Base', 'Sales': 1004.024, 'Quantity': 7, 'Discount': 0.2, 'Profit': -112.9527}
# {'_id': ObjectId('68e63b562e1853074f2a814d'), 'Row ID': 413, 'Order ID': 'CA-2017-117457', 'Order Date': datetime.datetime(2017, 12, 8, 0, 0), 'Ship Date': datetime.datetime(2017, 12, 12, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'KH-16510', 'Customer Name': 'Keith Herrera', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'FUR-BO-10001972', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': "O'Sullivan 4-Shelf Bookcase in Odessa Pine", 'Sales': 1336.829, 'Quantity': 13, 'Discount': 0.15, 'Profit': 31.4548}
# {'_id': ObjectId('68e63b562e1853074f2a8159'), 'Row ID': 425, 'Order ID': 'CA-2017-155705', 'Order Date': datetime.datetime(2017, 8, 21, 0, 0), 'Ship Date': datetime.datetime(2017, 8, 23, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'NF-18385', 'Customer Name': 'Natalie Fritzler', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Jackson', 'State': 'Mississippi', 'Postal Code': 39212, 'Region': 'South', 'Product ID': 'FUR-CH-10000015', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Hon Multipurpose Stacking Arm Chairs', 'Sales': 866.4, 'Quantity': 4, 'Discount': 0.0, 'Profit': 225.264}
# {'_id': ObjectId('68e63b562e1853074f2a8162'), 'Row ID': 434, 'Order ID': 'CA-2016-127369', 'Order Date': datetime.datetime(2016, 6, 6, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 7, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'DB-13060', 'Customer Name': 'Dave Brooks', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Lowell', 'State': 'Massachusetts', 'Postal Code': 1852, 'Region': 'East', 'Product ID': 'OFF-ST-10003306', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Letter Size Cart', 'Sales': 714.3, 'Quantity': 5, 'Discount': 0.0, 'Profit': 207.147}
# {'_id': ObjectId('68e63b562e1853074f2a8165'), 'Row ID': 437, 'Order ID': 'CA-2016-147375', 'Order Date': datetime.datetime(2016, 6, 12, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 14, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'PO-19180', 'Customer Name': 'Philisse Overcash', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Chicago', 'State': 'Illinois', 'Postal Code': 60623, 'Region': 'Central', 'Product ID': 'TEC-MA-10002937', 'Category': 'Technology', 'Sub-Category': 'Machines', 'Product Name': 'Canon Color ImageCLASS MF8580Cdw Wireless Laser All-In-One Printer, Copier, Scanner', 'Sales': 1007.979, 'Quantity': 3, 'Discount': 0.3, 'Profit': 43.1991}
# {'_id': ObjectId('68e63b562e1853074f2a8177'), 'Row ID': 455, 'Order ID': 'CA-2017-147277', 'Order Date': datetime.datetime(2017, 10, 20, 0, 0), 'Ship Date': datetime.datetime(2017, 10, 24, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'EB-13705', 'Customer Name': 'Ed Braxton', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Akron', 'State': 'Ohio', 'Postal Code': 44312, 'Region': 'East', 'Product ID': 'OFF-ST-10000142', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Deluxe Rollaway Locking File with Drawer', 'Sales': 665.408, 'Quantity': 2, 'Discount': 0.2, 'Profit': 66.5408}
# {'_id': ObjectId('68e63b562e1853074f2a817a'), 'Row ID': 458, 'Order ID': 'US-2016-157945', 'Order Date': datetime.datetime(2016, 9, 26, 0, 0), 'Ship Date': datetime.datetime(2016, 10, 1, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'NF-18385', 'Customer Name': 'Natalie Fritzler', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Decatur', 'State': 'Illinois', 'Postal Code': 62521, 'Region': 'Central', 'Product ID': 'FUR-CH-10002331', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Hon 4700 Series Mobuis Mid-Back Task Chairs with Adjustable Arms', 'Sales': 747.558, 'Quantity': 3, 'Discount': 0.3, 'Profit': -96.1146}
# {'_id': ObjectId('68e63b562e1853074f2a817d'), 'Row ID': 461, 'Order ID': 'CA-2015-109638', 'Order Date': datetime.datetime(2015, 12, 15, 0, 0), 'Ship Date': datetime.datetime(2015, 12, 22, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JH-15985', 'Customer Name': 'Joseph Holt', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98115, 'Region': 'West', 'Product ID': 'TEC-AC-10004571', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Logitech G700s Rechargeable Gaming Mouse', 'Sales': 899.91, 'Quantity': 9, 'Discount': 0.0, 'Profit': 377.9622}
# {'_id': ObjectId('68e63b562e1853074f2a8180'), 'Row ID': 464, 'Order ID': 'CA-2016-109869', 'Order Date': datetime.datetime(2016, 4, 22, 0, 0), 'Ship Date': datetime.datetime(2016, 4, 29, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'TN-21040', 'Customer Name': 'Tanja Norvell', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Phoenix', 'State': 'Arizona', 'Postal Code': 85023, 'Region': 'West', 'Product ID': 'FUR-TA-10001889', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bush Advantage Collection Racetrack Conference Table', 'Sales': 1272.63, 'Quantity': 6, 'Discount': 0.5, 'Profit': -814.4832}
# {'_id': ObjectId('68e63b562e1853074f2a818a'), 'Row ID': 474, 'Order ID': 'CA-2014-144666', 'Order Date': datetime.datetime(2014, 11, 9, 0, 0), 'Ship Date': datetime.datetime(2014, 11, 11, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'JP-15520', 'Customer Name': 'Jeremy Pistek', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'TEC-PH-10002680', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Samsung Galaxy Note 3', 'Sales': 703.968, 'Quantity': 4, 'Discount': 0.2, 'Profit': 87.996}
# {'_id': ObjectId('68e63b562e1853074f2a8191'), 'Row ID': 481, 'Order ID': 'CA-2016-100790', 'Order Date': datetime.datetime(2016, 6, 26, 0, 0), 'Ship Date': datetime.datetime(2016, 7, 2, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'JG-15805', 'Customer Name': 'John Grady', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10024, 'Region': 'East', 'Product ID': 'OFF-ST-10000689', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Fellowes Strictly Business Drawer File, Letter/Legal Size', 'Sales': 704.25, 'Quantity': 5, 'Discount': 0.0, 'Profit': 84.51}
# {'_id': ObjectId('68e63b562e1853074f2a8196'), 'Row ID': 486, 'Order ID': 'CA-2017-140963', 'Order Date': datetime.datetime(2017, 6, 10, 0, 0), 'Ship Date': datetime.datetime(2017, 6, 13, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'MT-18070', 'Customer Name': 'Michelle Tran', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90045, 'Region': 'West', 'Product ID': 'FUR-BO-10001337', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': "O'Sullivan Living Dimensions 2-Shelf Bookcases", 'Sales': 514.165, 'Quantity': 5, 'Discount': 0.15, 'Profit': -30.245}
# {'_id': ObjectId('68e63b562e1853074f2a8198'), 'Row ID': 488, 'Order ID': 'CA-2014-154627', 'Order Date': datetime.datetime(2014, 10, 29, 0, 0), 'Ship Date': datetime.datetime(2014, 10, 31, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'SA-20830', 'Customer Name': 'Sue Ann Reed', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Chicago', 'State': 'Illinois', 'Postal Code': 60610, 'Region': 'Central', 'Product ID': 'TEC-PH-10001363', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Apple iPhone 5S', 'Sales': 2735.952, 'Quantity': 6, 'Discount': 0.2, 'Profit': 341.994}
# {'_id': ObjectId('68e63b562e1853074f2a81a7'), 'Row ID': 503, 'Order ID': 'US-2016-105578', 'Order Date': datetime.datetime(2016, 5, 30, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 4, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'MY-17380', 'Customer Name': 'Maribeth Yedwab', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Parker', 'State': 'Colorado', 'Postal Code': 80134, 'Region': 'West', 'Product ID': 'FUR-CH-10001215', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Global Troy Executive Leather Low-Back Tilter', 'Sales': 801.568, 'Quantity': 2, 'Discount': 0.2, 'Profit': 50.098}
# {'_id': ObjectId('68e63b562e1853074f2a81ae'), 'Row ID': 510, 'Order ID': 'CA-2015-145352', 'Order Date': datetime.datetime(2015, 3, 16, 0, 0), 'Ship Date': datetime.datetime(2015, 3, 22, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'CM-12385', 'Customer Name': 'Christopher Martinez', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Atlanta', 'State': 'Georgia', 'Postal Code': 30318, 'Region': 'South', 'Product ID': 'OFF-BI-10003527', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind', 'Sales': 6354.95, 'Quantity': 5, 'Discount': 0.0, 'Profit': 3177.475}
# {'_id': ObjectId('68e63b562e1853074f2a81b4'), 'Row ID': 516, 'Order ID': 'CA-2017-127432', 'Order Date': datetime.datetime(2017, 1, 22, 0, 0), 'Ship Date': datetime.datetime(2017, 1, 27, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'AD-10180', 'Customer Name': 'Alan Dominguez', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Great Falls', 'State': 'Montana', 'Postal Code': 59405, 'Region': 'West', 'Product ID': 'TEC-CO-10003236', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Canon Image Class D660 Copier', 'Sales': 2999.95, 'Quantity': 5, 'Discount': 0.0, 'Profit': 1379.977}
# {'_id': ObjectId('68e63b562e1853074f2a81b7'), 'Row ID': 519, 'Order ID': 'CA-2017-127432', 'Order Date': datetime.datetime(2017, 1, 22, 0, 0), 'Ship Date': datetime.datetime(2017, 1, 27, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'AD-10180', 'Customer Name': 'Alan Dominguez', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Great Falls', 'State': 'Montana', 'Postal Code': 59405, 'Region': 'West', 'Product ID': 'OFF-ST-10004459', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Tennsco Single-Tier Lockers', 'Sales': 1126.02, 'Quantity': 3, 'Discount': 0.0, 'Profit': 56.301}
# {'_id': ObjectId('68e63b562e1853074f2a81bf'), 'Row ID': 527, 'Order ID': 'CA-2017-113558', 'Order Date': datetime.datetime(2017, 10, 21, 0, 0), 'Ship Date': datetime.datetime(2017, 10, 26, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'PH-18790', 'Customer Name': 'Patricia Hirasaki', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Lakeland', 'State': 'Florida', 'Postal Code': 33801, 'Region': 'South', 'Product ID': 'FUR-CH-10003379', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Global Commerce Series High-Back Swivel/Tilt Chairs', 'Sales': 683.952, 'Quantity': 3, 'Discount': 0.2, 'Profit': 42.747}
# {'_id': ObjectId('68e63b562e1853074f2a81c2'), 'Row ID': 530, 'Order ID': 'US-2015-138303', 'Order Date': datetime.datetime(2015, 9, 3, 0, 0), 'Ship Date': datetime.datetime(2015, 9, 7, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'MG-18145', 'Customer Name': 'Mike Gockenbach', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19134, 'Region': 'East', 'Product ID': 'OFF-SU-10002881', 'Category': 'Office Supplies', 'Sub-Category': 'Supplies', 'Product Name': 'Martin Yale Chadless Opener Electric Letter Opener', 'Sales': 666.248, 'Quantity': 1, 'Discount': 0.2, 'Profit': -149.9058}
# {'_id': ObjectId('68e63b562e1853074f2a81c6'), 'Row ID': 534, 'Order ID': 'CA-2016-168753', 'Order Date': datetime.datetime(2016, 5, 29, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 1, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'RL-19615', 'Customer Name': 'Rob Lucas', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Montgomery', 'State': 'Alabama', 'Postal Code': 36116, 'Region': 'South', 'Product ID': 'TEC-PH-10000984', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Panasonic KX-TG9471B', 'Sales': 979.95, 'Quantity': 5, 'Discount': 0.0, 'Profit': 274.386}
# {'_id': ObjectId('68e63b562e1853074f2a81cf'), 'Row ID': 543, 'Order ID': 'US-2015-120161', 'Order Date': datetime.datetime(2015, 12, 18, 0, 0), 'Ship Date': datetime.datetime(2015, 12, 23, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'LM-17065', 'Customer Name': 'Liz MacKendrick', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Springfield', 'State': 'Ohio', 'Postal Code': 45503, 'Region': 'East', 'Product ID': 'OFF-ST-10001809', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Fellowes Officeware Wire Shelving', 'Sales': 646.776, 'Quantity': 9, 'Discount': 0.2, 'Profit': -145.5246}
# ...
# {'_id': ObjectId('68e63b562e1853074f2a81de'), 'Row ID': 558, 'Order ID': 'CA-2016-113243', 'Order Date': datetime.datetime(2016, 6, 10, 0, 0), 'Ship Date': datetime.datetime(2016, 6, 15, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'OT-18730', 'Customer Name': 'Olvera Toch', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90045, 'Region': 'West', 'Product ID': 'FUR-TA-10004256', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bretford \x93Just In Time\x94 Height-Adjustable Multi-Task Work Tables', 'Sales': 1335.68, 'Quantity': 4, 'Discount': 0.2, 'Profit': -217.048}
# {'_id': ObjectId('68e63b562e1853074f2a8204'), 'Row ID': 596, 'Order ID': 'CA-2014-131450', 'Order Date': datetime.datetime(2014, 8, 8, 0, 0), 'Ship Date': datetime.datetime(2014, 8, 15, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'LR-16915', 'Customer Name': 'Lena Radford', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Diego', 'State': 'California', 'Postal Code': 92024, 'Region': 'West', 'Product ID': 'TEC-CO-10004115', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Sharp AL-1530CS Digital Copier', 'Sales': 1199.976, 'Quantity': 3, 'Discount': 0.2, 'Profit': 434.9913}
# {'_id': ObjectId('68e63b562e1853074f2a8216'), 'Row ID': 614, 'Order ID': 'CA-2016-121223', 'Order Date': datetime.datetime(2016, 9, 11, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 13, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'GD-14590', 'Customer Name': 'Giulietta Dortch', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19143, 'Region': 'East', 'Product ID': 'TEC-PH-10004667', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Cisco 8x8 Inc. 6753i IP Business Phone System', 'Sales': 728.946, 'Quantity': 9, 'Discount': 0.4, 'Profit': -157.9383}
# {'_id': ObjectId('68e63b562e1853074f2a8220'), 'Row ID': 624, 'Order ID': 'CA-2015-138009', 'Order Date': datetime.datetime(2015, 11, 29, 0, 0), 'Ship Date': datetime.datetime(2015, 12, 3, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'SF-20965', 'Customer Name': 'Sylvia Foulston', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Dearborn', 'State': 'Michigan', 'Postal Code': 48126, 'Region': 'Central', 'Product ID': 'OFF-AP-10000179', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': 'Honeywell Enviracaire Portable HEPA Air Cleaner for up to 10 x 16 Room', 'Sales': 555.21, 'Quantity': 5, 'Discount': 0.1, 'Profit': 178.901}
# {'_id': ObjectId('68e63b562e1853074f2a8221'), 'Row ID': 625, 'Order ID': 'CA-2015-138009', 'Order Date': datetime.datetime(2015, 11, 29, 0, 0), 'Ship Date': datetime.datetime(2015, 12, 3, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'SF-20965', 'Customer Name': 'Sylvia Foulston', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Dearborn', 'State': 'Michigan', 'Postal Code': 48126, 'Region': 'Central', 'Product ID': 'OFF-ST-10001272', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Mini 13-1/2 Capacity Data Binder Rack, Pearl', 'Sales': 523.48, 'Quantity': 4, 'Discount': 0.0, 'Profit': 130.87}
# {'_id': ObjectId('68e63b562e1853074f2a822f'), 'Row ID': 639, 'Order ID': 'CA-2016-115917', 'Order Date': datetime.datetime(2016, 5, 20, 0, 0), 'Ship Date': datetime.datetime(2016, 5, 25, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'RB-19465', 'Customer Name': 'Rick Bensley', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Vallejo', 'State': 'California', 'Postal Code': 94591, 'Region': 'West', 'Product ID': 'FUR-FU-10000576', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Luxo Professional Fluorescent Magnifier Lamp with Clamp-Mount Base', 'Sales': 1049.2, 'Quantity': 5, 'Discount': 0.0, 'Profit': 272.792}
# {'_id': ObjectId('68e63b562e1853074f2a8242'), 'Row ID': 658, 'Order ID': 'US-2016-156097', 'Order Date': datetime.datetime(2016, 9, 19, 0, 0), 'Ship Date': datetime.datetime(2016, 9, 19, 0, 0), 'Ship Mode': 'Same Day', 'Customer ID': 'EH-14125', 'Customer Name': 'Eugene Hildebrand', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Aurora', 'State': 'Illinois', 'Postal Code': 60505, 'Region': 'Central', 'Product ID': 'FUR-CH-10001215', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Global Troy Executive Leather Low-Back Tilter', 'Sales': 701.372, 'Quantity': 2, 'Discount': 0.3, 'Profit': -50.098}
# {'_id': ObjectId('68e63b562e1853074f2a8244'), 'Row ID': 660, 'Order ID': 'CA-2015-146563', 'Order Date': datetime.datetime(2015, 8, 24, 0, 0), 'Ship Date': datetime.datetime(2015, 8, 28, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'CB-12025', 'Customer Name': 'Cassandra Brandow', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Arlington', 'State': 'Texas', 'Postal Code': 76017, 'Region': 'Central', 'Product ID': 'OFF-ST-10001490', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Hot File 7-Pocket, Floor Stand', 'Sales': 999.432, 'Quantity': 7, 'Discount': 0.2, 'Profit': 124.929}
# {'_id': ObjectId('68e63b562e1853074f2a8245'), 'Row ID': 661, 'Order ID': 'CA-2015-146563', 'Order Date': datetime.datetime(2015, 8, 24, 0, 0), 'Ship Date': datetime.datetime(2015, 8, 28, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'CB-12025', 'Customer Name': 'Cassandra Brandow', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Arlington', 'State': 'Texas', 'Postal Code': 76017, 'Region': 'Central', 'Product ID': 'OFF-ST-10001511', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Space Solutions Commercial Steel Shelving', 'Sales': 724.08, 'Quantity': 14, 'Discount': 0.2, 'Profit': -135.765}
# {'_id': ObjectId('68e63b562e1853074f2a8246'), 'Row ID': 662, 'Order ID': 'CA-2015-146563', 'Order Date': datetime.datetime(2015, 8, 24, 0, 0), 'Ship Date': datetime.datetime(2015, 8, 28, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'CB-12025', 'Customer Name': 'Cassandra Brandow', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Arlington', 'State': 'Texas', 'Postal Code': 76017, 'Region': 'Central', 'Product ID': 'FUR-TA-10001768', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Hon Racetrack Conference Tables', 'Sales': 918.785, 'Quantity': 5, 'Discount': 0.3, 'Profit': -118.1295}
# {'_id': ObjectId('68e63b562e1853074f2a825c'), 'Row ID': 684, 'Order ID': 'US-2017-168116', 'Order Date': datetime.datetime(2017, 11, 4, 0, 0), 'Ship Date': datetime.datetime(2017, 11, 4, 0, 0), 'Ship Mode': 'Same Day', 'Customer ID': 'GT-14635', 'Customer Name': 'Grant Thornton', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Burlington', 'State': 'North Carolina', 'Postal Code': 27217, 'Region': 'South', 'Product ID': 'TEC-MA-10004125', 'Category': 'Technology', 'Sub-Category': 'Machines', 'Product Name': 'Cubify CubeX 3D Printer Triple Head Print', 'Sales': 7999.98, 'Quantity': 4, 'Discount': 0.5, 'Profit': -3839.9904}
# {'_id': ObjectId('68e63b562e1853074f2a8275'), 'Row ID': 709, 'Order ID': 'CA-2014-112158', 'Order Date': datetime.datetime(2014, 12, 2, 0, 0), 'Ship Date': datetime.datetime(2014, 12, 4, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'DP-13165', 'Customer Name': 'David Philippe', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10035, 'Region': 'East', 'Product ID': 'FUR-BO-10003272', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': "O'Sullivan Living Dimensions 5-Shelf Bookcases", 'Sales': 883.92, 'Quantity': 5, 'Discount': 0.2, 'Profit': -110.49}
# {'_id': ObjectId('68e63b562e1853074f2a8282'), 'Row ID': 722, 'Order ID': 'CA-2016-142335', 'Order Date': datetime.datetime(2016, 12, 15, 0, 0), 'Ship Date': datetime.datetime(2016, 12, 19, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'MP-17965', 'Customer Name': 'Michael Paige', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Detroit', 'State': 'Michigan', 'Postal Code': 48205, 'Region': 'Central', 'Product ID': 'FUR-TA-10000198', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Chromcraft Bull-Nose Wood Oval Conference Tables & Bases', 'Sales': 1652.94, 'Quantity': 3, 'Discount': 0.0, 'Profit': 231.4116}
# {'_id': ObjectId('68e63b562e1853074f2a828b'), 'Row ID': 731, 'Order ID': 'US-2016-150861', 'Order Date': datetime.datetime(2016, 12, 3, 0, 0), 'Ship Date': datetime.datetime(2016, 12, 6, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'EG-13900', 'Customer Name': 'Emily Grady', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Oceanside', 'State': 'New York', 'Postal Code': 11572, 'Region': 'East', 'Product ID': 'FUR-CH-10002965', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Global Leather Highback Executive Chair with Pneumatic Height Adjustment, Black', 'Sales': 542.646, 'Quantity': 3, 'Discount': 0.1, 'Profit': 102.4998}
# {'_id': ObjectId('68e63b562e1853074f2a829b'), 'Row ID': 747, 'Order ID': 'CA-2014-124429', 'Order Date': datetime.datetime(2014, 5, 27, 0, 0), 'Ship Date': datetime.datetime(2014, 5, 27, 0, 0), 'Ship Mode': 'Same Day', 'Customer ID': 'MH-17785', 'Customer Name': 'Maya Herman', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Diego', 'State': 'California', 'Postal Code': 92105, 'Region': 'West', 'Product ID': 'FUR-TA-10002607', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'KI Conference Tables', 'Sales': 567.12, 'Quantity': 10, 'Discount': 0.2, 'Profit': -28.356}
# {'_id': ObjectId('68e63b562e1853074f2a82a2'), 'Row ID': 754, 'Order ID': 'CA-2016-110499', 'Order Date': datetime.datetime(2016, 4, 7, 0, 0), 'Ship Date': datetime.datetime(2016, 4, 9, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'YC-21895', 'Customer Name': 'Yoseph Carroll', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'TEC-CO-10002095', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Hewlett Packard 610 Color Digital Copier / Printer', 'Sales': 1199.976, 'Quantity': 3, 'Discount': 0.2, 'Profit': 374.9925}
# {'_id': ObjectId('68e63b562e1853074f2a82ae'), 'Row ID': 766, 'Order ID': 'CA-2014-162775', 'Order Date': datetime.datetime(2014, 1, 13, 0, 0), 'Ship Date': datetime.datetime(2014, 1, 15, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'CS-12250', 'Customer Name': 'Chris Selesnick', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Bossier City', 'State': 'Louisiana', 'Postal Code': 71111, 'Region': 'South', 'Product ID': 'TEC-AC-10003174', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Plantronics S12 Corded Telephone Headset System', 'Sales': 646.74, 'Quantity': 6, 'Discount': 0.0, 'Profit': 258.696}
# {'_id': ObjectId('68e63b562e1853074f2a82b0'), 'Row ID': 768, 'Order ID': 'CA-2014-162775', 'Order Date': datetime.datetime(2014, 1, 13, 0, 0), 'Ship Date': datetime.datetime(2014, 1, 15, 0, 0), 'Ship Mode': 'Second Class', 'Customer ID': 'CS-12250', 'Customer Name': 'Chris Selesnick', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Bossier City', 'State': 'Louisiana', 'Postal Code': 71111, 'Region': 'South', 'Product ID': 'OFF-ST-10000025', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Fellowes Stor/Drawer Steel Plus Storage Drawers', 'Sales': 572.58, 'Quantity': 6, 'Discount': 0.0, 'Profit': 34.3548}
# {'_id': ObjectId('68e63b562e1853074f2a82b2'), 'Row ID': 770, 'Order ID': 'CA-2016-157245', 'Order Date': datetime.datetime(2016, 5, 19, 0, 0), 'Ship Date': datetime.datetime(2016, 5, 24, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'LE-16810', 'Customer Name': 'Laurel Elliston', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Arlington', 'State': 'Virginia', 'Postal Code': 22204, 'Region': 'South', 'Product ID': 'FUR-CH-10003746', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Hon 4070 Series Pagoda Round Back Stacking Chairs', 'Sales': 641.96, 'Quantity': 2, 'Discount': 0.0, 'Profit': 179.7488}
# {'_id': ObjectId('68e63b562e1853074f2a82ba'), 'Row ID': 778, 'Order ID': 'CA-2015-144267', 'Order Date': datetime.datetime(2015, 8, 21, 0, 0), 'Ship Date': datetime.datetime(2015, 8, 23, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'NZ-18565', 'Customer Name': 'Nick Zandusky', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'FUR-CH-10002335', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Hon GuestStacker Chair', 'Sales': 544.008, 'Quantity': 3, 'Discount': 0.2, 'Profit': 40.8006}
# {'_id': ObjectId('68e63b562e1853074f2a82c9'), 'Row ID': 793, 'Order ID': 'CA-2016-105256', 'Order Date': datetime.datetime(2016, 5, 20, 0, 0), 'Ship Date': datetime.datetime(2016, 5, 20, 0, 0), 'Ship Mode': 'Same Day', 'Customer ID': 'JK-15730', 'Customer Name': 'Joe Kamberova', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Asheville', 'State': 'North Carolina', 'Postal Code': 28806, 'Region': 'South', 'Product ID': 'TEC-PH-10001530', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Cisco Unified IP Phone 7945G VoIP phone', 'Sales': 1363.96, 'Quantity': 5, 'Discount': 0.2, 'Profit': 85.2475}
# {'_id': ObjectId('68e63b562e1853074f2a82d7'), 'Row ID': 807, 'Order ID': 'CA-2014-134313', 'Order Date': datetime.datetime(2014, 11, 1, 0, 0), 'Ship Date': datetime.datetime(2014, 11, 7, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'RA-19915', 'Customer Name': 'Russell Applegate', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Denver', 'State': 'Colorado', 'Postal Code': 80219, 'Region': 'West', 'Product ID': 'TEC-PH-10001795', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'ClearOne CHATAttach 160 -\xa0speaker phone', 'Sales': 1983.968, 'Quantity': 4, 'Discount': 0.2, 'Profit': 247.996}
# {'_id': ObjectId('68e63b562e1853074f2a82db'), 'Row ID': 811, 'Order ID': 'CA-2014-151995', 'Order Date': datetime.datetime(2014, 10, 13, 0, 0), 'Ship Date': datetime.datetime(2014, 10, 15, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'ZC-21910', 'Customer Name': 'Zuschuss Carroll', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Edmonds', 'State': 'Washington', 'Postal Code': 98026, 'Region': 'West', 'Product ID': 'FUR-TA-10002903', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bevis Round Bullnose 29" High Table Top', 'Sales': 1298.55, 'Quantity': 5, 'Discount': 0.0, 'Profit': 311.652}
# {'_id': ObjectId('68e63b562e1853074f2a82df'), 'Row ID': 815, 'Order ID': 'CA-2017-143686', 'Order Date': datetime.datetime(2017, 5, 14, 0, 0), 'Ship Date': datetime.datetime(2017, 5, 14, 0, 0), 'Ship Mode': 'Same Day', 'Customer ID': 'PJ-19015', 'Customer Name': 'Pauline Johnson', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Santa Ana', 'State': 'California', 'Postal Code': 92704, 'Region': 'West', 'Product ID': 'TEC-AC-10001838', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Razer Tiamat Over Ear 7.1 Surround Sound PC Gaming Headset', 'Sales': 1399.93, 'Quantity': 7, 'Discount': 0.0, 'Profit': 601.9699}

# %% [markdown]
# Question 6.  Fetch the top 3 orders with the highest Profit
#
# Answer:

# %%
#  Find and sort by Profit descending, then limit to top 3

top_3_profit_orders = collection.find().sort("Profit", -1).limit(3)

# Print the top 3 orders
for order in top_3_profit_orders:
    print(order)
# Out:
# {'_id': ObjectId('68e606399817aaf8632f78c9'), 'Row ID': 6827, 'Order ID': 'CA-2016-118689', 'Order Date': datetime.datetime(2016, 10, 2, 0, 0), 'Ship Date': datetime.datetime(2016, 10, 9, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'TC-20980', 'Customer Name': 'Tamara Chand', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Lafayette', 'State': 'Indiana', 'Postal Code': 47905, 'Region': 'Central', 'Product ID': 'TEC-CO-10004722', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Canon imageCLASS 2200 Advanced Copier', 'Sales': 17499.95, 'Quantity': 5, 'Discount': 0.0, 'Profit': 8399.976}
# {'_id': ObjectId('68e606399817aaf8632f7df8'), 'Row ID': 8154, 'Order ID': 'CA-2017-140151', 'Order Date': datetime.datetime(2017, 3, 23, 0, 0), 'Ship Date': datetime.datetime(2017, 3, 25, 0, 0), 'Ship Mode': 'First Class', 'Customer ID': 'RB-19360', 'Customer Name': 'Raymond Buch', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98115, 'Region': 'West', 'Product ID': 'TEC-CO-10004722', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Canon imageCLASS 2200 Advanced Copier', 'Sales': 13999.96, 'Quantity': 4, 'Discount': 0.0, 'Profit': 6719.9808}
# {'_id': ObjectId('68e606399817aaf8632f6e7d'), 'Row ID': 4191, 'Order ID': 'CA-2017-166709', 'Order Date': datetime.datetime(2017, 11, 17, 0, 0), 'Ship Date': datetime.datetime(2017, 11, 22, 0, 0), 'Ship Mode': 'Standard Class', 'Customer ID': 'HL-15040', 'Customer Name': 'Hunter Lopez', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Newark', 'State': 'Delaware', 'Postal Code': 19711, 'Region': 'East', 'Product ID': 'TEC-CO-10004722', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Canon imageCLASS 2200 Advanced Copier', 'Sales': 10499.97, 'Quantity': 3, 'Discount': 0.0, 'Profit': 5039.9856}

# %% [markdown]
# Question 7.  Update all orders with Ship Mode as "First Class" to "Premium Class."
#
# Answer:

# %%
# Filter and update documents

result = collection.update_many({"Ship Mode": "First Class"}, {"$set": {"Ship Mode": "Premium Class"}})

print(f"Documents matched: {result.matched_count}")
print(f"Documents modified: {result.modified_count}")
# Out:
# Documents matched: 1538
# Documents modified: 1538

# %% [markdown]
# Question 8. Delete all orders where Sales is less than 50.
#
# Answer:

# %%
# Delete all documents with Sales less than 50
delete_query = {"Sales": {"$lt": 50}}

result = collection.delete_many(delete_query)

print(f"Deleted {result.deleted_count} documents with Sales less than 50.")
# Out:
# Deleted 4849 documents with Sales less than 50.

# %% [markdown]
# Question 9. Use aggregation to group orders by Region and calculate total sales per region
#
# Answer:
#
# Note: this total sales for different regions might get affected as 4849 records has been deleted in question 8 whose sales was less than 50

# %%
# Aggregation pipeline to group by Region and sum Sales
pipeline = [
    {
        "$group": {
            "_id": "$Region",
            "total_sales": {"$sum": "$Sales"}
        }
    }
]

# Execute aggregation
results = collection.aggregate(pipeline)

# Print total sales per region
for result in results:
    print(f"Region: {result['_id']}, Total Sales: {result['total_sales']}")
# Out:
# Region: Central, Total Sales: 479611.8458
# Region: West, Total Sales: 694686.6195
# Region: East, Total Sales: 651137.705
# Region: South, Total Sales: 376023.312

# %% [markdown]
# Question 10.  Fetch all distinct values for Ship Mode from the collection.
#
# Answer:
#
# Note: First class mode was replaced with Premium class with question 7.

# %%
# Get distinct Ship Mode values
distinct_ship_modes = collection.distinct('Ship Mode')

# Print distinct values
print("Distinct Ship Mode values:")
for mode in distinct_ship_modes:
    print(mode)
# Out:
# Distinct Ship Mode values:
# Premium Class
# Same Day
# Second Class
# Standard Class

# %% [markdown]
# Question 11. Count the number of orders for each category.
#
# Answer:

# %%
# Aggregation pipeline to group by Category and count orders
pipeline = [
    {
        "$group": {
            "_id": "$Category",
            "total_orders": {"$sum": 1}
        }
    }
]

# Execute the aggregation
results = collection.aggregate(pipeline)

# Print the total orders per category
for result in results:
    print(f"Category: {result['_id']}, Total Orders: {result['total_orders']}")
# Out:
# Category: Furniture, Total Orders: 1573
# Category: Technology, Total Orders: 1496
# Category: Office Supplies, Total Orders: 2076
